# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

data = pd.read_excel('/content/drive/MyDrive/FYDP Final/Section_list.xlsx')
np_data = data.to_numpy()

# %% [markdown]
# # Input Data

# %%
n = input("Enter how many course you want to take = ")
taken_course = []
for i in range(int(n)) :
  a = input("Enter course Code = ")
  taken_course.append(a)

print("")
m = input("1.Day Class\n2.Morning Class \nEnter your preferrence = ")
selected = []
for i in range(0,len(np_data)):
  for j in range(len(taken_course)) :
    if np_data[i][0] == taken_course[j] :
      selected.append(np_data[i])

# %%
# CSE 323/CSE 3711    Computer Networks
# CSE 324 /CSE 3712   Computer Networks Lab
# CSE 3313/CSE 313    Computer Architecture
# CSE 3411/CSI 311    System Analysis and Design
# CSE 3412/CSI 312    System Analysis and Design Lab
# CSE 3521/CSI 221    Database Management Systems
# CSE 3522/CSI 222    Database Management Systems Lab
# CSE 3811/CSI 341    Artificial Intelligence
# CSE 3812/CSI 342    Artificial Intelligence Lab
# CSI 309/ CSE 4509   Operating Systems Concept
# CSI 310/ CSE 4510   Operating Systems Concept Lab
# CSI 321/CSE 3421    Software Engineering
# CSI 322/CSE 3422    Software Engineering Lab
# EEE 2123/ CSE 123   Electronics
# EEE 2124/ CSE 124   Electronics Lab

# %% [markdown]
# # Calculate Time Gap

# %%
def day_count(final_routine):
  c = final_routine
  sat_1 = []
  sat = []
  sun_1 = []
  sun = []
  t_1 = []
  t = []
  wed_1 = []
  wed = []
  time = 0
  time1 = 0
  time2 = 0
  time3 = 0
  for i in range(0,len(c)):
      if c[i][3].find('Sat') != -1:
        sat_1.append(c[i])
      if c[i][3].find('S W') != -1:
        sun_1.append(c[i])
      if c[i][3].find('T') != -1:
        t_1.append(c[i])
      if c[i][3].find('W') != -1:
        wed_1.append(c[i])


  #saturday
  for i in range(0,len(sat_1)):
    if sat_1[i][4] ==  '8:30 AM - 10:00 AM':
      sat.append(sat_1[i])
  for i in range(0,len(sat_1)):
    if sat_1[i][4] ==  '8:30 AM - 11:00 AM':
      sat.append(sat_1[i])
  for i in range(0,len(sat_1)):
    if sat_1[i][4] ==  '10:05 AM - 11:35 AM':
      sat.append(sat_1[i])
  for i in range(0,len(sat_1)):
    if sat_1[i][4] ==  '11:00 AM - 1:30 PM':
      sat.append(sat_1[i])
  for i in range(0,len(sat_1)):
    if sat_1[i][4] ==  '11:40 AM - 1:10 PM':
      sat.append(sat_1[i])
  for i in range(0,len(sat_1)):
    if sat_1[i][4] ==  '1:30 PM - 3:00 PM':
      sat.append(sat_1[i])
  for i in range(0,len(sat_1)):
    if sat_1[i][4] ==  '2:00 PM - 4:30 PM':
      sat.append(sat_1[i])
  for i in range(0,len(sat_1)):
    if sat_1[i][4] ==  '3:00 PM - 4:30 PM':
      sat.append(sat_1[i])

  if len(sat) <= 1 :
        time= time+0
  elif(len(sat)>1):
    for i in range(0,int(len(sat))-1):
        if sat[i][4] == '8:30 AM - 10:00 AM' and sat[i+1][4]=='10:05 AM - 11:35 AM':
          time = time + 5
        elif sat[i][4] == '8:30 AM - 10:00 AM' and sat[i+1][4]=='11:00 AM - 1:30 PM':
          time = time + 60
        elif sat[i][4] == '8:30 AM - 10:00 AM' and sat[i+1][4]=='11:40 AM - 1:10 PM':
          time = time+ 100
        elif sat[i][4] == '8:30 AM - 10:00 AM' and sat[i+1][4]=='1:30 PM - 3:00 PM':
          time =time+ 210
        elif sat[i][4] == '8:30 AM - 10:00 AM' and sat[i+1][4]=='2:00 PM - 4:30 PM':
          time =time+ 240
        elif sat[i][4] == '8:30 AM - 10:00 AM' and sat[i+1][4]=='3:00 PM - 4:30 PM':
          time =time+ 300
        elif sat[i][4] == '8:30 AM - 11:00 AM' and sat[i+1][4]=='11:00 AM - 1:30 PM':
          time =time+ 0
        elif sat[i][4] == '8:30 AM - 11:00 AM' and sat[i+1][4]=='11:40 AM - 1:10 PM':
          time =time+ 40
        elif sat[i][4] == '8:30 AM - 11:00 AM' and sat[i+1][4]=='1:30 PM - 3:00 PM':
          time =time+ 150
        elif sat[i][4] == '8:30 AM - 11:00 AM' and sat[i+1][4]=='2:00 PM - 4:30 PM':
          time =time+ 180
        elif sat[i][4] == '8:30 AM - 11:00 AM' and sat[i+1][4]=='3:00 PM - 4:30 PM':
          time =time+ 240     
        elif sat[i][4] == '10:05 AM - 11:35 AM' and sat[i+1][4]=='11:40 AM - 1:10 PM':
          time =time+ 5
        elif sat[i][4] == '10:05 AM - 11:35 AM' and sat[i+1][4]=='1:30 PM - 3:00 PM':
          time =time+ 115
        elif sat[i][4] == '10:05 AM - 11:35 AM' and sat[i+1][4]=='2:00 PM - 4:30 PM':
          time =time+ 145
        elif sat[i][4] == '10:05 AM - 11:35 AM' and sat[i+1][4]=='3:00 PM - 4:30 PM':
          time =time+ 205 
        elif sat[i][4] == '11:00 AM - 1:30 PM' and  sat[i+1][4]=='1:30 PM - 3:00 PM':
          time =time+ 0
        elif sat[i][4]=='11:00 AM - 1:30 PM' and  sat[i+1][4]=='2:00 PM - 4:30 PM':
          time =time+ 30
        elif sat[i][4]=='11:00 AM - 1:30 PM' and  sat[i+1][4]=='3:00 PM - 4:30 PM':
          time =time+ 90
        elif sat[i][4]=='11:40 AM - 1:10 PM' and sat[i+1][4]=='1:30 PM - 3:00 PM':
          time =time+20
        elif sat[i][4]=='11:40 AM - 1:10 PM' and sat[i+1][4]=='2:00 PM - 4:30 PM':
          time =time+50
        elif sat[i][4]=='11:40 AM - 1:10 PM' and sat[i+1][4]=='3:00 PM - 4:30 PM':
          time =time+110
        elif sat[i][4]=='1:30 PM - 3:00 PM' and sat[i+1][4]=='3:00 PM - 4:30 PM':
          time =time+0
        else:
          time = time+0 


  #sunday
  for i in range(0,len(sun_1)):
    if sun_1[i][4] ==  '8:30 AM - 10:00 AM':
      sun.append(sun_1[i])
  for i in range(0,len(sun_1)):
    if sun_1[i][4] ==  '8:30 AM - 11:00 AM':
      sun.append(sun_1[i])
  for i in range(0,len(sun_1)):
    if sun_1[i][4] ==  '10:05 AM - 11:35 AM':
      sun.append(sun_1[i])
  for i in range(0,len(sun_1)):
    if sun_1[i][4] ==  '11:00 AM - 1:30 PM':
      sun.append(sun_1[i])
  for i in range(0,len(sun_1)):
    if sun_1[i][4] ==  '11:40 AM - 1:10 PM':
      sun.append(sun_1[i])
  for i in range(0,len(sun_1)):
    if sun_1[i][4] ==  '1:30 PM - 3:00 PM':
      sun.append(sun_1[i])
  for i in range(0,len(sun_1)):
    if sun_1[i][4] ==  '2:00 PM - 4:30 PM':
      sun.append(sun_1[i])
  for i in range(0,len(sun_1)):
    if sun_1[i][4] ==  '3:00 PM - 4:30 PM':
      sun.append(sun_1[i])

  if len(sun) <= 1 :
        time1= time1+0
  elif(len(sun)>1):
    for i in range(0,int(len(sun))-1):
        if sun[i][4] == '8:30 AM - 10:00 AM' and sun[i+1][4]=='10:05 AM - 11:35 AM':
          time1 = time1 + 5
        elif sun[i][4] == '8:30 AM - 10:00 AM' and sun[i+1][4]=='11:00 AM - 1:30 PM':
          time1 = time1 + 60
        elif sun[i][4] == '8:30 AM - 10:00 AM' and sun[i+1][4]=='11:40 AM - 1:10 PM':
          time1 = time1+ 100
        elif sun[i][4] == '8:30 AM - 10:00 AM' and sun[i+1][4]=='1:30 PM - 3:00 PM':
          time1 =time1+ 210
        elif sun[i][4] == '8:30 AM - 10:00 AM' and sun[i+1][4]=='2:00 PM - 4:30 PM':
          time1 =time1+ 240
        elif sun[i][4] == '8:30 AM - 10:00 AM' and sun[i+1][4]=='3:00 PM - 4:30 PM':
          time1 =time1+ 300
        elif sun[i][4] == '8:30 AM - 11:00 AM' and sun[i+1][4]=='11:00 AM - 1:30 PM':
          time1 =time1+ 0
        elif sun[i][4] == '8:30 AM - 11:00 AM' and sun[i+1][4]=='11:40 AM - 1:10 PM':
          time1 =time1+ 40
        elif sun[i][4] == '8:30 AM - 11:00 AM' and sun[i+1][4]=='1:30 PM - 3:00 PM':
          time1 =time1+ 150
        elif sun[i][4] == '8:30 AM - 11:00 AM' and sun[i+1][4]=='2:00 PM - 4:30 PM':
          time1 =time1+ 180
        elif sun[i][4] == '8:30 AM - 11:00 AM' and sun[i+1][4]=='3:00 PM - 4:30 PM':
          time1 =time1+ 240     
        elif sun[i][4] == '10:05 AM - 11:35 AM' and sun[i+1][4]=='11:40 AM - 1:10 PM':
          time1 =time1+ 5
        elif sun[i][4] == '10:05 AM - 11:35 AM' and sun[i+1][4]=='1:30 PM - 3:00 PM':
          time1 =time1+ 115
        elif sun[i][4] == '10:05 AM - 11:35 AM' and sun[i+1][4]=='2:00 PM - 4:30 PM':
          time1 =time1+ 145
        elif sun[i][4] == '10:05 AM - 11:35 AM' and sun[i+1][4]=='3:00 PM - 4:30 PM':
          time1 =time1+ 205 
        elif sun[i][4] == '11:00 AM - 1:30 PM' and  sun[i+1][4]=='1:30 PM - 3:00 PM':
          time1 =time1+ 0
        elif sun[i][4]=='11:00 AM - 1:30 PM' and  sun[i+1][4]=='2:00 PM - 4:30 PM':
          time1 =time1+ 30
        elif sun[i][4]=='11:00 AM - 1:30 PM' and  sun[i+1][4]=='3:00 PM - 4:30 PM':
          time1 =time1+ 90
        elif sun[i][4]=='11:40 AM - 1:10 PM' and sun[i+1][4]=='1:30 PM - 3:00 PM':
          time1 =time1+20
        elif sun[i][4]=='11:40 AM - 1:10 PM' and sun[i+1][4]=='2:00 PM - 4:30 PM':
          time1 =time1+50
        elif sun[i][4]=='11:40 AM - 1:10 PM' and sun[i+1][4]=='3:00 PM - 4:30 PM':
          time1 =time1+110
        elif sun[i][4]=='1:30 PM - 3:00 PM' and sun[i+1][4]=='3:00 PM - 4:30 PM':
          time1 =time1+0
        else:
          time1 = time1+0 


  #tuesday
  for i in range(0,len(t_1)):
    if t_1[i][4] ==  '8:30 AM - 10:00 AM':
      t.append(t_1[i])
  for i in range(0,len(t_1)):
    if t_1[i][4] ==  '8:30 AM - 11:00 AM':
      t.append(t_1[i])
  for i in range(0,len(t_1)):
    if t_1[i][4] ==  '10:05 AM - 11:35 AM':
      t.append(t_1[i])
  for i in range(0,len(t_1)):
    if t_1[i][4] ==  '11:00 AM - 1:30 PM':
      t.append(t_1[i])
  for i in range(0,len(t_1)):
    if t_1[i][4] ==  '11:40 AM - 1:10 PM':
      t.append(t_1[i])
  for i in range(0,len(t_1)):
    if t_1[i][4] ==  '1:30 PM - 3:00 PM':
      t.append(t_1[i])
  for i in range(0,len(t_1)):
    if t_1[i][4] ==  '2:00 PM - 4:30 PM':
      t.append(t_1[i])
  for i in range(0,len(t_1)):
    if t_1[i][4] ==  '3:00 PM - 4:30 PM':
      t.append(t_1[i])
    
  if len(t) <= 1 :
        time2= time2+0
  elif(len(t)>1):
    for i in range(0,int(len(t))-1):
        if t[i][4] == '8:30 AM - 10:00 AM' and t[i+1][4]=='10:05 AM - 11:35 AM':
          time2 = time2 + 5
        elif t[i][4] == '8:30 AM - 10:00 AM' and t[i+1][4]=='11:00 AM - 1:30 PM':
          time2 = time2 + 60
        elif t[i][4] == '8:30 AM - 10:00 AM' and t[i+1][4]=='11:40 AM - 1:10 PM':
          time2 = time2+ 100
        elif t[i][4] == '8:30 AM - 10:00 AM' and t[i+1][4]=='1:30 PM - 3:00 PM':
          time2 =time2+ 210
        elif t[i][4] == '8:30 AM - 10:00 AM' and t[i+1][4]=='2:00 PM - 4:30 PM':
          time2 =time2+ 240
        elif t[i][4] == '8:30 AM - 10:00 AM' and t[i+1][4]=='3:00 PM - 4:30 PM':
          time2 =time2 + 300
        elif t[i][4] == '8:30 AM - 11:00 AM' and t[i+1][4]=='11:00 AM - 1:30 PM':
          time2 =time2+ 0
        elif t[i][4] == '8:30 AM - 11:00 AM' and t[i+1][4]=='11:40 AM - 1:10 PM':
          time2 =time2+ 40
        elif t[i][4] == '8:30 AM - 11:00 AM' and t[i+1][4]=='1:30 PM - 3:00 PM':
          time2 =time2+ 150
        elif t[i][4] == '8:30 AM - 11:00 AM' and t[i+1][4]=='2:00 PM - 4:30 PM':
          time2 = time2+ 180
        elif t[i][4] == '8:30 AM - 11:00 AM' and t[i+1][4]=='3:00 PM - 4:30 PM':
          time2 =time2+ 240     
        elif t[i][4] == '10:05 AM - 11:35 AM' and t[i+1][4]=='11:40 AM - 1:10 PM':
          time2 =time2+ 5
        elif t[i][4] == '10:05 AM - 11:35 AM' and t[i+1][4]=='1:30 PM - 3:00 PM':
          time2 =time2 + 115
        elif t[i][4] == '10:05 AM - 11:35 AM' and t[i+1][4]=='2:00 PM - 4:30 PM':
          time2 = time2+ 145
        elif t[i][4] == '10:05 AM - 11:35 AM' and t[i+1][4]=='3:00 PM - 4:30 PM':
          time2 =time2+ 205 
        elif t[i][4] == '11:00 AM - 1:30 PM' and  t[i+1][4]=='1:30 PM - 3:00 PM':
          time2 =time2+ 0
        elif t[i][4]=='11:00 AM - 1:30 PM' and  t[i+1][4]=='2:00 PM - 4:30 PM':
          time2 =time2+ 30
        elif t[i][4]=='11:00 AM - 1:30 PM' and  t[i+1][4]=='3:00 PM - 4:30 PM':
          time2 =time2+ 90
        elif t[i][4]=='11:40 AM - 1:10 PM' and t[i+1][4]=='1:30 PM - 3:00 PM':
          time2 =time2+20
        elif t[i][4]=='11:40 AM - 1:10 PM' and t[i+1][4]=='2:00 PM - 4:30 PM':
          time2 =time2+50
        elif t[i][4]=='11:40 AM - 1:10 PM' and t[i+1][4]=='3:00 PM - 4:30 PM':
          time2 =time2+110
        elif t[i][4]=='1:30 PM - 3:00 PM' and t[i+1][4]=='3:00 PM - 4:30 PM':
          time2 =time2+0
        else:
          time2 = time2+0                    


  #wednesday
  for i in range(0,len(wed_1)):
    if wed_1[i][4] ==  '8:30 AM - 10:00 AM':
      wed.append(wed_1[i])
  for i in range(0,len(wed_1)):
    if wed_1[i][4] ==  '8:30 AM - 11:00 AM':
      wed.append(wed_1[i])
  for i in range(0,len(wed_1)):
    if wed_1[i][4] ==  '10:05 AM - 11:35 AM':
      wed.append(wed_1[i])
  for i in range(0,len(wed_1)):
    if wed_1[i][4] ==  '11:00 AM - 1:30 PM':
      wed.append(wed_1[i])
  for i in range(0,len(wed_1)):
    if wed_1[i][4] ==  '11:40 AM - 1:10 PM':
      wed.append(wed_1[i])
  for i in range(0,len(wed_1)):
    if wed_1[i][4] ==  '1:30 PM - 3:00 PM':
      wed.append(wed_1[i])
  for i in range(0,len(wed_1)):
    if wed_1[i][4] ==  '2:00 PM - 4:30 PM':
      wed.append(wed_1[i])
  for i in range(0,len(wed_1)):
    if wed_1[i][4] ==  '3:00 PM - 4:30 PM':
      wed.append(wed_1[i])

  if len(wed) <= 1 :
        time3= time3+0
  elif(len(wed)>1):
    for i in range(0,int(len(wed))-1):
        if wed[i][4] == '8:30 AM - 10:00 AM' and wed[i+1][4]=='10:05 AM - 11:35 AM':
          time3 = time3 + 5
        elif wed[i][4] == '8:30 AM - 10:00 AM' and wed[i+1][4]=='11:00 AM - 1:30 PM':
          time3 = time3 + 60
        elif wed[i][4] == '8:30 AM - 10:00 AM' and wed[i+1][4]=='11:40 AM - 1:10 PM':
          time3 = time3+ 100
        elif wed[i][4] == '8:30 AM - 10:00 AM' and wed[i+1][4]=='1:30 PM - 3:00 PM':
          time3 =time3+ 210
        elif wed[i][4] == '8:30 AM - 10:00 AM' and wed[i+1][4]=='2:00 PM - 4:30 PM':
          time3 =time3+ 240
        elif wed[i][4] == '8:30 AM - 10:00 AM' and wed[i+1][4]=='3:00 PM - 4:30 PM':
          time3 =time3+ 300
        elif wed[i][4] == '8:30 AM - 11:00 AM' and wed[i+1][4]=='11:00 AM - 1:30 PM':
          time3 =time3+ 0
        elif wed[i][4] == '8:30 AM - 11:00 AM' and wed[i+1][4]=='11:40 AM - 1:10 PM':
          time3 =time3+ 40
        elif wed[i][4] == '8:30 AM - 11:00 AM' and wed[i+1][4]=='1:30 PM - 3:00 PM':
          time3 =time3+ 150
        elif wed[i][4] == '8:30 AM - 11:00 AM' and wed[i+1][4]=='2:00 PM - 4:30 PM':
          time3 =time3+ 180
        elif wed[i][4] == '8:30 AM - 11:00 AM' and wed[i+1][4]=='3:00 PM - 4:30 PM':
          time3 =time3+ 240     
        elif wed[i][4] == '10:05 AM - 11:35 AM' and wed[i+1][4]=='11:40 AM - 1:10 PM':
          time3 =time3+ 5
        elif wed[i][4] == '10:05 AM - 11:35 AM' and wed[i+1][4]=='1:30 PM - 3:00 PM':
          time3 =time3+ 115
        elif wed[i][4] == '10:05 AM - 11:35 AM' and wed[i+1][4]=='2:00 PM - 4:30 PM':
          time3 =time3+ 145
        elif wed[i][4] == '10:05 AM - 11:35 AM' and wed[i+1][4]=='3:00 PM - 4:30 PM':
          time3 =time3+ 205 
        elif wed[i][4] == '11:00 AM - 1:30 PM' and  wed[i+1][4]=='1:30 PM - 3:00 PM':
          time3 =time3+ 0
        elif wed[i][4]=='11:00 AM - 1:30 PM' and  wed[i+1][4]=='2:00 PM - 4:30 PM':
          time3 =time3+ 30
        elif wed[i][4]=='11:00 AM - 1:30 PM' and  wed[i+1][4]=='3:00 PM - 4:30 PM':
          time3 =time3+ 90
        elif wed[i][4]=='11:40 AM - 1:10 PM' and wed[i+1][4]=='1:30 PM - 3:00 PM':
          time3 =time3+20
        elif wed[i][4]=='11:40 AM - 1:10 PM' and wed[i+1][4]=='2:00 PM - 4:30 PM':
          time3 =time3+50
        elif wed[i][4]=='11:40 AM - 1:10 PM' and wed[i+1][4]=='3:00 PM - 4:30 PM':
          time3 =time3+110
        elif wed[i][4]=='1:30 PM - 3:00 PM' and wed[i+1][4]=='3:00 PM - 4:30 PM':
          time3 =time3+0
        else:
          time3 = time3+0 

  total_time=(time+time1+time2+time3)
  h = int(total_time/60)
  m = total_time % 60
  print("Total Time Gap = ",h ,' Hour ',m, "Minutes In One Week.")
  print("Saturday Time Gap = ",time," Minutes.")
  print("Sunday Time Gap = ",time1," Minutes.")
  print("Tuesday Time Gap = ",time2," Minutes.")
  print("Wednesday Time Gap = ",time3," Minutes.")

# %% [markdown]
# # 1 Course

# %%
if n == '1' :
  c1 = []
  for i in range (0,len(selected)):
      if selected[i][0] == taken_course[0] :
        c1.append(selected[i])

  r = 1
  for i in range(0,len(c1)):
    print("Suggested Schedule ",r," :")
    print(c1[i])
    r+=1

  print("\nDon't Worry, You Can Take Whatever Section You Want.")
  print("Suggested schedule = ",len(c1))
  print("")

  print("")
  print("")
  print("")
  print("Your Preferable Schedule :")
  r5 = c1
  if m == '1' :
    r=1
    p=0
    for i in range(0,len(r5)):
      if r5[i][4] != '8:30 AM - 10:00 AM' and  r5[i][4] != '8:30 AM - 11:00 AM':
          print("Your Day Class Schedule ",r," :")
          print(r5[i])
          r+=1
          p+=1
    if p==0:
      print("Sorry No Schedule Available In Day Time")
  if m == '2' :
    p=0
    r=1
    for i in range(0,len(r5)):
      if r5[i][4] != '2:00 PM - 4:30 PM' and r5[i][4] != '1:30 PM - 3:00 PM' and  r5[i][4] != '3:00 PM - 4:30 PM' :
          print("Your Morning Class Schedule ",r," :")
          print(r5[i])
          r+=1
          p+=1
    if p==0 :
      print("Sorry No Schedule Available In Morning Time")

# %% [markdown]
# # 2 Courses

# %%
if n == '2' :
  selected = []
  for i in range(0,len(np_data)):
    for j in range(len(taken_course)) :
      if np_data[i][0] == taken_course[j] :
        selected.append(np_data[i])

  c1 = []
  c2 = []
  for i in range (0,len(selected)):
      if selected[i][0] == taken_course[0] :
        c1.append(selected[i])
      elif selected[i][0] == taken_course[1] :
        c2.append(selected[i])

  all_possible = len(c1)*len(c2)
  r1 = []
  r5 = []
  #for c1 and c2
  for i in range(0,len(c1)):
    for j in range (0,len(c2)):
      #2 theory
      if c1[i][1].find('Lab') == -1 and c2[j][1].find('Lab') == -1 :
        if c1[i][3] == c2[j][3] :
          if c1[i][4] != c2[j][4]:
            r1.append(c1[i])
            r1.append(c2[j])
        elif  c1[i][3] != c2[j][3]:
          r1.append(c1[i])
          r1.append(c2[j])
      #2 Lab
      if c1[i][1].find('Lab') != -1 and c2[j][1].find('Lab') != -1 :
        if c1[i][3] == c2[j][3] :
          if c1[i][4] != c2[j][4]:
            r1.append(c1[i])
            r1.append(c2[j])
        elif  c1[i][3] != c2[j][3]:
          r1.append(c1[i])
          r1.append(c2[j])
      #1 Theory 1 Lab
      if c1[i][1].find('Lab') != -1 :
          if c2[j][3].find(c1[i][3]) != -1:
            if c1[i][4] == '8:30 AM - 11:00 AM' :
              if c2[j][4] != '8:30 AM - 10:00 AM' and c2[j][4] != '10:05 AM - 11:35 AM' :
                r1.append(c1[i])
                r1.append(c2[j])
            elif c1[i][4] == '11:00 AM - 1:30 PM' :
              if c2[j][4] != '10:05 AM - 11:35 AM' and c2[j][4] != '11:40 AM - 1:10 PM' :
                r1.append(c1[i])
                r1.append(c2[j])
            elif c1[i][4] == '2:00 PM - 4:30 PM' :
              if c2[j][4] != '1:30 PM - 3:00 PM' and c2[j][4] != '3:00 PM - 4:30 PM' :
                r1.append(c1[i])
                r1.append(c2[j])
          else :
            r1.append(c1[i])
            r1.append(c2[j])
      if c2[j][1].find('Lab') != -1:
          if c1[i][3].find(c2[j][3]) != -1:
            if c2[j][4] == '8:30 AM - 11:00 AM' :
              if c1[i][4] != '8:30 AM - 10:00 AM' and c1[i][4] != '10:05 AM - 11:35 AM' :
                r1.append(c1[i])
                r1.append(c2[j])
            elif c2[j][4] == '11:00 AM - 1:30 PM' :
              if c1[i][4] != '10:05 AM - 11:35 AM' and c1[i][4] != '11:40 AM - 1:10 PM' :
                r1.append(c1[i])
                r1.append(c2[j])
            elif c2[j][4] == '2:00 PM - 4:30 PM' :
              if c1[i][4] != '1:30 PM - 3:00 PM' and c1[i][4] != '3:00 PM - 4:30 PM' :
                r1.append(c1[i])
                r1.append(c2[j])
          else :
            r1.append(c1[i])
            r1.append(c2[j])
  r5 = r1
  t=0
  r=1
  for i in range(0,len(r5),2):
    print("Suggested Schedule ",r," :")
    print(r5[i],r5[i+1])
    final_routine=[]
    final_routine.append(r5[i])
    final_routine.append( r5[i+1])
    print("Time Gap Of Schedule ",r," :")
    day_count(final_routine)
    t+=1
    r+=1
    print("")

  print("All possible combination = ",all_possible)
  print("Suggested schedule = ",t)
  print("")

  print("")
  print("")
  print("")
  print("Your Preferable Schedule :")
  if m == '1' :
    p=0
    r=1
    for i in range(0,len(r5),2):
      if r5[i][4] != '8:30 AM - 10:00 AM' and  r5[i][4] != '8:30 AM - 11:00 AM':
        if r5[i+1][4] != '8:30 AM - 10:00 AM' and r5[i+1][4] != '8:30 AM - 11:00 AM':
          print("Your Day Class Schedule ",r," :")
          print(r5[i],r5[i+1])
          final_routine=[]
          final_routine.append(r5[i])
          final_routine.append( r5[i+1])
          print("Time Gap Of Day Schedule ",r," :")
          day_count(final_routine)
          print("")
          p+=1
          r+=1
    if p==0:
      print("Sorry No Schedule Available In Day Time")
  if m == '2' :
    p=0
    r=1
    for i in range(0,len(r5),2):
      if r5[i][4] != '2:00 PM - 4:30 PM' and r5[i][4] != '1:30 PM - 3:00 PM' and  r5[i][4] != '3:00 PM - 4:30 PM' :
        if r5[i+1][4] != '2:00 PM - 4:30 PM' and r5[i+1][4] != '1:30 PM - 3:00 PM' and  r5[i+1][4] != '3:00 PM - 4:30 PM' :
          print("Your Morning Class Schedule ",r," :")
          print(r5[i],r5[i+1])
          final_routine=[]
          final_routine.append(r5[i])
          final_routine.append( r5[i+1])
          print("Time Gap Of Morning Schedule ",r," :")
          day_count(final_routine)
          print("")
          p+=1
          r+=1
    if p==0 :
      print("Sorry No Schedule Available In Morning Time")

# %% [markdown]
# # 3 Courses

# %%
if n == '3' :
  selected = []
  for i in range(0,len(np_data)):
    for j in range(len(taken_course)) :
      if np_data[i][0] == taken_course[j] :
        selected.append(np_data[i])

  c1 = []
  c2 = []
  c3 = []
  for i in range (0,len(selected)):
      if selected[i][0] == taken_course[0] :
        c1.append(selected[i])
      elif selected[i][0] == taken_course[1] :
        c2.append(selected[i])
      elif selected[i][0] == taken_course[2] :
        c3.append(selected[i])

  all_possible = len(c1)*len(c2)*len(c3)
  r1 = []
  r2 = []
  #for c1 and c2
  for i in range(0,len(c1)):
    for j in range (0,len(c2)):
      #2 theory
      if c1[i][1].find('Lab') == -1 and c2[j][1].find('Lab') == -1 :
        if c1[i][3] == c2[j][3] :
          if c1[i][4] != c2[j][4]:
            r1.append(c1[i])
            r1.append(c2[j])
        elif  c1[i][3] != c2[j][3]:
          r1.append(c1[i])
          r1.append(c2[j])
      #2 Lab
      if c1[i][1].find('Lab') != -1 and c2[j][1].find('Lab') != -1 :
        if c1[i][3] == c2[j][3] :
          if c1[i][4] != c2[j][4]:
            r1.append(c1[i])
            r1.append(c2[j])
        elif  c1[i][3] != c2[j][3]:
          r1.append(c1[i])
          r1.append(c2[j])
      #1 Theory 1 Lab
      if c1[i][1].find('Lab') != -1 :
          if c2[j][3].find(c1[i][3]) != -1:
            if c1[i][4] == '8:30 AM - 11:00 AM' :
              if c2[j][4] != '8:30 AM - 10:00 AM' and c2[j][4] != '10:05 AM - 11:35 AM' :
                r1.append(c1[i])
                r1.append(c2[j])
            elif c1[i][4] == '11:00 AM - 1:30 PM' :
              if c2[j][4] != '10:05 AM - 11:35 AM' and c2[j][4] != '11:40 AM - 1:10 PM' :
                r1.append(c1[i])
                r1.append(c2[j])
            elif c1[i][4] == '2:00 PM - 4:30 PM' :
              if c2[j][4] != '1:30 PM - 3:00 PM' and c2[j][4] != '3:00 PM - 4:30 PM' :
                r1.append(c1[i])
                r1.append(c2[j])
          else :
            r1.append(c1[i])
            r1.append(c2[j])
      if c2[j][1].find('Lab') != -1:
          if c1[i][3].find(c2[j][3]) != -1:
            if c2[j][4] == '8:30 AM - 11:00 AM' :
              if c1[i][4] != '8:30 AM - 10:00 AM' and c1[i][4] != '10:05 AM - 11:35 AM' :
                r1.append(c1[i])
                r1.append(c2[j])
            elif c2[j][4] == '11:00 AM - 1:30 PM' :
              if c1[i][4] != '10:05 AM - 11:35 AM' and c1[i][4] != '11:40 AM - 1:10 PM' :
                r1.append(c1[i])
                r1.append(c2[j])
            elif c2[j][4] == '2:00 PM - 4:30 PM' :
              if c1[i][4] != '1:30 PM - 3:00 PM' and c1[i][4] != '3:00 PM - 4:30 PM' :
                r1.append(c1[i])
                r1.append(c2[j])
          else :
            r1.append(c1[i])
            r1.append(c2[j])

  r2 = c3
  t=0
  r5=[]
  r=1
  for i in range(0,len(r1),2):
    for j in range(0,len(r2)):
      s=0
      #c1 and C3
      #2 theory
      if r1[i][1].find('Lab') == -1 and r2[j][1].find('Lab') == -1 :
        if r1[i][3] == r2[j][3] :
          if r1[i][4] != r2[j][4]:
            s+=1
        elif  r1[i][3] != r2[j][3]:
          s+=1
      #2 Lab
      elif r1[i][1].find('Lab') != -1 and r2[j][1].find('Lab') != -1 :
        if r1[i][3] == r2[j][3] :
          if r1[i][4] != r2[j][4]:
            s+=1
        elif  r1[i][3] != r2[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r1[i][1].find('Lab') != -1 :
          if r2[j][3].find(r1[i][3]) != -1:
            if r1[i][4] == '8:30 AM - 11:00 AM' :
              if r2[j][4] != '8:30 AM - 10:00 AM' and r2[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r1[i][4] == '11:00 AM - 1:30 PM' :
              if r2[j][4] != '10:05 AM - 11:35 AM' and r2[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r1[i][4] == '2:00 PM - 4:30 PM' :
              if r2[j][4] != '1:30 PM - 3:00 PM' and r2[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r2[j][1].find('Lab') != -1:
          if r1[i][3].find(r2[j][3]) != -1:
            if r2[j][4] == '8:30 AM - 11:00 AM' :
              if r1[i][4] != '8:30 AM - 10:00 AM' and r1[i][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r2[j][4] == '11:00 AM - 1:30 PM' :
              if r1[i][4] != '10:05 AM - 11:35 AM' and r1[i][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r2[j][4] == '2:00 PM - 4:30 PM' :
              if r1[i][4] != '1:30 PM - 3:00 PM' and r1[i][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      #c2 and C3
      #2 theory
      if r1[i+1][1].find('Lab') == -1 and r2[j][1].find('Lab') == -1 :
        if r1[i+1][3] == r2[j][3] :
          if r1[i+1][4] != r2[j][4]:
            s+=1
        elif  r1[i+1][3] != r2[j][3]:
          s+=1
      #2 Lab
      elif r1[i+1][1].find('Lab') != -1 and r2[j][1].find('Lab') != -1 :
        if r1[i+1][3] == r2[j][3] :
          if r1[i+1][4] != r2[j][4]:
            s+=1
        elif  r1[i+1][3] != r2[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r1[i+1][1].find('Lab') != -1 :
          if r2[j][3].find(r1[i+1][3]) != -1:
            if r1[i+1][4] == '8:30 AM - 11:00 AM' :
              if r2[j][4] != '8:30 AM - 10:00 AM' and r2[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r1[i+1][4] == '11:00 AM - 1:30 PM' :
              if r2[j][4] != '10:05 AM - 11:35 AM' and r2[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r1[i+1][4] == '2:00 PM - 4:30 PM' :
              if r2[j][4] != '1:30 PM - 3:00 PM' and r2[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r2[j][1].find('Lab') != -1:
          if r1[i+1][3].find(r2[j][3]) != -1:
            if r2[j][4] == '8:30 AM - 11:00 AM' :
              if r1[i+1][4] != '8:30 AM - 10:00 AM' and r1[i+1][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r2[j][4] == '11:00 AM - 1:30 PM' :
              if r1[i+1][4] != '10:05 AM - 11:35 AM' and r1[i+1][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r2[j][4] == '2:00 PM - 4:30 PM' :
              if r1[i+1][4] != '1:30 PM - 3:00 PM' and r1[i+1][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1

      if s==2 :
        print("Suggested Schedule ",r," :")
        print(r1[i],r1[i+1],r2[j])
        r5.append(r1[i])
        r5.append(r1[i+1])
        r5.append(r2[j])

        final_routine=[]
        final_routine.append(r1[i])
        final_routine.append(r1[i+1])
        final_routine.append(r2[j])
        print("Time Gap Of Schedule ",r," :")
        day_count(final_routine)
        t+=1
        r+=1
        print("")

  print("All possible Schedule = ",all_possible)
  print("Suggested Schedule = ",t)
  print("")

  print("")
  print("")
  print("")
  print("Your Preferable Schedule :")
  if m == '1' :
    p=0
    r=1
    for i in range(0,len(r5),3):
      if r5[i][4] != '8:30 AM - 10:00 AM' and r5[i][4] != '8:30 AM - 11:00 AM':
        if r5[i+1][4] != '8:30 AM - 10:00 AM'  and r5[i+1][4] != '8:30 AM - 11:00 AM':
          if r5[i+2][4] != '8:30 AM - 10:00 AM' and r5[i+2][4] != '8:30 AM - 11:00 AM':
            print("Your Day Class Schedule ",r," :")
            print(r5[i],r5[i+1],r5[i+2])
            final_routine=[]
            final_routine.append(r5[i])
            final_routine.append( r5[i+1])
            final_routine.append( r5[i+2])
            print("Time Gap Of Day Schedule ",r," :")
            day_count(final_routine)
            print("") 
            p+=1
            r+=1
    if p==0:
      print("Sorry No Schedule Available In Day Time")
  if m == '2' :
    p=0
    r=1
    for i in range(0,len(r5),3):
      if r5[i][4] != '2:00 PM - 4:30 PM' and r5[i][4] != '1:30 PM - 3:00 PM' and  r5[i][4] != '3:00 PM - 4:30 PM' :
        if r5[i+1][4] != '2:00 PM - 4:30 PM' and r5[i+1][4] != '1:30 PM - 3:00 PM' and  r5[i+1][4] != '3:00 PM - 4:30 PM' :
          if r5[i+2][4] != '2:00 PM - 4:30 PM' and r5[i+2][4] != '1:30 PM - 3:00 PM' and  r5[i+2][4] != '3:00 PM - 4:30 PM' :
            print("Your Morning Class Schedule ",r," :")
            print(r5[i],r5[i+1],r5[i+2])
            final_routine.append(r5[i])
            final_routine.append( r5[i+1])
            final_routine.append( r5[i+2])
            print("Time Gap Of Morning Schedule ",r," :")
            day_count(final_routine)
            print("")
            p+=1
            r+=1
    if p==0 :
      print("Sorry No Schedule Available In Morning Time")

# %% [markdown]
# # 4 Courses

# %%
if n == '4' :
  selected = []
  for i in range(0,len(np_data)):
    for j in range(len(taken_course)) :
      if np_data[i][0] == taken_course[j] :
        selected.append(np_data[i])

  c1 = []
  c2 = []
  c3 = []
  c4 = []
  for i in range (0,len(selected)):
      if selected[i][0] == taken_course[0] :
        c1.append(selected[i])
      elif selected[i][0] == taken_course[1] :
        c2.append(selected[i])
      elif selected[i][0] == taken_course[2] :
        c3.append(selected[i])
      elif selected[i][0] == taken_course[3] :
        c4.append(selected[i])

  all_possible = len(c1)*len(c2)*len(c3)*len(c4)
  r1 = []
  r2 = []
  #for c1 and c2
  for i in range(0,len(c1)):
    for j in range (0,len(c2)):
      #2 theory
      if c1[i][1].find('Lab') == -1 and c2[j][1].find('Lab') == -1 :
        if c1[i][3] == c2[j][3] :
          if c1[i][4] != c2[j][4]:
            r1.append(c1[i])
            r1.append(c2[j])
        elif  c1[i][3] != c2[j][3]:
          r1.append(c1[i])
          r1.append(c2[j])
      #2 Lab
      if c1[i][1].find('Lab') != -1 and c2[j][1].find('Lab') != -1 :
        if c1[i][3] == c2[j][3] :
          if c1[i][4] != c2[j][4]:
            r1.append(c1[i])
            r1.append(c2[j])
        elif  c1[i][3] != c2[j][3]:
          r1.append(c1[i])
          r1.append(c2[j])
      #1 Theory 1 Lab
      if c1[i][1].find('Lab') != -1 :
          if c2[j][3].find(c1[i][3]) != -1:
            if c1[i][4] == '8:30 AM - 11:00 AM' :
              if c2[j][4] != '8:30 AM - 10:00 AM' and c2[j][4] != '10:05 AM - 11:35 AM' :
                r1.append(c1[i])
                r1.append(c2[j])
            elif c1[i][4] == '11:00 AM - 1:30 PM' :
              if c2[j][4] != '10:05 AM - 11:35 AM' and c2[j][4] != '11:40 AM - 1:10 PM' :
                r1.append(c1[i])
                r1.append(c2[j])
            elif c1[i][4] == '2:00 PM - 4:30 PM' :
              if c2[j][4] != '1:30 PM - 3:00 PM' and c2[j][4] != '3:00 PM - 4:30 PM' :
                r1.append(c1[i])
                r1.append(c2[j])
          else :
            r1.append(c1[i])
            r1.append(c2[j])
      if c2[j][1].find('Lab') != -1:
          if c1[i][3].find(c2[j][3]) != -1:
            if c2[j][4] == '8:30 AM - 11:00 AM' :
              if c1[i][4] != '8:30 AM - 10:00 AM' and c1[i][4] != '10:05 AM - 11:35 AM' :
                r1.append(c1[i])
                r1.append(c2[j])
            elif c2[j][4] == '11:00 AM - 1:30 PM' :
              if c1[i][4] != '10:05 AM - 11:35 AM' and c1[i][4] != '11:40 AM - 1:10 PM' :
                r1.append(c1[i])
                r1.append(c2[j])
            elif c2[j][4] == '2:00 PM - 4:30 PM' :
              if c1[i][4] != '1:30 PM - 3:00 PM' and c1[i][4] != '3:00 PM - 4:30 PM' :
                r1.append(c1[i])
                r1.append(c2[j])
          else :
            r1.append(c1[i])
            r1.append(c2[j])

  r2 = c3
  r3 = []
  for i in range(0,len(r1),2):
    for j in range(0,len(r2)):
      s=0
      #c1 and C3
      #2 theory
      if r1[i][1].find('Lab') == -1 and r2[j][1].find('Lab') == -1 :
        if r1[i][3] == r2[j][3] :
          if r1[i][4] != r2[j][4]:
            s+=1
        elif  r1[i][3] != r2[j][3]:
          s+=1
      #2 Lab
      elif r1[i][1].find('Lab') != -1 and r2[j][1].find('Lab') != -1 :
        if r1[i][3] == r2[j][3] :
          if r1[i][4] != r2[j][4]:
            s+=1
        elif  r1[i][3] != r2[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r1[i][1].find('Lab') != -1 :
          if r2[j][3].find(r1[i][3]) != -1:
            if r1[i][4] == '8:30 AM - 11:00 AM' :
              if r2[j][4] != '8:30 AM - 10:00 AM' and r2[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r1[i][4] == '11:00 AM - 1:30 PM' :
              if r2[j][4] != '10:05 AM - 11:35 AM' and r2[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r1[i][4] == '2:00 PM - 4:30 PM' :
              if r2[j][4] != '1:30 PM - 3:00 PM' and r2[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r2[j][1].find('Lab') != -1:
          if r1[i][3].find(r2[j][3]) != -1:
            if r2[j][4] == '8:30 AM - 11:00 AM' :
              if r1[i][4] != '8:30 AM - 10:00 AM' and r1[i][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r2[j][4] == '11:00 AM - 1:30 PM' :
              if r1[i][4] != '10:05 AM - 11:35 AM' and r1[i][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r2[j][4] == '2:00 PM - 4:30 PM' :
              if r1[i][4] != '1:30 PM - 3:00 PM' and r1[i][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      #c2 and C3
      #2 theory
      if r1[i+1][1].find('Lab') == -1 and r2[j][1].find('Lab') == -1 :
        if r1[i+1][3] == r2[j][3] :
          if r1[i+1][4] != r2[j][4]:
            s+=1
        elif  r1[i+1][3] != r2[j][3]:
          s+=1
      #2 Lab
      elif r1[i+1][1].find('Lab') != -1 and r2[j][1].find('Lab') != -1 :
        if r1[i+1][3] == r2[j][3] :
          if r1[i+1][4] != r2[j][4]:
            s+=1
        elif  r1[i+1][3] != r2[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r1[i+1][1].find('Lab') != -1 :
          if r2[j][3].find(r1[i+1][3]) != -1:
            if r1[i+1][4] == '8:30 AM - 11:00 AM' :
              if r2[j][4] != '8:30 AM - 10:00 AM' and r2[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r1[i+1][4] == '11:00 AM - 1:30 PM' :
              if r2[j][4] != '10:05 AM - 11:35 AM' and r2[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r1[i+1][4] == '2:00 PM - 4:30 PM' :
              if r2[j][4] != '1:30 PM - 3:00 PM' and r2[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r2[j][1].find('Lab') != -1:
          if r1[i+1][3].find(r2[j][3]) != -1:
            if r2[j][4] == '8:30 AM - 11:00 AM' :
              if r1[i+1][4] != '8:30 AM - 10:00 AM' and r1[i+1][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r2[j][4] == '11:00 AM - 1:30 PM' :
              if r1[i+1][4] != '10:05 AM - 11:35 AM' and r1[i+1][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r2[j][4] == '2:00 PM - 4:30 PM' :
              if r1[i+1][4] != '1:30 PM - 3:00 PM' and r1[i+1][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1

      if s==2 :
        r3.append(r1[i])
        r3.append(r1[i+1])
        r3.append(r2[j])

  r4 = c4
  t=0
  r5 = []
  r=1
  print("Suggested Schedule :")
  for i in range(0,len(r3),3):
    for j in range(0,len(r4)):
      s=0
      #course c1 and c4
      #2 theory
      if r3[i][1].find('Lab') == -1 and r4[j][1].find('Lab') == -1 :
        if r3[i][3] == r4[j][3] :
          if r3[i][4] != r4[j][4]:
            s+=1
        elif  r3[i][3] != r4[j][3]:
          s+=1
      #2 Lab
      elif r3[i][1].find('Lab') != -1 and r4[j][1].find('Lab') != -1 :
        if r3[i][3] == r4[j][3] :
          if r3[i][4] != r4[j][4]:
            s+=1
        elif  r3[i][3] != r4[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r3[i][1].find('Lab') != -1 and r4[j][1].find('Lab') == -1:
          if r4[j][3].find(r3[i][3]) != -1:
            if r3[i][4] == '8:30 AM - 11:00 AM' :
              if r4[j][4] != '8:30 AM - 10:00 AM' and r4[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r3[i][4] == '11:00 AM - 1:30 PM' :
              if r4[j][4] != '10:05 AM - 11:35 AM' and r4[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r3[i][4] == '2:00 PM - 4:30 PM' :
              if r4[j][4] != '1:30 PM - 3:00 PM' and r4[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r4[j][1].find('Lab') != -1 and r3[i][1].find('Lab') == -1:
          if r3[i][3].find(r4[j][3]) != -1:
            if r4[j][4] == '8:30 AM - 11:00 AM' :
              if r3[i][4] != '8:30 AM - 10:00 AM' and r3[i][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r4[j][4] == '11:00 AM - 1:30 PM' :
              if r3[i][4] != '10:05 AM - 11:35 AM' and r3[i][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r4[j][4] == '2:00 PM - 4:30 PM' :
              if r3[i][4] != '1:30 PM - 3:00 PM' and r3[i][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      #course c2 and c4
      #2 theory
      if r3[i+1][1].find('Lab') == -1 and r4[j][1].find('Lab') == -1 :
        if r3[i+1][3] == r4[j][3] :
          if r3[i+1][4] != r4[j][4]:
            s+=1
        elif  r3[i+1][3] != r4[j][3]:
          s+=1
      #2 Lab
      elif r3[i+1][1].find('Lab') != -1 and r4[j][1].find('Lab') != -1 :
        if r3[i+1][3] == r4[j][3] :
          if r3[i+1][4] != r4[j][4]:
            s+=1
        elif  r3[i+1][3] != r4[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r3[i+1][1].find('Lab') != -1 and r4[j][1].find('Lab') == -1:
          if r4[j][3].find(r3[i+1][3]) != -1:
            if r3[i+1][4] == '8:30 AM - 11:00 AM' :
              if r4[j][4] != '8:30 AM - 10:00 AM' and r4[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r3[i+1][4] == '11:00 AM - 1:30 PM' :
              if r4[j][4] != '10:05 AM - 11:35 AM' and r4[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r3[i+1][4] == '2:00 PM - 4:30 PM' :
              if r4[j][4] != '1:30 PM - 3:00 PM' and r4[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r4[j][1].find('Lab') != -1:
          if r3[i+1][3].find(r4[j][3]) != -1 and r3[i+1][1].find('Lab') == -1:
            if r4[j][4] == '8:30 AM - 11:00 AM' :
              if r3[i+1][4] != '8:30 AM - 10:00 AM' and r3[i+1][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r4[j][4] == '11:00 AM - 1:30 PM' :
              if r3[i+1][4] != '10:05 AM - 11:35 AM' and r3[i+1][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r4[j][4] == '2:00 PM - 4:30 PM' :
              if r3[i+1][4] != '1:30 PM - 3:00 PM' and r3[i+1][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      #course c3 and c4
      #2 theory
      if r3[i+2][1].find('Lab') == -1 and r4[j][1].find('Lab') == -1 :
        if r3[i+2][3] == r4[j][3] :
          if r3[i+2][4] != r4[j][4]:
            s+=1
        elif  r3[i+2][3] != r4[j][3]:
          s+=1
      #2 Lab
      elif r3[i+2][1].find('Lab') != -1 and r4[j][1].find('Lab') != -1 :
        if r3[i+2][3] == r4[j][3] :
          if r3[i+2][4] != r4[j][4]:
            s+=1
        elif  r3[i+2][3] != r4[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r3[i+2][1].find('Lab') != -1 and r4[j][1].find('Lab') == -1 :
          if r4[j][3].find(r3[i+2][3]) != -1:
            if r3[i+2][4] == '8:30 AM - 11:00 AM' :
              if r4[j][4] != '8:30 AM - 10:00 AM' and r4[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r3[i+2][4] == '11:00 AM - 1:30 PM' :
              if r4[j][4] != '10:05 AM - 11:35 AM' and r4[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r3[i+2][4] == '2:00 PM - 4:30 PM' :
              if r4[j][4] != '1:30 PM - 3:00 PM' and r4[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r4[j][1].find('Lab') != -1 and r3[i+2][1].find('Lab') == -1:
          if r3[i+2][3].find(r4[j][3]) != -1:
            if r4[j][4] == '8:30 AM - 11:00 AM' :
              if r3[i+2][4] != '8:30 AM - 10:00 AM' and r3[i+2][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r4[j][4] == '11:00 AM - 1:30 PM' :
              if r3[i+2][4] != '10:05 AM - 11:35 AM' and r3[i+2][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r4[j][4] == '2:00 PM - 4:30 PM' :
              if r3[i+2][4] != '1:30 PM - 3:00 PM' and r3[i+2][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1

      if s==3 :
        print("Suggested Schedule ",r," :")
        print(r3[i],r3[i+1],r3[i+2],r4[j])
        r5.append(r3[i])
        r5.append(r3[i+1])
        r5.append(r3[i+2])
        r5.append(r4[j])

        final_routine=[]
        final_routine.append(r3[i])
        final_routine.append(r3[i+1])
        final_routine.append(r3[i+2])
        final_routine.append(r4[j])
        print("Time Gap Of Schedule ",r," :")
        day_count(final_routine)
        t+=1
        r+=1
        print("")

  print("All Posible Schedule = ",all_possible)
  print("Suggested Schedule = ",t)
  print("")

  print("")
  print("")
  print("")
  print("Your Preferable Schedule :")
  if m == '1' :
    p=0
    r=1
    for i in range(0,len(r5),4):
      if r5[i][4] != '8:30 AM - 10:00 AM' and r5[i][4] != '8:30 AM - 11:00 AM':
        if r5[i+1][4] != '8:30 AM - 10:00 AM'  and r5[i+1][4] != '8:30 AM - 11:00 AM':
          if r5[i+2][4] != '8:30 AM - 10:00 AM' and r5[i+2][4] != '8:30 AM - 11:00 AM':
            if r5[i+3][4] != '8:30 AM - 10:00 AM' and r5[i+3][4] != '8:30 AM - 11:00 AM':
              print("Your Day Class Schedule ",r," :")
              print(r5[i],r5[i+1],r5[i+2],r5[i+3])
              final_routine=[]
              final_routine.append(r5[i])
              final_routine.append(r5[i+1])
              final_routine.append(r5[i+2])
              final_routine.append(r5[i+3])
              print("Time Gap Of Day Schedule ",r," :")
              day_count(final_routine)
              print("") 
              p+=1
              r+=1
    if p==0:
      print("Sorry No Schedule Available In Day Time")
  if m == '2' :
    p=0
    r=1
    for i in range(0,len(r5),4):
      if r5[i][4] != '2:00 PM - 4:30 PM' and r5[i][4] != '1:30 PM - 3:00 PM' and  r5[i][4] != '3:00 PM - 4:30 PM' :
        if r5[i+1][4] != '2:00 PM - 4:30 PM' and r5[i+1][4] != '1:30 PM - 3:00 PM' and  r5[i+1][4] != '3:00 PM - 4:30 PM' :
          if r5[i+2][4] != '2:00 PM - 4:30 PM' and r5[i+2][4] != '1:30 PM - 3:00 PM' and  r5[i+2][4] != '3:00 PM - 4:30 PM' :
            if r5[i+3][4] != '2:00 PM - 4:30 PM' and r5[i+3][4] != '1:30 PM - 3:00 PM' and  r5[i+3][4] != '3:00 PM - 4:30 PM' :
              print("Your Morning Class Schedule ",r," :")
              print(r5[i],r5[i+1],r5[i+2],r5[i+3])
              final_routine=[]
              final_routine.append(r5[i])
              final_routine.append(r5[i+1])
              final_routine.append(r5[i+2])
              final_routine.append(r5[i+3])
              print("Time Gap Of Day Schedule ",r," :")
              day_count(final_routine)
              print("")
              p+=1
              r+=1
    if p==0 :
      print("Sorry No Schedule Available In Morning Time")

# %% [markdown]
# # 5 Courses

# %%
if n == '5' :
  selected = []
  for i in range(0,len(np_data)):
    for j in range(len(taken_course)) :
      if np_data[i][0] == taken_course[j] :
        selected.append(np_data[i])

  c1 = []
  c2 = []
  c3 = []
  c4 = []
  c5 = []
  for i in range (0,len(selected)):
      if selected[i][0] == taken_course[0] :
        c1.append(selected[i])
      elif selected[i][0] == taken_course[1] :
        c2.append(selected[i])
      elif selected[i][0] == taken_course[2] :
        c3.append(selected[i])
      elif selected[i][0] == taken_course[3] :
        c4.append(selected[i])
      elif selected[i][0] == taken_course[4] :
        c5.append(selected[i])

  all_possible = len(c1)*len(c2)*len(c3)*len(c4)*len(c5)
  r1 = []
  r2 = []
  #for c1 and c2
  for i in range(0,len(c1)):
    for j in range (0,len(c2)):
      #2 theory
      if c1[i][1].find('Lab') == -1 and c2[j][1].find('Lab') == -1 :
        if c1[i][3] == c2[j][3] :
          if c1[i][4] != c2[j][4]:
            r1.append(c1[i])
            r1.append(c2[j])
        elif  c1[i][3] != c2[j][3]:
          r1.append(c1[i])
          r1.append(c2[j])
      #2 Lab
      if c1[i][1].find('Lab') != -1 and c2[j][1].find('Lab') != -1 :
        if c1[i][3] == c2[j][3] :
          if c1[i][4] != c2[j][4]:
            r1.append(c1[i])
            r1.append(c2[j])
        elif  c1[i][3] != c2[j][3]:
          r1.append(c1[i])
          r1.append(c2[j])
      #1 Theory 1 Lab
      if c1[i][1].find('Lab') != -1 :
          if c2[j][3].find(c1[i][3]) != -1:
            if c1[i][4] == '8:30 AM - 11:00 AM' :
              if c2[j][4] != '8:30 AM - 10:00 AM' and c2[j][4] != '10:05 AM - 11:35 AM' :
                r1.append(c1[i])
                r1.append(c2[j])
            elif c1[i][4] == '11:00 AM - 1:30 PM' :
              if c2[j][4] != '10:05 AM - 11:35 AM' and c2[j][4] != '11:40 AM - 1:10 PM' :
                r1.append(c1[i])
                r1.append(c2[j])
            elif c1[i][4] == '2:00 PM - 4:30 PM' :
              if c2[j][4] != '1:30 PM - 3:00 PM' and c2[j][4] != '3:00 PM - 4:30 PM' :
                r1.append(c1[i])
                r1.append(c2[j])
          else :
            r1.append(c1[i])
            r1.append(c2[j])
      if c2[j][1].find('Lab') != -1:
          if c1[i][3].find(c2[j][3]) != -1:
            if c2[j][4] == '8:30 AM - 11:00 AM' :
              if c1[i][4] != '8:30 AM - 10:00 AM' and c1[i][4] != '10:05 AM - 11:35 AM' :
                r1.append(c1[i])
                r1.append(c2[j])
            elif c2[j][4] == '11:00 AM - 1:30 PM' :
              if c1[i][4] != '10:05 AM - 11:35 AM' and c1[i][4] != '11:40 AM - 1:10 PM' :
                r1.append(c1[i])
                r1.append(c2[j])
            elif c2[j][4] == '2:00 PM - 4:30 PM' :
              if c1[i][4] != '1:30 PM - 3:00 PM' and c1[i][4] != '3:00 PM - 4:30 PM' :
                r1.append(c1[i])
                r1.append(c2[j])
          else :
            r1.append(c1[i])
            r1.append(c2[j])

  r2 = c3
  r3 = []
  for i in range(0,len(r1),2):
    for j in range(0,len(r2)):
      s=0
      #c1 and C3
      #2 theory
      if r1[i][1].find('Lab') == -1 and r2[j][1].find('Lab') == -1 :
        if r1[i][3] == r2[j][3] :
          if r1[i][4] != r2[j][4]:
            s+=1
        elif  r1[i][3] != r2[j][3]:
          s+=1
      #2 Lab
      elif r1[i][1].find('Lab') != -1 and r2[j][1].find('Lab') != -1 :
        if r1[i][3] == r2[j][3] :
          if r1[i][4] != r2[j][4]:
            s+=1
        elif  r1[i][3] != r2[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r1[i][1].find('Lab') != -1 :
          if r2[j][3].find(r1[i][3]) != -1:
            if r1[i][4] == '8:30 AM - 11:00 AM' :
              if r2[j][4] != '8:30 AM - 10:00 AM' and r2[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r1[i][4] == '11:00 AM - 1:30 PM' :
              if r2[j][4] != '10:05 AM - 11:35 AM' and r2[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r1[i][4] == '2:00 PM - 4:30 PM' :
              if r2[j][4] != '1:30 PM - 3:00 PM' and r2[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r2[j][1].find('Lab') != -1:
          if r1[i][3].find(r2[j][3]) != -1:
            if r2[j][4] == '8:30 AM - 11:00 AM' :
              if r1[i][4] != '8:30 AM - 10:00 AM' and r1[i][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r2[j][4] == '11:00 AM - 1:30 PM' :
              if r1[i][4] != '10:05 AM - 11:35 AM' and r1[i][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r2[j][4] == '2:00 PM - 4:30 PM' :
              if r1[i][4] != '1:30 PM - 3:00 PM' and r1[i][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      #c2 and C3
      #2 theory
      if r1[i+1][1].find('Lab') == -1 and r2[j][1].find('Lab') == -1 :
        if r1[i+1][3] == r2[j][3] :
          if r1[i+1][4] != r2[j][4]:
            s+=1
        elif  r1[i+1][3] != r2[j][3]:
          s+=1
      #2 Lab
      elif r1[i+1][1].find('Lab') != -1 and r2[j][1].find('Lab') != -1 :
        if r1[i+1][3] == r2[j][3] :
          if r1[i+1][4] != r2[j][4]:
            s+=1
        elif  r1[i+1][3] != r2[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r1[i+1][1].find('Lab') != -1 :
          if r2[j][3].find(r1[i+1][3]) != -1:
            if r1[i+1][4] == '8:30 AM - 11:00 AM' :
              if r2[j][4] != '8:30 AM - 10:00 AM' and r2[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r1[i+1][4] == '11:00 AM - 1:30 PM' :
              if r2[j][4] != '10:05 AM - 11:35 AM' and r2[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r1[i+1][4] == '2:00 PM - 4:30 PM' :
              if r2[j][4] != '1:30 PM - 3:00 PM' and r2[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r2[j][1].find('Lab') != -1:
          if r1[i+1][3].find(r2[j][3]) != -1:
            if r2[j][4] == '8:30 AM - 11:00 AM' :
              if r1[i+1][4] != '8:30 AM - 10:00 AM' and r1[i+1][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r2[j][4] == '11:00 AM - 1:30 PM' :
              if r1[i+1][4] != '10:05 AM - 11:35 AM' and r1[i+1][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r2[j][4] == '2:00 PM - 4:30 PM' :
              if r1[i+1][4] != '1:30 PM - 3:00 PM' and r1[i+1][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1

      if s==2 :
        r3.append(r1[i])
        r3.append(r1[i+1])
        r3.append(r2[j])

  r4 = c4
  r5 = []
  for i in range(0,len(r3),3):
    for j in range(0,len(r4)):
      s=0
      #course c1 and c4
      #2 theory
      if r3[i][1].find('Lab') == -1 and r4[j][1].find('Lab') == -1 :
        if r3[i][3] == r4[j][3] :
          if r3[i][4] != r4[j][4]:
            s+=1
        elif  r3[i][3] != r4[j][3]:
          s+=1
      #2 Lab
      elif r3[i][1].find('Lab') != -1 and r4[j][1].find('Lab') != -1 :
        if r3[i][3] == r4[j][3] :
          if r3[i][4] != r4[j][4]:
            s+=1
        elif  r3[i][3] != r4[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r3[i][1].find('Lab') != -1 and r4[j][1].find('Lab') == -1:
          if r4[j][3].find(r3[i][3]) != -1:
            if r3[i][4] == '8:30 AM - 11:00 AM' :
              if r4[j][4] != '8:30 AM - 10:00 AM' and r4[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r3[i][4] == '11:00 AM - 1:30 PM' :
              if r4[j][4] != '10:05 AM - 11:35 AM' and r4[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r3[i][4] == '2:00 PM - 4:30 PM' :
              if r4[j][4] != '1:30 PM - 3:00 PM' and r4[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r4[j][1].find('Lab') != -1 and r3[i][1].find('Lab') == -1:
          if r3[i][3].find(r4[j][3]) != -1:
            if r4[j][4] == '8:30 AM - 11:00 AM' :
              if r3[i][4] != '8:30 AM - 10:00 AM' and r3[i][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r4[j][4] == '11:00 AM - 1:30 PM' :
              if r3[i][4] != '10:05 AM - 11:35 AM' and r3[i][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r4[j][4] == '2:00 PM - 4:30 PM' :
              if r3[i][4] != '1:30 PM - 3:00 PM' and r3[i][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      #course c2 and c4
      #2 theory
      if r3[i+1][1].find('Lab') == -1 and r4[j][1].find('Lab') == -1 :
        if r3[i+1][3] == r4[j][3] :
          if r3[i+1][4] != r4[j][4]:
            s+=1
        elif  r3[i+1][3] != r4[j][3]:
          s+=1
      #2 Lab
      elif r3[i+1][1].find('Lab') != -1 and r4[j][1].find('Lab') != -1 :
        if r3[i+1][3] == r4[j][3] :
          if r3[i+1][4] != r4[j][4]:
            s+=1
        elif  r3[i+1][3] != r4[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r3[i+1][1].find('Lab') != -1 and r4[j][1].find('Lab') == -1:
          if r4[j][3].find(r3[i+1][3]) != -1:
            if r3[i+1][4] == '8:30 AM - 11:00 AM' :
              if r4[j][4] != '8:30 AM - 10:00 AM' and r4[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r3[i+1][4] == '11:00 AM - 1:30 PM' :
              if r4[j][4] != '10:05 AM - 11:35 AM' and r4[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r3[i+1][4] == '2:00 PM - 4:30 PM' :
              if r4[j][4] != '1:30 PM - 3:00 PM' and r4[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r4[j][1].find('Lab') != -1:
          if r3[i+1][3].find(r4[j][3]) != -1 and r3[i+1][1].find('Lab') == -1:
            if r4[j][4] == '8:30 AM - 11:00 AM' :
              if r3[i+1][4] != '8:30 AM - 10:00 AM' and r3[i+1][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r4[j][4] == '11:00 AM - 1:30 PM' :
              if r3[i+1][4] != '10:05 AM - 11:35 AM' and r3[i+1][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r4[j][4] == '2:00 PM - 4:30 PM' :
              if r3[i+1][4] != '1:30 PM - 3:00 PM' and r3[i+1][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      #course c3 and c4
      #2 theory
      if r3[i+2][1].find('Lab') == -1 and r4[j][1].find('Lab') == -1 :
        if r3[i+2][3] == r4[j][3] :
          if r3[i+2][4] != r4[j][4]:
            s+=1
        elif  r3[i+2][3] != r4[j][3]:
          s+=1
      #2 Lab
      elif r3[i+2][1].find('Lab') != -1 and r4[j][1].find('Lab') != -1 :
        if r3[i+2][3] == r4[j][3] :
          if r3[i+2][4] != r4[j][4]:
            s+=1
        elif  r3[i+2][3] != r4[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r3[i+2][1].find('Lab') != -1 and r4[j][1].find('Lab') == -1 :
          if r4[j][3].find(r3[i+2][3]) != -1:
            if r3[i+2][4] == '8:30 AM - 11:00 AM' :
              if r4[j][4] != '8:30 AM - 10:00 AM' and r4[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r3[i+2][4] == '11:00 AM - 1:30 PM' :
              if r4[j][4] != '10:05 AM - 11:35 AM' and r4[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r3[i+2][4] == '2:00 PM - 4:30 PM' :
              if r4[j][4] != '1:30 PM - 3:00 PM' and r4[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r4[j][1].find('Lab') != -1 and r3[i+2][1].find('Lab') == -1:
          if r3[i+2][3].find(r4[j][3]) != -1:
            if r4[j][4] == '8:30 AM - 11:00 AM' :
              if r3[i+2][4] != '8:30 AM - 10:00 AM' and r3[i+2][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r4[j][4] == '11:00 AM - 1:30 PM' :
              if r3[i+2][4] != '10:05 AM - 11:35 AM' and r3[i+2][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r4[j][4] == '2:00 PM - 4:30 PM' :
              if r3[i+2][4] != '1:30 PM - 3:00 PM' and r3[i+2][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1

      if s==3 :
        r5.append(r3[i])
        r5.append(r3[i+1])
        r5.append(r3[i+2])
        r5.append(r4[j])

  r=1
  r3 = r5
  r4 = c5
  t=0
  r5 = []
  print("Suggested Schedule :")
  for i in range(0,len(r3),4):
    for j in range(0,len(r4)):
      s=0
      #course c1 and c5
      #2 theory
      if r3[i][1].find('Lab') == -1 and r4[j][1].find('Lab') == -1 :
        if r3[i][3] == r4[j][3] :
          if r3[i][4] != r4[j][4]:
            s+=1
        elif  r3[i][3] != r4[j][3]:
          s+=1
      #2 Lab
      elif r3[i][1].find('Lab') != -1 and r4[j][1].find('Lab') != -1 :
        if r3[i][3] == r4[j][3] :
          if r3[i][4] != r4[j][4]:
            s+=1
        elif  r3[i][3] != r4[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r3[i][1].find('Lab') != -1 and r4[j][1].find('Lab') == -1:
          if r4[j][3].find(r3[i][3]) != -1:
            if r3[i][4] == '8:30 AM - 11:00 AM' :
              if r4[j][4] != '8:30 AM - 10:00 AM' and r4[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r3[i][4] == '11:00 AM - 1:30 PM' :
              if r4[j][4] != '10:05 AM - 11:35 AM' and r4[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r3[i][4] == '2:00 PM - 4:30 PM' :
              if r4[j][4] != '1:30 PM - 3:00 PM' and r4[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r4[j][1].find('Lab') != -1 and r3[i][1].find('Lab') == -1:
          if r3[i][3].find(r4[j][3]) != -1:
            if r4[j][4] == '8:30 AM - 11:00 AM' :
              if r3[i][4] != '8:30 AM - 10:00 AM' and r3[i][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r4[j][4] == '11:00 AM - 1:30 PM' :
              if r3[i][4] != '10:05 AM - 11:35 AM' and r3[i][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r4[j][4] == '2:00 PM - 4:30 PM' :
              if r3[i][4] != '1:30 PM - 3:00 PM' and r3[i][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      #course c2 and c5
      #2 theory
      if r3[i+1][1].find('Lab') == -1 and r4[j][1].find('Lab') == -1 :
        if r3[i+1][3] == r4[j][3] :
          if r3[i+1][4] != r4[j][4]:
            s+=1
        elif  r3[i+1][3] != r4[j][3]:
          s+=1
      #2 Lab
      elif r3[i+1][1].find('Lab') != -1 and r4[j][1].find('Lab') != -1 :
        if r3[i+1][3] == r4[j][3] :
          if r3[i+1][4] != r4[j][4]:
            s+=1
        elif  r3[i+1][3] != r4[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r3[i+1][1].find('Lab') != -1 and r4[j][1].find('Lab') == -1:
          if r4[j][3].find(r3[i+1][3]) != -1:
            if r3[i+1][4] == '8:30 AM - 11:00 AM' :
              if r4[j][4] != '8:30 AM - 10:00 AM' and r4[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r3[i+1][4] == '11:00 AM - 1:30 PM' :
              if r4[j][4] != '10:05 AM - 11:35 AM' and r4[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r3[i+1][4] == '2:00 PM - 4:30 PM' :
              if r4[j][4] != '1:30 PM - 3:00 PM' and r4[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r4[j][1].find('Lab') != -1:
          if r3[i+1][3].find(r4[j][3]) != -1 and r3[i+1][1].find('Lab') == -1:
            if r4[j][4] == '8:30 AM - 11:00 AM' :
              if r3[i+1][4] != '8:30 AM - 10:00 AM' and r3[i+1][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r4[j][4] == '11:00 AM - 1:30 PM' :
              if r3[i+1][4] != '10:05 AM - 11:35 AM' and r3[i+1][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r4[j][4] == '2:00 PM - 4:30 PM' :
              if r3[i+1][4] != '1:30 PM - 3:00 PM' and r3[i+1][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      #course c3 and c5
      #2 theory
      if r3[i+2][1].find('Lab') == -1 and r4[j][1].find('Lab') == -1 :
        if r3[i+2][3] == r4[j][3] :
          if r3[i+2][4] != r4[j][4]:
            s+=1
        elif  r3[i+2][3] != r4[j][3]:
          s+=1
      #2 Lab
      elif r3[i+2][1].find('Lab') != -1 and r4[j][1].find('Lab') != -1 :
        if r3[i+2][3] == r4[j][3] :
          if r3[i+2][4] != r4[j][4]:
            s+=1
        elif  r3[i+2][3] != r4[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r3[i+2][1].find('Lab') != -1 and r4[j][1].find('Lab') == -1 :
          if r4[j][3].find(r3[i+2][3]) != -1:
            if r3[i+2][4] == '8:30 AM - 11:00 AM' :
              if r4[j][4] != '8:30 AM - 10:00 AM' and r4[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r3[i+2][4] == '11:00 AM - 1:30 PM' :
              if r4[j][4] != '10:05 AM - 11:35 AM' and r4[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r3[i+2][4] == '2:00 PM - 4:30 PM' :
              if r4[j][4] != '1:30 PM - 3:00 PM' and r4[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r4[j][1].find('Lab') != -1 and r3[i+2][1].find('Lab') == -1:
          if r3[i+2][3].find(r4[j][3]) != -1:
            if r4[j][4] == '8:30 AM - 11:00 AM' :
              if r3[i+2][4] != '8:30 AM - 10:00 AM' and r3[i+2][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r4[j][4] == '11:00 AM - 1:30 PM' :
              if r3[i+2][4] != '10:05 AM - 11:35 AM' and r3[i+2][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r4[j][4] == '2:00 PM - 4:30 PM' :
              if r3[i+2][4] != '1:30 PM - 3:00 PM' and r3[i+2][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      #course c4 and c5
      #2 theory
      if r3[i+3][1].find('Lab') == -1 and r4[j][1].find('Lab') == -1 :
        if r3[i+3][3] == r4[j][3] :
          if r3[i+3][4] != r4[j][4]:
            s+=1
        elif  r3[i+3][3] != r4[j][3]:
          s+=1
      #2 Lab
      elif r3[i+3][1].find('Lab') != -1 and r4[j][1].find('Lab') != -1 :
        if r3[i+3][3] == r4[j][3] :
          if r3[i+3][4] != r4[j][4]:
            s+=1
        elif  r3[i+3][3] != r4[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r3[i+3][1].find('Lab') != -1 and r4[j][1].find('Lab') == -1 :
          if r4[j][3].find(r3[i+3][3]) != -1:
            if r3[i+3][4] == '8:30 AM - 11:00 AM' :
              if r4[j][4] != '8:30 AM - 10:00 AM' and r4[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r3[i+3][4] == '11:00 AM - 1:30 PM' :
              if r4[j][4] != '10:05 AM - 11:35 AM' and r4[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r3[i+3][4] == '2:00 PM - 4:30 PM' :
              if r4[j][4] != '1:30 PM - 3:00 PM' and r4[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r4[j][1].find('Lab') != -1 and r3[i+3][1].find('Lab') == -1:
          if r3[i+3][3].find(r4[j][3]) != -1:
            if r4[j][4] == '8:30 AM - 11:00 AM' :
              if r3[i+3][4] != '8:30 AM - 10:00 AM' and r3[i+3][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r4[j][4] == '11:00 AM - 1:30 PM' :
              if r3[i+3][4] != '10:05 AM - 11:35 AM' and r3[i+3][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r4[j][4] == '2:00 PM - 4:30 PM' :
              if r3[i+3][4] != '1:30 PM - 3:00 PM' and r3[i+3][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1

      if s==4 :
        print("Suggested Schedule ",r," :")
        print(r3[i],r3[i+1],r3[i+2],r3[i+3],r4[j])
        r5.append(r3[i])
        r5.append(r3[i+1])
        r5.append(r3[i+2])
        r5.append(r3[i+3])
        r5.append(r4[j])

        final_routine=[]
        print("Time Gap Of Schedule ",r," :")
        final_routine.append(r3[i])
        final_routine.append( r3[i+1])
        final_routine.append( r3[i+2])
        final_routine.append( r3[i+3])
        final_routine.append(r4[j])
        day_count(final_routine)

        t+=1
        r+=1
        print("")

  print("All Posible Schedule = ",all_possible)
  print("Suggested Schedule = ",t)
  print("")

  print("")
  print("")
  print("")
  print("Your Preferable Schedule :")
  if m == '1' :
    p=0
    r=1
    for i in range(0,len(r5),5):
      if r5[i][4] != '8:30 AM - 10:00 AM' and r5[i][4] != '8:30 AM - 11:00 AM':
        if r5[i+1][4] != '8:30 AM - 10:00 AM'  and r5[i+1][4] != '8:30 AM - 11:00 AM':
          if r5[i+2][4] != '8:30 AM - 10:00 AM' and r5[i+2][4] != '8:30 AM - 11:00 AM':
            if r5[i+3][4] != '8:30 AM - 10:00 AM' and r5[i+3][4] != '8:30 AM - 11:00 AM':
              if r5[i+4][4] != '8:30 AM - 10:00 AM' and r5[i+4][4] != '8:30 AM - 11:00 AM':
                print("Your Day Class Schedule ",r," :")
                print(r5[i],r5[i+1],r5[i+2],r5[i+3],r5[i+4])
                final_routine=[]
                final_routine.append(r5[i])
                final_routine.append(r5[i+1])
                final_routine.append(r5[i+2])
                final_routine.append(r5[i+3])
                final_routine.append(r5[i+4])
                print("Time Gap Of Day Schedule ",r," :")
                day_count(final_routine)
                print("") 
                p+=1
                r+=1
    if p==0:
      print("Sorry No Schedule Available In Day Time")
  if m == '2' :
    p=0
    r=1
    for i in range(0,len(r5),5):
      if r5[i][4] != '2:00 PM - 4:30 PM' and r5[i][4] != '1:30 PM - 3:00 PM' and  r5[i][4] != '3:00 PM - 4:30 PM' :
        if r5[i+1][4] != '2:00 PM - 4:30 PM' and r5[i+1][4] != '1:30 PM - 3:00 PM' and  r5[i+1][4] != '3:00 PM - 4:30 PM' :
          if r5[i+2][4] != '2:00 PM - 4:30 PM' and r5[i+2][4] != '1:30 PM - 3:00 PM' and  r5[i+2][4] != '3:00 PM - 4:30 PM' :
            if r5[i+3][4] != '2:00 PM - 4:30 PM' and r5[i+3][4] != '1:30 PM - 3:00 PM' and  r5[i+3][4] != '3:00 PM - 4:30 PM' :
              if r5[i+4][4] != '2:00 PM - 4:30 PM' and r5[i+4][4] != '1:30 PM - 3:00 PM' and  r5[i+4][4] != '3:00 PM - 4:30 PM' :
                print("Your Morning Class Schedule ",r," :")
                print(r5[i],r5[i+1],r5[i+2],r5[i+3],r5[i+4])
                final_routine=[]
                final_routine.append(r5[i])
                final_routine.append(r5[i+1])
                final_routine.append(r5[i+2])
                final_routine.append(r5[i+3]) 
                final_routine.append(r5[i+4]) 
                print("Time Gap Of Morning Schedule ",r," :")
                day_count(final_routine)
                print("")
                p+=1
                r+=1
    if p==0 :
      print("Sorry No Schedule Available In Morning Time")

# %% [markdown]
# # 6 Courses

# %%
if n == '6' :
  selected = []
  for i in range(0,len(np_data)):
    for j in range(len(taken_course)) :
      if np_data[i][0] == taken_course[j] :
        selected.append(np_data[i])

  c1 = []
  c2 = []
  c3 = []
  c4 = []
  c5 = []
  c6 = []
  for i in range (0,len(selected)):
      if selected[i][0] == taken_course[0] :
        c1.append(selected[i])
      elif selected[i][0] == taken_course[1] :
        c2.append(selected[i])
      elif selected[i][0] == taken_course[2] :
        c3.append(selected[i])
      elif selected[i][0] == taken_course[3] :
        c4.append(selected[i])
      elif selected[i][0] == taken_course[4] :
        c5.append(selected[i])
      elif selected[i][0] == taken_course[5] :
        c6.append(selected[i])

  all_possible = len(c1)*len(c2)*len(c3)*len(c4)*len(c5)*len(c6)
  r1 = []
  r2 = []
  #for c1 and c2
  for i in range(0,len(c1)):
    for j in range (0,len(c2)):
      #2 theory
      if c1[i][1].find('Lab') == -1 and c2[j][1].find('Lab') == -1 :
        if c1[i][3] == c2[j][3] :
          if c1[i][4] != c2[j][4]:
            r1.append(c1[i])
            r1.append(c2[j])
        elif  c1[i][3] != c2[j][3]:
          r1.append(c1[i])
          r1.append(c2[j])
      #2 Lab
      if c1[i][1].find('Lab') != -1 and c2[j][1].find('Lab') != -1 :
        if c1[i][3] == c2[j][3] :
          if c1[i][4] != c2[j][4]:
            r1.append(c1[i])
            r1.append(c2[j])
        elif  c1[i][3] != c2[j][3]:
          r1.append(c1[i])
          r1.append(c2[j])
      #1 Theory 1 Lab
      if c1[i][1].find('Lab') != -1 :
          if c2[j][3].find(c1[i][3]) != -1:
            if c1[i][4] == '8:30 AM - 11:00 AM' :
              if c2[j][4] != '8:30 AM - 10:00 AM' and c2[j][4] != '10:05 AM - 11:35 AM' :
                r1.append(c1[i])
                r1.append(c2[j])
            elif c1[i][4] == '11:00 AM - 1:30 PM' :
              if c2[j][4] != '10:05 AM - 11:35 AM' and c2[j][4] != '11:40 AM - 1:10 PM' :
                r1.append(c1[i])
                r1.append(c2[j])
            elif c1[i][4] == '2:00 PM - 4:30 PM' :
              if c2[j][4] != '1:30 PM - 3:00 PM' and c2[j][4] != '3:00 PM - 4:30 PM' :
                r1.append(c1[i])
                r1.append(c2[j])
          else :
            r1.append(c1[i])
            r1.append(c2[j])
      if c2[j][1].find('Lab') != -1:
          if c1[i][3].find(c2[j][3]) != -1:
            if c2[j][4] == '8:30 AM - 11:00 AM' :
              if c1[i][4] != '8:30 AM - 10:00 AM' and c1[i][4] != '10:05 AM - 11:35 AM' :
                r1.append(c1[i])
                r1.append(c2[j])
            elif c2[j][4] == '11:00 AM - 1:30 PM' :
              if c1[i][4] != '10:05 AM - 11:35 AM' and c1[i][4] != '11:40 AM - 1:10 PM' :
                r1.append(c1[i])
                r1.append(c2[j])
            elif c2[j][4] == '2:00 PM - 4:30 PM' :
              if c1[i][4] != '1:30 PM - 3:00 PM' and c1[i][4] != '3:00 PM - 4:30 PM' :
                r1.append(c1[i])
                r1.append(c2[j])
          else :
            r1.append(c1[i])
            r1.append(c2[j])

  r2 = c3
  r3 = []
  for i in range(0,len(r1),2):
    for j in range(0,len(r2)):
      s=0
      #c1 and C3
      #2 theory
      if r1[i][1].find('Lab') == -1 and r2[j][1].find('Lab') == -1 :
        if r1[i][3] == r2[j][3] :
          if r1[i][4] != r2[j][4]:
            s+=1
        elif  r1[i][3] != r2[j][3]:
          s+=1
      #2 Lab
      elif r1[i][1].find('Lab') != -1 and r2[j][1].find('Lab') != -1 :
        if r1[i][3] == r2[j][3] :
          if r1[i][4] != r2[j][4]:
            s+=1
        elif  r1[i][3] != r2[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r1[i][1].find('Lab') != -1 :
          if r2[j][3].find(r1[i][3]) != -1:
            if r1[i][4] == '8:30 AM - 11:00 AM' :
              if r2[j][4] != '8:30 AM - 10:00 AM' and r2[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r1[i][4] == '11:00 AM - 1:30 PM' :
              if r2[j][4] != '10:05 AM - 11:35 AM' and r2[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r1[i][4] == '2:00 PM - 4:30 PM' :
              if r2[j][4] != '1:30 PM - 3:00 PM' and r2[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r2[j][1].find('Lab') != -1:
          if r1[i][3].find(r2[j][3]) != -1:
            if r2[j][4] == '8:30 AM - 11:00 AM' :
              if r1[i][4] != '8:30 AM - 10:00 AM' and r1[i][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r2[j][4] == '11:00 AM - 1:30 PM' :
              if r1[i][4] != '10:05 AM - 11:35 AM' and r1[i][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r2[j][4] == '2:00 PM - 4:30 PM' :
              if r1[i][4] != '1:30 PM - 3:00 PM' and r1[i][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      #c2 and C3
      #2 theory
      if r1[i+1][1].find('Lab') == -1 and r2[j][1].find('Lab') == -1 :
        if r1[i+1][3] == r2[j][3] :
          if r1[i+1][4] != r2[j][4]:
            s+=1
        elif  r1[i+1][3] != r2[j][3]:
          s+=1
      #2 Lab
      elif r1[i+1][1].find('Lab') != -1 and r2[j][1].find('Lab') != -1 :
        if r1[i+1][3] == r2[j][3] :
          if r1[i+1][4] != r2[j][4]:
            s+=1
        elif  r1[i+1][3] != r2[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r1[i+1][1].find('Lab') != -1 :
          if r2[j][3].find(r1[i+1][3]) != -1:
            if r1[i+1][4] == '8:30 AM - 11:00 AM' :
              if r2[j][4] != '8:30 AM - 10:00 AM' and r2[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r1[i+1][4] == '11:00 AM - 1:30 PM' :
              if r2[j][4] != '10:05 AM - 11:35 AM' and r2[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r1[i+1][4] == '2:00 PM - 4:30 PM' :
              if r2[j][4] != '1:30 PM - 3:00 PM' and r2[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r2[j][1].find('Lab') != -1:
          if r1[i+1][3].find(r2[j][3]) != -1:
            if r2[j][4] == '8:30 AM - 11:00 AM' :
              if r1[i+1][4] != '8:30 AM - 10:00 AM' and r1[i+1][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r2[j][4] == '11:00 AM - 1:30 PM' :
              if r1[i+1][4] != '10:05 AM - 11:35 AM' and r1[i+1][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r2[j][4] == '2:00 PM - 4:30 PM' :
              if r1[i+1][4] != '1:30 PM - 3:00 PM' and r1[i+1][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1

      if s==2 :
        r3.append(r1[i])
        r3.append(r1[i+1])
        r3.append(r2[j])

  r4 = c4
  r5 = []
  for i in range(0,len(r3),3):
    for j in range(0,len(r4)):
      s=0
      #course c1 and c4
      #2 theory
      if r3[i][1].find('Lab') == -1 and r4[j][1].find('Lab') == -1 :
        if r3[i][3] == r4[j][3] :
          if r3[i][4] != r4[j][4]:
            s+=1
        elif  r3[i][3] != r4[j][3]:
          s+=1
      #2 Lab
      elif r3[i][1].find('Lab') != -1 and r4[j][1].find('Lab') != -1 :
        if r3[i][3] == r4[j][3] :
          if r3[i][4] != r4[j][4]:
            s+=1
        elif  r3[i][3] != r4[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r3[i][1].find('Lab') != -1 and r4[j][1].find('Lab') == -1:
          if r4[j][3].find(r3[i][3]) != -1:
            if r3[i][4] == '8:30 AM - 11:00 AM' :
              if r4[j][4] != '8:30 AM - 10:00 AM' and r4[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r3[i][4] == '11:00 AM - 1:30 PM' :
              if r4[j][4] != '10:05 AM - 11:35 AM' and r4[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r3[i][4] == '2:00 PM - 4:30 PM' :
              if r4[j][4] != '1:30 PM - 3:00 PM' and r4[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r4[j][1].find('Lab') != -1 and r3[i][1].find('Lab') == -1:
          if r3[i][3].find(r4[j][3]) != -1:
            if r4[j][4] == '8:30 AM - 11:00 AM' :
              if r3[i][4] != '8:30 AM - 10:00 AM' and r3[i][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r4[j][4] == '11:00 AM - 1:30 PM' :
              if r3[i][4] != '10:05 AM - 11:35 AM' and r3[i][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r4[j][4] == '2:00 PM - 4:30 PM' :
              if r3[i][4] != '1:30 PM - 3:00 PM' and r3[i][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      #course c2 and c4
      #2 theory
      if r3[i+1][1].find('Lab') == -1 and r4[j][1].find('Lab') == -1 :
        if r3[i+1][3] == r4[j][3] :
          if r3[i+1][4] != r4[j][4]:
            s+=1
        elif  r3[i+1][3] != r4[j][3]:
          s+=1
      #2 Lab
      elif r3[i+1][1].find('Lab') != -1 and r4[j][1].find('Lab') != -1 :
        if r3[i+1][3] == r4[j][3] :
          if r3[i+1][4] != r4[j][4]:
            s+=1
        elif  r3[i+1][3] != r4[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r3[i+1][1].find('Lab') != -1 and r4[j][1].find('Lab') == -1:
          if r4[j][3].find(r3[i+1][3]) != -1:
            if r3[i+1][4] == '8:30 AM - 11:00 AM' :
              if r4[j][4] != '8:30 AM - 10:00 AM' and r4[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r3[i+1][4] == '11:00 AM - 1:30 PM' :
              if r4[j][4] != '10:05 AM - 11:35 AM' and r4[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r3[i+1][4] == '2:00 PM - 4:30 PM' :
              if r4[j][4] != '1:30 PM - 3:00 PM' and r4[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r4[j][1].find('Lab') != -1:
          if r3[i+1][3].find(r4[j][3]) != -1 and r3[i+1][1].find('Lab') == -1:
            if r4[j][4] == '8:30 AM - 11:00 AM' :
              if r3[i+1][4] != '8:30 AM - 10:00 AM' and r3[i+1][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r4[j][4] == '11:00 AM - 1:30 PM' :
              if r3[i+1][4] != '10:05 AM - 11:35 AM' and r3[i+1][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r4[j][4] == '2:00 PM - 4:30 PM' :
              if r3[i+1][4] != '1:30 PM - 3:00 PM' and r3[i+1][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      #course c3 and c4
      #2 theory
      if r3[i+2][1].find('Lab') == -1 and r4[j][1].find('Lab') == -1 :
        if r3[i+2][3] == r4[j][3] :
          if r3[i+2][4] != r4[j][4]:
            s+=1
        elif  r3[i+2][3] != r4[j][3]:
          s+=1
      #2 Lab
      elif r3[i+2][1].find('Lab') != -1 and r4[j][1].find('Lab') != -1 :
        if r3[i+2][3] == r4[j][3] :
          if r3[i+2][4] != r4[j][4]:
            s+=1
        elif  r3[i+2][3] != r4[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r3[i+2][1].find('Lab') != -1 and r4[j][1].find('Lab') == -1 :
          if r4[j][3].find(r3[i+2][3]) != -1:
            if r3[i+2][4] == '8:30 AM - 11:00 AM' :
              if r4[j][4] != '8:30 AM - 10:00 AM' and r4[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r3[i+2][4] == '11:00 AM - 1:30 PM' :
              if r4[j][4] != '10:05 AM - 11:35 AM' and r4[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r3[i+2][4] == '2:00 PM - 4:30 PM' :
              if r4[j][4] != '1:30 PM - 3:00 PM' and r4[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r4[j][1].find('Lab') != -1 and r3[i+2][1].find('Lab') == -1:
          if r3[i+2][3].find(r4[j][3]) != -1:
            if r4[j][4] == '8:30 AM - 11:00 AM' :
              if r3[i+2][4] != '8:30 AM - 10:00 AM' and r3[i+2][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r4[j][4] == '11:00 AM - 1:30 PM' :
              if r3[i+2][4] != '10:05 AM - 11:35 AM' and r3[i+2][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r4[j][4] == '2:00 PM - 4:30 PM' :
              if r3[i+2][4] != '1:30 PM - 3:00 PM' and r3[i+2][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1

      if s==3 :
        r5.append(r3[i])
        r5.append(r3[i+1])
        r5.append(r3[i+2])
        r5.append(r4[j])

  r3 = r5
  r4 = c5
  r5=[]
  for i in range(0,len(r3),4):
    for j in range(0,len(r4)):
      s=0
      #course c1 and c5
      #2 theory
      if r3[i][1].find('Lab') == -1 and r4[j][1].find('Lab') == -1 :
        if r3[i][3] == r4[j][3] :
          if r3[i][4] != r4[j][4]:
            s+=1
        elif  r3[i][3] != r4[j][3]:
          s+=1
      #2 Lab
      elif r3[i][1].find('Lab') != -1 and r4[j][1].find('Lab') != -1 :
        if r3[i][3] == r4[j][3] :
          if r3[i][4] != r4[j][4]:
            s+=1
        elif  r3[i][3] != r4[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r3[i][1].find('Lab') != -1 and r4[j][1].find('Lab') == -1:
          if r4[j][3].find(r3[i][3]) != -1:
            if r3[i][4] == '8:30 AM - 11:00 AM' :
              if r4[j][4] != '8:30 AM - 10:00 AM' and r4[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r3[i][4] == '11:00 AM - 1:30 PM' :
              if r4[j][4] != '10:05 AM - 11:35 AM' and r4[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r3[i][4] == '2:00 PM - 4:30 PM' :
              if r4[j][4] != '1:30 PM - 3:00 PM' and r4[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r4[j][1].find('Lab') != -1 and r3[i][1].find('Lab') == -1:
          if r3[i][3].find(r4[j][3]) != -1:
            if r4[j][4] == '8:30 AM - 11:00 AM' :
              if r3[i][4] != '8:30 AM - 10:00 AM' and r3[i][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r4[j][4] == '11:00 AM - 1:30 PM' :
              if r3[i][4] != '10:05 AM - 11:35 AM' and r3[i][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r4[j][4] == '2:00 PM - 4:30 PM' :
              if r3[i][4] != '1:30 PM - 3:00 PM' and r3[i][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      #course c2 and c5
      #2 theory
      if r3[i+1][1].find('Lab') == -1 and r4[j][1].find('Lab') == -1 :
        if r3[i+1][3] == r4[j][3] :
          if r3[i+1][4] != r4[j][4]:
            s+=1
        elif  r3[i+1][3] != r4[j][3]:
          s+=1
      #2 Lab
      elif r3[i+1][1].find('Lab') != -1 and r4[j][1].find('Lab') != -1 :
        if r3[i+1][3] == r4[j][3] :
          if r3[i+1][4] != r4[j][4]:
            s+=1
        elif  r3[i+1][3] != r4[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r3[i+1][1].find('Lab') != -1 and r4[j][1].find('Lab') == -1:
          if r4[j][3].find(r3[i+1][3]) != -1:
            if r3[i+1][4] == '8:30 AM - 11:00 AM' :
              if r4[j][4] != '8:30 AM - 10:00 AM' and r4[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r3[i+1][4] == '11:00 AM - 1:30 PM' :
              if r4[j][4] != '10:05 AM - 11:35 AM' and r4[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r3[i+1][4] == '2:00 PM - 4:30 PM' :
              if r4[j][4] != '1:30 PM - 3:00 PM' and r4[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r4[j][1].find('Lab') != -1:
          if r3[i+1][3].find(r4[j][3]) != -1 and r3[i+1][1].find('Lab') == -1:
            if r4[j][4] == '8:30 AM - 11:00 AM' :
              if r3[i+1][4] != '8:30 AM - 10:00 AM' and r3[i+1][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r4[j][4] == '11:00 AM - 1:30 PM' :
              if r3[i+1][4] != '10:05 AM - 11:35 AM' and r3[i+1][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r4[j][4] == '2:00 PM - 4:30 PM' :
              if r3[i+1][4] != '1:30 PM - 3:00 PM' and r3[i+1][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      #course c3 and c5
      #2 theory
      if r3[i+2][1].find('Lab') == -1 and r4[j][1].find('Lab') == -1 :
        if r3[i+2][3] == r4[j][3] :
          if r3[i+2][4] != r4[j][4]:
            s+=1
        elif  r3[i+2][3] != r4[j][3]:
          s+=1
      #2 Lab
      elif r3[i+2][1].find('Lab') != -1 and r4[j][1].find('Lab') != -1 :
        if r3[i+2][3] == r4[j][3] :
          if r3[i+2][4] != r4[j][4]:
            s+=1
        elif  r3[i+2][3] != r4[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r3[i+2][1].find('Lab') != -1 and r4[j][1].find('Lab') == -1 :
          if r4[j][3].find(r3[i+2][3]) != -1:
            if r3[i+2][4] == '8:30 AM - 11:00 AM' :
              if r4[j][4] != '8:30 AM - 10:00 AM' and r4[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r3[i+2][4] == '11:00 AM - 1:30 PM' :
              if r4[j][4] != '10:05 AM - 11:35 AM' and r4[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r3[i+2][4] == '2:00 PM - 4:30 PM' :
              if r4[j][4] != '1:30 PM - 3:00 PM' and r4[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r4[j][1].find('Lab') != -1 and r3[i+2][1].find('Lab') == -1:
          if r3[i+2][3].find(r4[j][3]) != -1:
            if r4[j][4] == '8:30 AM - 11:00 AM' :
              if r3[i+2][4] != '8:30 AM - 10:00 AM' and r3[i+2][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r4[j][4] == '11:00 AM - 1:30 PM' :
              if r3[i+2][4] != '10:05 AM - 11:35 AM' and r3[i+2][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r4[j][4] == '2:00 PM - 4:30 PM' :
              if r3[i+2][4] != '1:30 PM - 3:00 PM' and r3[i+2][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      #course c4 and c5
      #2 theory
      if r3[i+3][1].find('Lab') == -1 and r4[j][1].find('Lab') == -1 :
        if r3[i+3][3] == r4[j][3] :
          if r3[i+3][4] != r4[j][4]:
            s+=1
        elif  r3[i+3][3] != r4[j][3]:
          s+=1
      #2 Lab
      elif r3[i+3][1].find('Lab') != -1 and r4[j][1].find('Lab') != -1 :
        if r3[i+3][3] == r4[j][3] :
          if r3[i+3][4] != r4[j][4]:
            s+=1
        elif  r3[i+3][3] != r4[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r3[i+3][1].find('Lab') != -1 and r4[j][1].find('Lab') == -1 :
          if r4[j][3].find(r3[i+3][3]) != -1:
            if r3[i+3][4] == '8:30 AM - 11:00 AM' :
              if r4[j][4] != '8:30 AM - 10:00 AM' and r4[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r3[i+3][4] == '11:00 AM - 1:30 PM' :
              if r4[j][4] != '10:05 AM - 11:35 AM' and r4[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r3[i+3][4] == '2:00 PM - 4:30 PM' :
              if r4[j][4] != '1:30 PM - 3:00 PM' and r4[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r4[j][1].find('Lab') != -1 and r3[i+3][1].find('Lab') == -1:
          if r3[i+3][3].find(r4[j][3]) != -1:
            if r4[j][4] == '8:30 AM - 11:00 AM' :
              if r3[i+3][4] != '8:30 AM - 10:00 AM' and r3[i+3][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r4[j][4] == '11:00 AM - 1:30 PM' :
              if r3[i+3][4] != '10:05 AM - 11:35 AM' and r3[i+3][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r4[j][4] == '2:00 PM - 4:30 PM' :
              if r3[i+3][4] != '1:30 PM - 3:00 PM' and r3[i+3][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1

      if s==4 :
        r5.append(r3[i])
        r5.append(r3[i+1])
        r5.append(r3[i+2])
        r5.append(r3[i+3])
        r5.append(r4[j])

  r3 = r5
  r4 = c6
  t=0
  r5 = []
  r=1
  print("Suggested Schedule : ")
  for i in range(0,len(r3),5):
    for j in range(0,len(r4)):
      s=0
      #course c1 and c6
      #2 theory
      if r3[i][1].find('Lab') == -1 and r4[j][1].find('Lab') == -1 :
        if r3[i][3] == r4[j][3] :
          if r3[i][4] != r4[j][4]:
            s+=1
        elif  r3[i][3] != r4[j][3]:
          s+=1
      #2 Lab
      elif r3[i][1].find('Lab') != -1 and r4[j][1].find('Lab') != -1 :
        if r3[i][3] == r4[j][3] :
          if r3[i][4] != r4[j][4]:
            s+=1
        elif  r3[i][3] != r4[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r3[i][1].find('Lab') != -1 and r4[j][1].find('Lab') == -1:
          if r4[j][3].find(r3[i][3]) != -1:
            if r3[i][4] == '8:30 AM - 11:00 AM' :
              if r4[j][4] != '8:30 AM - 10:00 AM' and r4[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r3[i][4] == '11:00 AM - 1:30 PM' :
              if r4[j][4] != '10:05 AM - 11:35 AM' and r4[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r3[i][4] == '2:00 PM - 4:30 PM' :
              if r4[j][4] != '1:30 PM - 3:00 PM' and r4[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r4[j][1].find('Lab') != -1 and r3[i][1].find('Lab') == -1:
          if r3[i][3].find(r4[j][3]) != -1:
            if r4[j][4] == '8:30 AM - 11:00 AM' :
              if r3[i][4] != '8:30 AM - 10:00 AM' and r3[i][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r4[j][4] == '11:00 AM - 1:30 PM' :
              if r3[i][4] != '10:05 AM - 11:35 AM' and r3[i][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r4[j][4] == '2:00 PM - 4:30 PM' :
              if r3[i][4] != '1:30 PM - 3:00 PM' and r3[i][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      #course c2 and c6
      #2 theory
      if r3[i+1][1].find('Lab') == -1 and r4[j][1].find('Lab') == -1 :
        if r3[i+1][3] == r4[j][3] :
          if r3[i+1][4] != r4[j][4]:
            s+=1
        elif  r3[i+1][3] != r4[j][3]:
          s+=1
      #2 Lab
      elif r3[i+1][1].find('Lab') != -1 and r4[j][1].find('Lab') != -1 :
        if r3[i+1][3] == r4[j][3] :
          if r3[i+1][4] != r4[j][4]:
            s+=1
        elif  r3[i+1][3] != r4[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r3[i+1][1].find('Lab') != -1 and r4[j][1].find('Lab') == -1:
          if r4[j][3].find(r3[i+1][3]) != -1:
            if r3[i+1][4] == '8:30 AM - 11:00 AM' :
              if r4[j][4] != '8:30 AM - 10:00 AM' and r4[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r3[i+1][4] == '11:00 AM - 1:30 PM' :
              if r4[j][4] != '10:05 AM - 11:35 AM' and r4[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r3[i+1][4] == '2:00 PM - 4:30 PM' :
              if r4[j][4] != '1:30 PM - 3:00 PM' and r4[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r4[j][1].find('Lab') != -1:
          if r3[i+1][3].find(r4[j][3]) != -1 and r3[i+1][1].find('Lab') == -1:
            if r4[j][4] == '8:30 AM - 11:00 AM' :
              if r3[i+1][4] != '8:30 AM - 10:00 AM' and r3[i+1][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r4[j][4] == '11:00 AM - 1:30 PM' :
              if r3[i+1][4] != '10:05 AM - 11:35 AM' and r3[i+1][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r4[j][4] == '2:00 PM - 4:30 PM' :
              if r3[i+1][4] != '1:30 PM - 3:00 PM' and r3[i+1][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      #course c3 and c6
      #2 theory
      if r3[i+2][1].find('Lab') == -1 and r4[j][1].find('Lab') == -1 :
        if r3[i+2][3] == r4[j][3] :
          if r3[i+2][4] != r4[j][4]:
            s+=1
        elif  r3[i+2][3] != r4[j][3]:
          s+=1
      #2 Lab
      elif r3[i+2][1].find('Lab') != -1 and r4[j][1].find('Lab') != -1 :
        if r3[i+2][3] == r4[j][3] :
          if r3[i+2][4] != r4[j][4]:
            s+=1
        elif  r3[i+2][3] != r4[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r3[i+2][1].find('Lab') != -1 and r4[j][1].find('Lab') == -1 :
          if r4[j][3].find(r3[i+2][3]) != -1:
            if r3[i+2][4] == '8:30 AM - 11:00 AM' :
              if r4[j][4] != '8:30 AM - 10:00 AM' and r4[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r3[i+2][4] == '11:00 AM - 1:30 PM' :
              if r4[j][4] != '10:05 AM - 11:35 AM' and r4[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r3[i+2][4] == '2:00 PM - 4:30 PM' :
              if r4[j][4] != '1:30 PM - 3:00 PM' and r4[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r4[j][1].find('Lab') != -1 and r3[i+2][1].find('Lab') == -1:
          if r3[i+2][3].find(r4[j][3]) != -1:
            if r4[j][4] == '8:30 AM - 11:00 AM' :
              if r3[i+2][4] != '8:30 AM - 10:00 AM' and r3[i+2][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r4[j][4] == '11:00 AM - 1:30 PM' :
              if r3[i+2][4] != '10:05 AM - 11:35 AM' and r3[i+2][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r4[j][4] == '2:00 PM - 4:30 PM' :
              if r3[i+2][4] != '1:30 PM - 3:00 PM' and r3[i+2][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      #course c4 and c6
      #2 theory
      if r3[i+3][1].find('Lab') == -1 and r4[j][1].find('Lab') == -1 :
        if r3[i+3][3] == r4[j][3] :
          if r3[i+3][4] != r4[j][4]:
            s+=1
        elif  r3[i+3][3] != r4[j][3]:
          s+=1
      #2 Lab
      elif r3[i+3][1].find('Lab') != -1 and r4[j][1].find('Lab') != -1 :
        if r3[i+3][3] == r4[j][3] :
          if r3[i+3][4] != r4[j][4]:
            s+=1
        elif  r3[i+3][3] != r4[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r3[i+3][1].find('Lab') != -1 and r4[j][1].find('Lab') == -1 :
          if r4[j][3].find(r3[i+3][3]) != -1:
            if r3[i+3][4] == '8:30 AM - 11:00 AM' :
              if r4[j][4] != '8:30 AM - 10:00 AM' and r4[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r3[i+3][4] == '11:00 AM - 1:30 PM' :
              if r4[j][4] != '10:05 AM - 11:35 AM' and r4[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r3[i+3][4] == '2:00 PM - 4:30 PM' :
              if r4[j][4] != '1:30 PM - 3:00 PM' and r4[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r4[j][1].find('Lab') != -1 and r3[i+3][1].find('Lab') == -1:
          if r3[i+3][3].find(r4[j][3]) != -1:
            if r4[j][4] == '8:30 AM - 11:00 AM' :
              if r3[i+3][4] != '8:30 AM - 10:00 AM' and r3[i+3][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r4[j][4] == '11:00 AM - 1:30 PM' :
              if r3[i+3][4] != '10:05 AM - 11:35 AM' and r3[i+3][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r4[j][4] == '2:00 PM - 4:30 PM' :
              if r3[i+3][4] != '1:30 PM - 3:00 PM' and r3[i+3][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      #course c5 and c6
      #2 theory
      if r3[i+4][1].find('Lab') == -1 and r4[j][1].find('Lab') == -1 :
        if r3[i+4][3] == r4[j][3] :
          if r3[i+4][4] != r4[j][4]:
            s+=1
        elif  r3[i+4][3] != r4[j][3]:
          s+=1
      #2 Lab
      elif r3[i+4][1].find('Lab') != -1 and r4[j][1].find('Lab') != -1 :
        if r3[i+4][3] == r4[j][3] :
          if r3[i+4][4] != r4[j][4]:
            s+=1
        elif  r3[i+4][3] != r4[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r3[i+4][1].find('Lab') != -1 and r4[j][1].find('Lab') == -1 :
          if r4[j][3].find(r3[i+4][3]) != -1:
            if r3[i+4][4] == '8:30 AM - 11:00 AM' :
              if r4[j][4] != '8:30 AM - 10:00 AM' and r4[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r3[i+4][4] == '11:00 AM - 1:30 PM' :
              if r4[j][4] != '10:05 AM - 11:35 AM' and r4[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r3[i+4][4] == '2:00 PM - 4:30 PM' :
              if r4[j][4] != '1:30 PM - 3:00 PM' and r4[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r4[j][1].find('Lab') != -1 and r3[i+4][1].find('Lab') == -1:
          if r3[i+4][3].find(r4[j][3]) != -1:
            if r4[j][4] == '8:30 AM - 11:00 AM' :
              if r3[i+4][4] != '8:30 AM - 10:00 AM' and r3[i+4][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r4[j][4] == '11:00 AM - 1:30 PM' :
              if r3[i+4][4] != '10:05 AM - 11:35 AM' and r3[i+4][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r4[j][4] == '2:00 PM - 4:30 PM' :
              if r3[i+4][4] != '1:30 PM - 3:00 PM' and r3[i+4][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1

      if s==5 :
        print("Suggested Schedule ",r," :")
        print(r3[i],r3[i+1],r3[i+2],r3[i+3],r3[i+4],r4[j])
        r5.append(r3[i])
        r5.append(r3[i+1])
        r5.append(r3[i+2])
        r5.append(r3[i+3])
        r5.append(r3[i+4])
        r5.append(r4[j])

        final_routine=[]
        final_routine.append(r3[i])
        final_routine.append(r3[i+1])
        final_routine.append(r3[i+2])
        final_routine.append(r3[i+3])
        final_routine.append(r3[i+4])
        final_routine.append(r4[j])
        print("Time Gap Of Schedule ",r," :")
        day_count(final_routine)

        t+=1
        r+=1
        print("")

  print("All Posible Schedule = ",all_possible)
  print("Suggested Schedule = ",t)
  print("")

  print("")
  print("")
  print("")
  print("Your Preferable Schedule :")

  if m == '1' :
    p=0
    r=1
    for i in range(0,len(r5),6):
      if r5[i][4] != '8:30 AM - 10:00 AM' and r5[i][4] != '8:30 AM - 11:00 AM':
        if r5[i+1][4] != '8:30 AM - 10:00 AM'  and r5[i+1][4] != '8:30 AM - 11:00 AM':
          if r5[i+2][4] != '8:30 AM - 10:00 AM' and r5[i+2][4] != '8:30 AM - 11:00 AM':
            if r5[i+3][4] != '8:30 AM - 10:00 AM' and r5[i+3][4] != '8:30 AM - 11:00 AM':
              if r5[i+4][4] != '8:30 AM - 10:00 AM' and r5[i+4][4] != '8:30 AM - 11:00 AM':
                if r5[i+5][4] != '8:30 AM - 10:00 AM' and r5[i+5][4] != '8:30 AM - 11:00 AM':
                  print("Your Day Class Schedule ",r," :")
                  print(r5[i],r5[i+1],r5[i+2],r5[i+3],r5[i+4],r5[i+5])
                  final_routine=[]
                  final_routine.append(r5[i])
                  final_routine.append(r5[i+1])
                  final_routine.append(r5[i+2])
                  final_routine.append(r5[i+3])
                  final_routine.append(r5[i+4])
                  final_routine.append(r5[i+5])
                  print("Time Gap Of Day Schedule ",r," :")
                  day_count(final_routine)
                  print("") 
                  p+=1
                  r+=1
    if p==0:
      print("Sorry No Schedule Available In Day Time")
  if m == '2' :
    p=0
    r=1
    for i in range(0,len(r5),6):
      if r5[i][4] != '2:00 PM - 4:30 PM' and r5[i][4] != '1:30 PM - 3:00 PM' and  r5[i][4] != '3:00 PM - 4:30 PM' :
        if r5[i+1][4] != '2:00 PM - 4:30 PM' and r5[i+1][4] != '1:30 PM - 3:00 PM' and  r5[i+1][4] != '3:00 PM - 4:30 PM' :
          if r5[i+2][4] != '2:00 PM - 4:30 PM' and r5[i+2][4] != '1:30 PM - 3:00 PM' and  r5[i+2][4] != '3:00 PM - 4:30 PM' :
            if r5[i+3][4] != '2:00 PM - 4:30 PM' and r5[i+3][4] != '1:30 PM - 3:00 PM' and  r5[i+3][4] != '3:00 PM - 4:30 PM' :
              if r5[i+4][4] != '2:00 PM - 4:30 PM' and r5[i+4][4] != '1:30 PM - 3:00 PM' and  r5[i+4][4] != '3:00 PM - 4:30 PM' :
                if r5[i+5][4] != '2:00 PM - 4:30 PM' and r5[i+5][4] != '1:30 PM - 3:00 PM' and  r5[i+5][4] != '3:00 PM - 4:30 PM' :
                  print("Your Morning Class Schedule ",r," :")
                  print(r5[i],r5[i+1],r5[i+2],r5[i+3],r5[i+4],r5[i+5])
                  final_routine=[]
                  final_routine.append(r5[i])
                  final_routine.append(r5[i+1])
                  final_routine.append(r5[i+2])
                  final_routine.append(r5[i+3])
                  final_routine.append(r5[i+4])
                  final_routine.append(r5[i+5])
                  print("Time Gap Of Morning Schedule ",r," :")
                  day_count(final_routine)
                  print("")
                  p+=1
                  r+=1
    if p==0 :
      print("Sorry No Schedule Available In Morning Time")

# %% [markdown]
# # 7 Courses

# %%
if n == '7' :
  selected = []
  for i in range(0,len(np_data)):
    for j in range(len(taken_course)) :
      if np_data[i][0] == taken_course[j] :
        selected.append(np_data[i])

  c1 = []
  c2 = []
  c3 = []
  c4 = []
  c5 = []
  c6 = []
  c7 = []
  for i in range (0,len(selected)):
      if selected[i][0] == taken_course[0] :
        c1.append(selected[i])
      elif selected[i][0] == taken_course[1] :
        c2.append(selected[i])
      elif selected[i][0] == taken_course[2] :
        c3.append(selected[i])
      elif selected[i][0] == taken_course[3] :
        c4.append(selected[i])
      elif selected[i][0] == taken_course[4] :
        c5.append(selected[i])
      elif selected[i][0] == taken_course[5] :
        c6.append(selected[i])
      elif selected[i][0] == taken_course[6] :
        c7.append(selected[i])


  all_possible = len(c1)*len(c2)*len(c3)*len(c4)*len(c5)*len(c6)*len(c7)
  r1 = []
  r2 = []
  #for c1 and c2
  for i in range(0,len(c1)):
    for j in range (0,len(c2)):
      #2 theory
      if c1[i][1].find('Lab') == -1 and c2[j][1].find('Lab') == -1 :
        if c1[i][3] == c2[j][3] :
          if c1[i][4] != c2[j][4]:
            r1.append(c1[i])
            r1.append(c2[j])
        elif  c1[i][3] != c2[j][3]:
          r1.append(c1[i])
          r1.append(c2[j])
      #2 Lab
      if c1[i][1].find('Lab') != -1 and c2[j][1].find('Lab') != -1 :
        if c1[i][3] == c2[j][3] :
          if c1[i][4] != c2[j][4]:
            r1.append(c1[i])
            r1.append(c2[j])
        elif  c1[i][3] != c2[j][3]:
          r1.append(c1[i])
          r1.append(c2[j])
      #1 Theory 1 Lab
      if c1[i][1].find('Lab') != -1 :
          if c2[j][3].find(c1[i][3]) != -1:
            if c1[i][4] == '8:30 AM - 11:00 AM' :
              if c2[j][4] != '8:30 AM - 10:00 AM' and c2[j][4] != '10:05 AM - 11:35 AM' :
                r1.append(c1[i])
                r1.append(c2[j])
            elif c1[i][4] == '11:00 AM - 1:30 PM' :
              if c2[j][4] != '10:05 AM - 11:35 AM' and c2[j][4] != '11:40 AM - 1:10 PM' :
                r1.append(c1[i])
                r1.append(c2[j])
            elif c1[i][4] == '2:00 PM - 4:30 PM' :
              if c2[j][4] != '1:30 PM - 3:00 PM' and c2[j][4] != '3:00 PM - 4:30 PM' :
                r1.append(c1[i])
                r1.append(c2[j])
          else :
            r1.append(c1[i])
            r1.append(c2[j])
      if c2[j][1].find('Lab') != -1:
          if c1[i][3].find(c2[j][3]) != -1:
            if c2[j][4] == '8:30 AM - 11:00 AM' :
              if c1[i][4] != '8:30 AM - 10:00 AM' and c1[i][4] != '10:05 AM - 11:35 AM' :
                r1.append(c1[i])
                r1.append(c2[j])
            elif c2[j][4] == '11:00 AM - 1:30 PM' :
              if c1[i][4] != '10:05 AM - 11:35 AM' and c1[i][4] != '11:40 AM - 1:10 PM' :
                r1.append(c1[i])
                r1.append(c2[j])
            elif c2[j][4] == '2:00 PM - 4:30 PM' :
              if c1[i][4] != '1:30 PM - 3:00 PM' and c1[i][4] != '3:00 PM - 4:30 PM' :
                r1.append(c1[i])
                r1.append(c2[j])
          else :
            r1.append(c1[i])
            r1.append(c2[j])

  r2 = c3
  r3 = []
  for i in range(0,len(r1),2):
    for j in range(0,len(r2)):
      s=0
      #c1 and C3
      #2 theory
      if r1[i][1].find('Lab') == -1 and r2[j][1].find('Lab') == -1 :
        if r1[i][3] == r2[j][3] :
          if r1[i][4] != r2[j][4]:
            s+=1
        elif  r1[i][3] != r2[j][3]:
          s+=1
      #2 Lab
      elif r1[i][1].find('Lab') != -1 and r2[j][1].find('Lab') != -1 :
        if r1[i][3] == r2[j][3] :
          if r1[i][4] != r2[j][4]:
            s+=1
        elif  r1[i][3] != r2[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r1[i][1].find('Lab') != -1 :
          if r2[j][3].find(r1[i][3]) != -1:
            if r1[i][4] == '8:30 AM - 11:00 AM' :
              if r2[j][4] != '8:30 AM - 10:00 AM' and r2[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r1[i][4] == '11:00 AM - 1:30 PM' :
              if r2[j][4] != '10:05 AM - 11:35 AM' and r2[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r1[i][4] == '2:00 PM - 4:30 PM' :
              if r2[j][4] != '1:30 PM - 3:00 PM' and r2[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r2[j][1].find('Lab') != -1:
          if r1[i][3].find(r2[j][3]) != -1:
            if r2[j][4] == '8:30 AM - 11:00 AM' :
              if r1[i][4] != '8:30 AM - 10:00 AM' and r1[i][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r2[j][4] == '11:00 AM - 1:30 PM' :
              if r1[i][4] != '10:05 AM - 11:35 AM' and r1[i][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r2[j][4] == '2:00 PM - 4:30 PM' :
              if r1[i][4] != '1:30 PM - 3:00 PM' and r1[i][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      #c2 and C3
      #2 theory
      if r1[i+1][1].find('Lab') == -1 and r2[j][1].find('Lab') == -1 :
        if r1[i+1][3] == r2[j][3] :
          if r1[i+1][4] != r2[j][4]:
            s+=1
        elif  r1[i+1][3] != r2[j][3]:
          s+=1
      #2 Lab
      elif r1[i+1][1].find('Lab') != -1 and r2[j][1].find('Lab') != -1 :
        if r1[i+1][3] == r2[j][3] :
          if r1[i+1][4] != r2[j][4]:
            s+=1
        elif  r1[i+1][3] != r2[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r1[i+1][1].find('Lab') != -1 :
          if r2[j][3].find(r1[i+1][3]) != -1:
            if r1[i+1][4] == '8:30 AM - 11:00 AM' :
              if r2[j][4] != '8:30 AM - 10:00 AM' and r2[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r1[i+1][4] == '11:00 AM - 1:30 PM' :
              if r2[j][4] != '10:05 AM - 11:35 AM' and r2[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r1[i+1][4] == '2:00 PM - 4:30 PM' :
              if r2[j][4] != '1:30 PM - 3:00 PM' and r2[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r2[j][1].find('Lab') != -1:
          if r1[i+1][3].find(r2[j][3]) != -1:
            if r2[j][4] == '8:30 AM - 11:00 AM' :
              if r1[i+1][4] != '8:30 AM - 10:00 AM' and r1[i+1][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r2[j][4] == '11:00 AM - 1:30 PM' :
              if r1[i+1][4] != '10:05 AM - 11:35 AM' and r1[i+1][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r2[j][4] == '2:00 PM - 4:30 PM' :
              if r1[i+1][4] != '1:30 PM - 3:00 PM' and r1[i+1][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1

      if s==2 :
        r3.append(r1[i])
        r3.append(r1[i+1])
        r3.append(r2[j])

  r4 = c4
  r5 = []
  for i in range(0,len(r3),3):
    for j in range(0,len(r4)):
      s=0
      #course c1 and c4
      #2 theory
      if r3[i][1].find('Lab') == -1 and r4[j][1].find('Lab') == -1 :
        if r3[i][3] == r4[j][3] :
          if r3[i][4] != r4[j][4]:
            s+=1
        elif  r3[i][3] != r4[j][3]:
          s+=1
      #2 Lab
      elif r3[i][1].find('Lab') != -1 and r4[j][1].find('Lab') != -1 :
        if r3[i][3] == r4[j][3] :
          if r3[i][4] != r4[j][4]:
            s+=1
        elif  r3[i][3] != r4[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r3[i][1].find('Lab') != -1 and r4[j][1].find('Lab') == -1:
          if r4[j][3].find(r3[i][3]) != -1:
            if r3[i][4] == '8:30 AM - 11:00 AM' :
              if r4[j][4] != '8:30 AM - 10:00 AM' and r4[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r3[i][4] == '11:00 AM - 1:30 PM' :
              if r4[j][4] != '10:05 AM - 11:35 AM' and r4[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r3[i][4] == '2:00 PM - 4:30 PM' :
              if r4[j][4] != '1:30 PM - 3:00 PM' and r4[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r4[j][1].find('Lab') != -1 and r3[i][1].find('Lab') == -1:
          if r3[i][3].find(r4[j][3]) != -1:
            if r4[j][4] == '8:30 AM - 11:00 AM' :
              if r3[i][4] != '8:30 AM - 10:00 AM' and r3[i][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r4[j][4] == '11:00 AM - 1:30 PM' :
              if r3[i][4] != '10:05 AM - 11:35 AM' and r3[i][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r4[j][4] == '2:00 PM - 4:30 PM' :
              if r3[i][4] != '1:30 PM - 3:00 PM' and r3[i][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      #course c2 and c4
      #2 theory
      if r3[i+1][1].find('Lab') == -1 and r4[j][1].find('Lab') == -1 :
        if r3[i+1][3] == r4[j][3] :
          if r3[i+1][4] != r4[j][4]:
            s+=1
        elif  r3[i+1][3] != r4[j][3]:
          s+=1
      #2 Lab
      elif r3[i+1][1].find('Lab') != -1 and r4[j][1].find('Lab') != -1 :
        if r3[i+1][3] == r4[j][3] :
          if r3[i+1][4] != r4[j][4]:
            s+=1
        elif  r3[i+1][3] != r4[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r3[i+1][1].find('Lab') != -1 and r4[j][1].find('Lab') == -1:
          if r4[j][3].find(r3[i+1][3]) != -1:
            if r3[i+1][4] == '8:30 AM - 11:00 AM' :
              if r4[j][4] != '8:30 AM - 10:00 AM' and r4[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r3[i+1][4] == '11:00 AM - 1:30 PM' :
              if r4[j][4] != '10:05 AM - 11:35 AM' and r4[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r3[i+1][4] == '2:00 PM - 4:30 PM' :
              if r4[j][4] != '1:30 PM - 3:00 PM' and r4[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r4[j][1].find('Lab') != -1:
          if r3[i+1][3].find(r4[j][3]) != -1 and r3[i+1][1].find('Lab') == -1:
            if r4[j][4] == '8:30 AM - 11:00 AM' :
              if r3[i+1][4] != '8:30 AM - 10:00 AM' and r3[i+1][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r4[j][4] == '11:00 AM - 1:30 PM' :
              if r3[i+1][4] != '10:05 AM - 11:35 AM' and r3[i+1][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r4[j][4] == '2:00 PM - 4:30 PM' :
              if r3[i+1][4] != '1:30 PM - 3:00 PM' and r3[i+1][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      #course c3 and c4
      #2 theory
      if r3[i+2][1].find('Lab') == -1 and r4[j][1].find('Lab') == -1 :
        if r3[i+2][3] == r4[j][3] :
          if r3[i+2][4] != r4[j][4]:
            s+=1
        elif  r3[i+2][3] != r4[j][3]:
          s+=1
      #2 Lab
      elif r3[i+2][1].find('Lab') != -1 and r4[j][1].find('Lab') != -1 :
        if r3[i+2][3] == r4[j][3] :
          if r3[i+2][4] != r4[j][4]:
            s+=1
        elif  r3[i+2][3] != r4[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r3[i+2][1].find('Lab') != -1 and r4[j][1].find('Lab') == -1 :
          if r4[j][3].find(r3[i+2][3]) != -1:
            if r3[i+2][4] == '8:30 AM - 11:00 AM' :
              if r4[j][4] != '8:30 AM - 10:00 AM' and r4[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r3[i+2][4] == '11:00 AM - 1:30 PM' :
              if r4[j][4] != '10:05 AM - 11:35 AM' and r4[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r3[i+2][4] == '2:00 PM - 4:30 PM' :
              if r4[j][4] != '1:30 PM - 3:00 PM' and r4[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r4[j][1].find('Lab') != -1 and r3[i+2][1].find('Lab') == -1:
          if r3[i+2][3].find(r4[j][3]) != -1:
            if r4[j][4] == '8:30 AM - 11:00 AM' :
              if r3[i+2][4] != '8:30 AM - 10:00 AM' and r3[i+2][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r4[j][4] == '11:00 AM - 1:30 PM' :
              if r3[i+2][4] != '10:05 AM - 11:35 AM' and r3[i+2][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r4[j][4] == '2:00 PM - 4:30 PM' :
              if r3[i+2][4] != '1:30 PM - 3:00 PM' and r3[i+2][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1

      if s==3 :
        r5.append(r3[i])
        r5.append(r3[i+1])
        r5.append(r3[i+2])
        r5.append(r4[j])

  r3 = r5
  r4 = c5
  r5=[]
  for i in range(0,len(r3),4):
    for j in range(0,len(r4)):
      s=0
      #course c1 and c5
      #2 theory
      if r3[i][1].find('Lab') == -1 and r4[j][1].find('Lab') == -1 :
        if r3[i][3] == r4[j][3] :
          if r3[i][4] != r4[j][4]:
            s+=1
        elif  r3[i][3] != r4[j][3]:
          s+=1
      #2 Lab
      elif r3[i][1].find('Lab') != -1 and r4[j][1].find('Lab') != -1 :
        if r3[i][3] == r4[j][3] :
          if r3[i][4] != r4[j][4]:
            s+=1
        elif  r3[i][3] != r4[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r3[i][1].find('Lab') != -1 and r4[j][1].find('Lab') == -1:
          if r4[j][3].find(r3[i][3]) != -1:
            if r3[i][4] == '8:30 AM - 11:00 AM' :
              if r4[j][4] != '8:30 AM - 10:00 AM' and r4[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r3[i][4] == '11:00 AM - 1:30 PM' :
              if r4[j][4] != '10:05 AM - 11:35 AM' and r4[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r3[i][4] == '2:00 PM - 4:30 PM' :
              if r4[j][4] != '1:30 PM - 3:00 PM' and r4[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r4[j][1].find('Lab') != -1 and r3[i][1].find('Lab') == -1:
          if r3[i][3].find(r4[j][3]) != -1:
            if r4[j][4] == '8:30 AM - 11:00 AM' :
              if r3[i][4] != '8:30 AM - 10:00 AM' and r3[i][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r4[j][4] == '11:00 AM - 1:30 PM' :
              if r3[i][4] != '10:05 AM - 11:35 AM' and r3[i][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r4[j][4] == '2:00 PM - 4:30 PM' :
              if r3[i][4] != '1:30 PM - 3:00 PM' and r3[i][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      #course c2 and c5
      #2 theory
      if r3[i+1][1].find('Lab') == -1 and r4[j][1].find('Lab') == -1 :
        if r3[i+1][3] == r4[j][3] :
          if r3[i+1][4] != r4[j][4]:
            s+=1
        elif  r3[i+1][3] != r4[j][3]:
          s+=1
      #2 Lab
      elif r3[i+1][1].find('Lab') != -1 and r4[j][1].find('Lab') != -1 :
        if r3[i+1][3] == r4[j][3] :
          if r3[i+1][4] != r4[j][4]:
            s+=1
        elif  r3[i+1][3] != r4[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r3[i+1][1].find('Lab') != -1 and r4[j][1].find('Lab') == -1:
          if r4[j][3].find(r3[i+1][3]) != -1:
            if r3[i+1][4] == '8:30 AM - 11:00 AM' :
              if r4[j][4] != '8:30 AM - 10:00 AM' and r4[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r3[i+1][4] == '11:00 AM - 1:30 PM' :
              if r4[j][4] != '10:05 AM - 11:35 AM' and r4[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r3[i+1][4] == '2:00 PM - 4:30 PM' :
              if r4[j][4] != '1:30 PM - 3:00 PM' and r4[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r4[j][1].find('Lab') != -1:
          if r3[i+1][3].find(r4[j][3]) != -1 and r3[i+1][1].find('Lab') == -1:
            if r4[j][4] == '8:30 AM - 11:00 AM' :
              if r3[i+1][4] != '8:30 AM - 10:00 AM' and r3[i+1][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r4[j][4] == '11:00 AM - 1:30 PM' :
              if r3[i+1][4] != '10:05 AM - 11:35 AM' and r3[i+1][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r4[j][4] == '2:00 PM - 4:30 PM' :
              if r3[i+1][4] != '1:30 PM - 3:00 PM' and r3[i+1][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      #course c3 and c5
      #2 theory
      if r3[i+2][1].find('Lab') == -1 and r4[j][1].find('Lab') == -1 :
        if r3[i+2][3] == r4[j][3] :
          if r3[i+2][4] != r4[j][4]:
            s+=1
        elif  r3[i+2][3] != r4[j][3]:
          s+=1
      #2 Lab
      elif r3[i+2][1].find('Lab') != -1 and r4[j][1].find('Lab') != -1 :
        if r3[i+2][3] == r4[j][3] :
          if r3[i+2][4] != r4[j][4]:
            s+=1
        elif  r3[i+2][3] != r4[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r3[i+2][1].find('Lab') != -1 and r4[j][1].find('Lab') == -1 :
          if r4[j][3].find(r3[i+2][3]) != -1:
            if r3[i+2][4] == '8:30 AM - 11:00 AM' :
              if r4[j][4] != '8:30 AM - 10:00 AM' and r4[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r3[i+2][4] == '11:00 AM - 1:30 PM' :
              if r4[j][4] != '10:05 AM - 11:35 AM' and r4[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r3[i+2][4] == '2:00 PM - 4:30 PM' :
              if r4[j][4] != '1:30 PM - 3:00 PM' and r4[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r4[j][1].find('Lab') != -1 and r3[i+2][1].find('Lab') == -1:
          if r3[i+2][3].find(r4[j][3]) != -1:
            if r4[j][4] == '8:30 AM - 11:00 AM' :
              if r3[i+2][4] != '8:30 AM - 10:00 AM' and r3[i+2][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r4[j][4] == '11:00 AM - 1:30 PM' :
              if r3[i+2][4] != '10:05 AM - 11:35 AM' and r3[i+2][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r4[j][4] == '2:00 PM - 4:30 PM' :
              if r3[i+2][4] != '1:30 PM - 3:00 PM' and r3[i+2][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      #course c4 and c5
      #2 theory
      if r3[i+3][1].find('Lab') == -1 and r4[j][1].find('Lab') == -1 :
        if r3[i+3][3] == r4[j][3] :
          if r3[i+3][4] != r4[j][4]:
            s+=1
        elif  r3[i+3][3] != r4[j][3]:
          s+=1
      #2 Lab
      elif r3[i+3][1].find('Lab') != -1 and r4[j][1].find('Lab') != -1 :
        if r3[i+3][3] == r4[j][3] :
          if r3[i+3][4] != r4[j][4]:
            s+=1
        elif  r3[i+3][3] != r4[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r3[i+3][1].find('Lab') != -1 and r4[j][1].find('Lab') == -1 :
          if r4[j][3].find(r3[i+3][3]) != -1:
            if r3[i+3][4] == '8:30 AM - 11:00 AM' :
              if r4[j][4] != '8:30 AM - 10:00 AM' and r4[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r3[i+3][4] == '11:00 AM - 1:30 PM' :
              if r4[j][4] != '10:05 AM - 11:35 AM' and r4[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r3[i+3][4] == '2:00 PM - 4:30 PM' :
              if r4[j][4] != '1:30 PM - 3:00 PM' and r4[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r4[j][1].find('Lab') != -1 and r3[i+3][1].find('Lab') == -1:
          if r3[i+3][3].find(r4[j][3]) != -1:
            if r4[j][4] == '8:30 AM - 11:00 AM' :
              if r3[i+3][4] != '8:30 AM - 10:00 AM' and r3[i+3][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r4[j][4] == '11:00 AM - 1:30 PM' :
              if r3[i+3][4] != '10:05 AM - 11:35 AM' and r3[i+3][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r4[j][4] == '2:00 PM - 4:30 PM' :
              if r3[i+3][4] != '1:30 PM - 3:00 PM' and r3[i+3][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1

      if s==4 :
        r5.append(r3[i])
        r5.append(r3[i+1])
        r5.append(r3[i+2])
        r5.append(r3[i+3])
        r5.append(r4[j])

  r3 = r5
  r4 = c6
  r5 = []
  print("Suggested Schedule : ")
  for i in range(0,len(r3),5):
    for j in range(0,len(r4)):
      s=0
      #course c1 and c6
      #2 theory
      if r3[i][1].find('Lab') == -1 and r4[j][1].find('Lab') == -1 :
        if r3[i][3] == r4[j][3] :
          if r3[i][4] != r4[j][4]:
            s+=1
        elif  r3[i][3] != r4[j][3]:
          s+=1
      #2 Lab
      elif r3[i][1].find('Lab') != -1 and r4[j][1].find('Lab') != -1 :
        if r3[i][3] == r4[j][3] :
          if r3[i][4] != r4[j][4]:
            s+=1
        elif  r3[i][3] != r4[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r3[i][1].find('Lab') != -1 and r4[j][1].find('Lab') == -1:
          if r4[j][3].find(r3[i][3]) != -1:
            if r3[i][4] == '8:30 AM - 11:00 AM' :
              if r4[j][4] != '8:30 AM - 10:00 AM' and r4[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r3[i][4] == '11:00 AM - 1:30 PM' :
              if r4[j][4] != '10:05 AM - 11:35 AM' and r4[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r3[i][4] == '2:00 PM - 4:30 PM' :
              if r4[j][4] != '1:30 PM - 3:00 PM' and r4[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r4[j][1].find('Lab') != -1 and r3[i][1].find('Lab') == -1:
          if r3[i][3].find(r4[j][3]) != -1:
            if r4[j][4] == '8:30 AM - 11:00 AM' :
              if r3[i][4] != '8:30 AM - 10:00 AM' and r3[i][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r4[j][4] == '11:00 AM - 1:30 PM' :
              if r3[i][4] != '10:05 AM - 11:35 AM' and r3[i][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r4[j][4] == '2:00 PM - 4:30 PM' :
              if r3[i][4] != '1:30 PM - 3:00 PM' and r3[i][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      #course c2 and c6
      #2 theory
      if r3[i+1][1].find('Lab') == -1 and r4[j][1].find('Lab') == -1 :
        if r3[i+1][3] == r4[j][3] :
          if r3[i+1][4] != r4[j][4]:
            s+=1
        elif  r3[i+1][3] != r4[j][3]:
          s+=1
      #2 Lab
      elif r3[i+1][1].find('Lab') != -1 and r4[j][1].find('Lab') != -1 :
        if r3[i+1][3] == r4[j][3] :
          if r3[i+1][4] != r4[j][4]:
            s+=1
        elif  r3[i+1][3] != r4[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r3[i+1][1].find('Lab') != -1 and r4[j][1].find('Lab') == -1:
          if r4[j][3].find(r3[i+1][3]) != -1:
            if r3[i+1][4] == '8:30 AM - 11:00 AM' :
              if r4[j][4] != '8:30 AM - 10:00 AM' and r4[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r3[i+1][4] == '11:00 AM - 1:30 PM' :
              if r4[j][4] != '10:05 AM - 11:35 AM' and r4[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r3[i+1][4] == '2:00 PM - 4:30 PM' :
              if r4[j][4] != '1:30 PM - 3:00 PM' and r4[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r4[j][1].find('Lab') != -1:
          if r3[i+1][3].find(r4[j][3]) != -1 and r3[i+1][1].find('Lab') == -1:
            if r4[j][4] == '8:30 AM - 11:00 AM' :
              if r3[i+1][4] != '8:30 AM - 10:00 AM' and r3[i+1][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r4[j][4] == '11:00 AM - 1:30 PM' :
              if r3[i+1][4] != '10:05 AM - 11:35 AM' and r3[i+1][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r4[j][4] == '2:00 PM - 4:30 PM' :
              if r3[i+1][4] != '1:30 PM - 3:00 PM' and r3[i+1][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      #course c3 and c6
      #2 theory
      if r3[i+2][1].find('Lab') == -1 and r4[j][1].find('Lab') == -1 :
        if r3[i+2][3] == r4[j][3] :
          if r3[i+2][4] != r4[j][4]:
            s+=1
        elif  r3[i+2][3] != r4[j][3]:
          s+=1
      #2 Lab
      elif r3[i+2][1].find('Lab') != -1 and r4[j][1].find('Lab') != -1 :
        if r3[i+2][3] == r4[j][3] :
          if r3[i+2][4] != r4[j][4]:
            s+=1
        elif  r3[i+2][3] != r4[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r3[i+2][1].find('Lab') != -1 and r4[j][1].find('Lab') == -1 :
          if r4[j][3].find(r3[i+2][3]) != -1:
            if r3[i+2][4] == '8:30 AM - 11:00 AM' :
              if r4[j][4] != '8:30 AM - 10:00 AM' and r4[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r3[i+2][4] == '11:00 AM - 1:30 PM' :
              if r4[j][4] != '10:05 AM - 11:35 AM' and r4[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r3[i+2][4] == '2:00 PM - 4:30 PM' :
              if r4[j][4] != '1:30 PM - 3:00 PM' and r4[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r4[j][1].find('Lab') != -1 and r3[i+2][1].find('Lab') == -1:
          if r3[i+2][3].find(r4[j][3]) != -1:
            if r4[j][4] == '8:30 AM - 11:00 AM' :
              if r3[i+2][4] != '8:30 AM - 10:00 AM' and r3[i+2][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r4[j][4] == '11:00 AM - 1:30 PM' :
              if r3[i+2][4] != '10:05 AM - 11:35 AM' and r3[i+2][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r4[j][4] == '2:00 PM - 4:30 PM' :
              if r3[i+2][4] != '1:30 PM - 3:00 PM' and r3[i+2][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      #course c4 and c6
      #2 theory
      if r3[i+3][1].find('Lab') == -1 and r4[j][1].find('Lab') == -1 :
        if r3[i+3][3] == r4[j][3] :
          if r3[i+3][4] != r4[j][4]:
            s+=1
        elif  r3[i+3][3] != r4[j][3]:
          s+=1
      #2 Lab
      elif r3[i+3][1].find('Lab') != -1 and r4[j][1].find('Lab') != -1 :
        if r3[i+3][3] == r4[j][3] :
          if r3[i+3][4] != r4[j][4]:
            s+=1
        elif  r3[i+3][3] != r4[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r3[i+3][1].find('Lab') != -1 and r4[j][1].find('Lab') == -1 :
          if r4[j][3].find(r3[i+3][3]) != -1:
            if r3[i+3][4] == '8:30 AM - 11:00 AM' :
              if r4[j][4] != '8:30 AM - 10:00 AM' and r4[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r3[i+3][4] == '11:00 AM - 1:30 PM' :
              if r4[j][4] != '10:05 AM - 11:35 AM' and r4[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r3[i+3][4] == '2:00 PM - 4:30 PM' :
              if r4[j][4] != '1:30 PM - 3:00 PM' and r4[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r4[j][1].find('Lab') != -1 and r3[i+3][1].find('Lab') == -1:
          if r3[i+3][3].find(r4[j][3]) != -1:
            if r4[j][4] == '8:30 AM - 11:00 AM' :
              if r3[i+3][4] != '8:30 AM - 10:00 AM' and r3[i+3][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r4[j][4] == '11:00 AM - 1:30 PM' :
              if r3[i+3][4] != '10:05 AM - 11:35 AM' and r3[i+3][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r4[j][4] == '2:00 PM - 4:30 PM' :
              if r3[i+3][4] != '1:30 PM - 3:00 PM' and r3[i+3][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      #course c5 and c6
      #2 theory
      if r3[i+4][1].find('Lab') == -1 and r4[j][1].find('Lab') == -1 :
        if r3[i+4][3] == r4[j][3] :
          if r3[i+4][4] != r4[j][4]:
            s+=1
        elif  r3[i+4][3] != r4[j][3]:
          s+=1
      #2 Lab
      elif r3[i+4][1].find('Lab') != -1 and r4[j][1].find('Lab') != -1 :
        if r3[i+4][3] == r4[j][3] :
          if r3[i+4][4] != r4[j][4]:
            s+=1
        elif  r3[i+4][3] != r4[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r3[i+4][1].find('Lab') != -1 and r4[j][1].find('Lab') == -1 :
          if r4[j][3].find(r3[i+4][3]) != -1:
            if r3[i+4][4] == '8:30 AM - 11:00 AM' :
              if r4[j][4] != '8:30 AM - 10:00 AM' and r4[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r3[i+4][4] == '11:00 AM - 1:30 PM' :
              if r4[j][4] != '10:05 AM - 11:35 AM' and r4[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r3[i+4][4] == '2:00 PM - 4:30 PM' :
              if r4[j][4] != '1:30 PM - 3:00 PM' and r4[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r4[j][1].find('Lab') != -1 and r3[i+4][1].find('Lab') == -1:
          if r3[i+4][3].find(r4[j][3]) != -1:
            if r4[j][4] == '8:30 AM - 11:00 AM' :
              if r3[i+4][4] != '8:30 AM - 10:00 AM' and r3[i+4][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r4[j][4] == '11:00 AM - 1:30 PM' :
              if r3[i+4][4] != '10:05 AM - 11:35 AM' and r3[i+4][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r4[j][4] == '2:00 PM - 4:30 PM' :
              if r3[i+4][4] != '1:30 PM - 3:00 PM' and r3[i+4][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1

      if s==5 :
        r5.append(r3[i])
        r5.append(r3[i+1])
        r5.append(r3[i+2])
        r5.append(r3[i+3])
        r5.append(r3[i+4])
        r5.append(r4[j])

  r3 = r5
  r4 = c7
  r=1
  #7 course
  t=0
  r5 = []
  for i in range(0,len(r3),6):
    for j in range(0,len(r4)):
      s=0
      #course c1 and c7
      #2 theory
      if r3[i][1].find('Lab') == -1 and r4[j][1].find('Lab') == -1 :
        if r3[i][3] == r4[j][3] :
          if r3[i][4] != r4[j][4]:
            s+=1
        elif  r3[i][3] != r4[j][3]:
          s+=1
      #2 Lab
      elif r3[i][1].find('Lab') != -1 and r4[j][1].find('Lab') != -1 :
        if r3[i][3] == r4[j][3] :
          if r3[i][4] != r4[j][4]:
            s+=1
        elif  r3[i][3] != r4[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r3[i][1].find('Lab') != -1 and r4[j][1].find('Lab') == -1:
          if r4[j][3].find(r3[i][3]) != -1:
            if r3[i][4] == '8:30 AM - 11:00 AM' :
              if r4[j][4] != '8:30 AM - 10:00 AM' and r4[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r3[i][4] == '11:00 AM - 1:30 PM' :
              if r4[j][4] != '10:05 AM - 11:35 AM' and r4[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r3[i][4] == '2:00 PM - 4:30 PM' :
              if r4[j][4] != '1:30 PM - 3:00 PM' and r4[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r4[j][1].find('Lab') != -1 and r3[i][1].find('Lab') == -1:
          if r3[i][3].find(r4[j][3]) != -1:
            if r4[j][4] == '8:30 AM - 11:00 AM' :
              if r3[i][4] != '8:30 AM - 10:00 AM' and r3[i][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r4[j][4] == '11:00 AM - 1:30 PM' :
              if r3[i][4] != '10:05 AM - 11:35 AM' and r3[i][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r4[j][4] == '2:00 PM - 4:30 PM' :
              if r3[i][4] != '1:30 PM - 3:00 PM' and r3[i][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      #course c2 and c7
      #2 theory
      if r3[i+1][1].find('Lab') == -1 and r4[j][1].find('Lab') == -1 :
        if r3[i+1][3] == r4[j][3] :
          if r3[i+1][4] != r4[j][4]:
            s+=1
        elif  r3[i+1][3] != r4[j][3]:
          s+=1
      #2 Lab
      elif r3[i+1][1].find('Lab') != -1 and r4[j][1].find('Lab') != -1 :
        if r3[i+1][3] == r4[j][3] :
          if r3[i+1][4] != r4[j][4]:
            s+=1
        elif  r3[i+1][3] != r4[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r3[i+1][1].find('Lab') != -1 and r4[j][1].find('Lab') == -1:
          if r4[j][3].find(r3[i+1][3]) != -1:
            if r3[i+1][4] == '8:30 AM - 11:00 AM' :
              if r4[j][4] != '8:30 AM - 10:00 AM' and r4[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r3[i+1][4] == '11:00 AM - 1:30 PM' :
              if r4[j][4] != '10:05 AM - 11:35 AM' and r4[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r3[i+1][4] == '2:00 PM - 4:30 PM' :
              if r4[j][4] != '1:30 PM - 3:00 PM' and r4[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r4[j][1].find('Lab') != -1:
          if r3[i+1][3].find(r4[j][3]) != -1 and r3[i+1][1].find('Lab') == -1:
            if r4[j][4] == '8:30 AM - 11:00 AM' :
              if r3[i+1][4] != '8:30 AM - 10:00 AM' and r3[i+1][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r4[j][4] == '11:00 AM - 1:30 PM' :
              if r3[i+1][4] != '10:05 AM - 11:35 AM' and r3[i+1][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r4[j][4] == '2:00 PM - 4:30 PM' :
              if r3[i+1][4] != '1:30 PM - 3:00 PM' and r3[i+1][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      #course c3 and c7
      #2 theory
      if r3[i+2][1].find('Lab') == -1 and r4[j][1].find('Lab') == -1 :
        if r3[i+2][3] == r4[j][3] :
          if r3[i+2][4] != r4[j][4]:
            s+=1
        elif  r3[i+2][3] != r4[j][3]:
          s+=1
      #2 Lab
      elif r3[i+2][1].find('Lab') != -1 and r4[j][1].find('Lab') != -1 :
        if r3[i+2][3] == r4[j][3] :
          if r3[i+2][4] != r4[j][4]:
            s+=1
        elif  r3[i+2][3] != r4[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r3[i+2][1].find('Lab') != -1 and r4[j][1].find('Lab') == -1 :
          if r4[j][3].find(r3[i+2][3]) != -1:
            if r3[i+2][4] == '8:30 AM - 11:00 AM' :
              if r4[j][4] != '8:30 AM - 10:00 AM' and r4[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r3[i+2][4] == '11:00 AM - 1:30 PM' :
              if r4[j][4] != '10:05 AM - 11:35 AM' and r4[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r3[i+2][4] == '2:00 PM - 4:30 PM' :
              if r4[j][4] != '1:30 PM - 3:00 PM' and r4[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r4[j][1].find('Lab') != -1 and r3[i+2][1].find('Lab') == -1:
          if r3[i+2][3].find(r4[j][3]) != -1:
            if r4[j][4] == '8:30 AM - 11:00 AM' :
              if r3[i+2][4] != '8:30 AM - 10:00 AM' and r3[i+2][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r4[j][4] == '11:00 AM - 1:30 PM' :
              if r3[i+2][4] != '10:05 AM - 11:35 AM' and r3[i+2][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r4[j][4] == '2:00 PM - 4:30 PM' :
              if r3[i+2][4] != '1:30 PM - 3:00 PM' and r3[i+2][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      #course c4 and c7
      #2 theory
      if r3[i+3][1].find('Lab') == -1 and r4[j][1].find('Lab') == -1 :
        if r3[i+3][3] == r4[j][3] :
          if r3[i+3][4] != r4[j][4]:
            s+=1
        elif  r3[i+3][3] != r4[j][3]:
          s+=1
      #2 Lab
      elif r3[i+3][1].find('Lab') != -1 and r4[j][1].find('Lab') != -1 :
        if r3[i+3][3] == r4[j][3] :
          if r3[i+3][4] != r4[j][4]:
            s+=1
        elif  r3[i+3][3] != r4[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r3[i+3][1].find('Lab') != -1 and r4[j][1].find('Lab') == -1 :
          if r4[j][3].find(r3[i+3][3]) != -1:
            if r3[i+3][4] == '8:30 AM - 11:00 AM' :
              if r4[j][4] != '8:30 AM - 10:00 AM' and r4[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r3[i+3][4] == '11:00 AM - 1:30 PM' :
              if r4[j][4] != '10:05 AM - 11:35 AM' and r4[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r3[i+3][4] == '2:00 PM - 4:30 PM' :
              if r4[j][4] != '1:30 PM - 3:00 PM' and r4[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r4[j][1].find('Lab') != -1 and r3[i+3][1].find('Lab') == -1:
          if r3[i+3][3].find(r4[j][3]) != -1:
            if r4[j][4] == '8:30 AM - 11:00 AM' :
              if r3[i+3][4] != '8:30 AM - 10:00 AM' and r3[i+3][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r4[j][4] == '11:00 AM - 1:30 PM' :
              if r3[i+3][4] != '10:05 AM - 11:35 AM' and r3[i+3][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r4[j][4] == '2:00 PM - 4:30 PM' :
              if r3[i+3][4] != '1:30 PM - 3:00 PM' and r3[i+3][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      #course c5 and c7
      #2 theory
      if r3[i+4][1].find('Lab') == -1 and r4[j][1].find('Lab') == -1 :
        if r3[i+4][3] == r4[j][3] :
          if r3[i+4][4] != r4[j][4]:
            s+=1
        elif  r3[i+4][3] != r4[j][3]:
          s+=1
      #2 Lab
      elif r3[i+4][1].find('Lab') != -1 and r4[j][1].find('Lab') != -1 :
        if r3[i+4][3] == r4[j][3] :
          if r3[i+4][4] != r4[j][4]:
            s+=1
        elif  r3[i+4][3] != r4[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r3[i+4][1].find('Lab') != -1 and r4[j][1].find('Lab') == -1 :
          if r4[j][3].find(r3[i+4][3]) != -1:
            if r3[i+4][4] == '8:30 AM - 11:00 AM' :
              if r4[j][4] != '8:30 AM - 10:00 AM' and r4[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r3[i+4][4] == '11:00 AM - 1:30 PM' :
              if r4[j][4] != '10:05 AM - 11:35 AM' and r4[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r3[i+4][4] == '2:00 PM - 4:30 PM' :
              if r4[j][4] != '1:30 PM - 3:00 PM' and r4[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r4[j][1].find('Lab') != -1 and r3[i+4][1].find('Lab') == -1:
          if r3[i+4][3].find(r4[j][3]) != -1:
            if r4[j][4] == '8:30 AM - 11:00 AM' :
              if r3[i+4][4] != '8:30 AM - 10:00 AM' and r3[i+4][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r4[j][4] == '11:00 AM - 1:30 PM' :
              if r3[i+4][4] != '10:05 AM - 11:35 AM' and r3[i+4][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r4[j][4] == '2:00 PM - 4:30 PM' :
              if r3[i+4][4] != '1:30 PM - 3:00 PM' and r3[i+4][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      #c6 and c7
      #2 theory
      if r3[i+5][1].find('Lab') == -1 and r4[j][1].find('Lab') == -1 :
        if r3[i+5][3] == r4[j][3] :
          if r3[i+5][4] != r4[j][4]:
            s+=1
        elif  r3[i+5][3] != r4[j][3]:
          s+=1
      #2 Lab
      elif r3[i+5][1].find('Lab') != -1 and r4[j][1].find('Lab') != -1 :
        if r3[i+5][3] == r4[j][3] :
          if r3[i+5][4] != r4[j][4]:
            s+=1
        elif  r3[i+5][3] != r4[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r3[i+5][1].find('Lab') != -1 and r4[j][1].find('Lab') == -1:
          if r4[j][3].find(r3[i+5][3]) != -1:
            if r3[i+5][4] == '8:30 AM - 11:00 AM' :
              if r4[j][4] != '8:30 AM - 10:00 AM' and r4[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r3[i+5][4] == '11:00 AM - 1:30 PM' :
              if r4[j][4] != '10:05 AM - 11:35 AM' and r4[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r3[i+5][4] == '2:00 PM - 4:30 PM' :
              if r4[j][4] != '1:30 PM - 3:00 PM' and r4[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r4[j][1].find('Lab') != -1 and r3[i+5][1].find('Lab') == -1:
          if r3[i+5][3].find(r4[j][3]) != -1:
            if r4[j][4] == '8:30 AM - 11:00 AM' :
              if r3[i+5][4] != '8:30 AM - 10:00 AM' and r3[i+5][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r4[j][4] == '11:00 AM - 1:30 PM' :
              if r3[i+5][4] != '10:05 AM - 11:35 AM' and r3[i+5][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r4[j][4] == '2:00 PM - 4:30 PM' :
              if r3[i+5][4] != '1:30 PM - 3:00 PM' and r3[i+5][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1

      if s==6 :
        print("Suggested Schedule ",r," :")
        print(r3[i],r3[i+1],r3[i+2],r3[i+3],r3[i+4],r3[i+5],r4[j])
        r5.append(r3[i])
        r5.append(r3[i+1])
        r5.append(r3[i+2])
        r5.append(r3[i+3])
        r5.append(r3[i+4])
        r5.append(r3[i+5])
        r5.append(r4[j])

        final_routine=[]
        final_routine.append(r3[i])
        final_routine.append(r3[i+1])
        final_routine.append(r3[i+2])
        final_routine.append(r3[i+3])
        final_routine.append(r3[i+4])
        final_routine.append(r3[i+5])
        final_routine.append(r4[j])
        print("Time Gap Of Schedule ",r," :")
        day_count(final_routine)

        t+=1
        r+=1
        print("")

  print("All Posible Schedule = ",all_possible)
  print("Suggested Schedule = ",t)
  print("")

  print("")
  print("")
  print("")
  print("Your Preferable Schedule :")
  if m == '1' :
    p=0
    r=1
    for i in range(0,len(r5),7):
      if r5[i][4] != '8:30 AM - 10:00 AM' and r5[i][4] != '8:30 AM - 11:00 AM':
        if r5[i+1][4] != '8:30 AM - 10:00 AM'  and r5[i+1][4] != '8:30 AM - 11:00 AM':
          if r5[i+2][4] != '8:30 AM - 10:00 AM' and r5[i+2][4] != '8:30 AM - 11:00 AM':
            if r5[i+3][4] != '8:30 AM - 10:00 AM' and r5[i+3][4] != '8:30 AM - 11:00 AM':
              if r5[i+4][4] != '8:30 AM - 10:00 AM' and r5[i+4][4] != '8:30 AM - 11:00 AM':
                if r5[i+5][4] != '8:30 AM - 10:00 AM' and r5[i+5][4] != '8:30 AM - 11:00 AM':
                  if r5[i+6][4] != '8:30 AM - 10:00 AM' and r5[i+6][4] != '8:30 AM - 11:00 AM':
                    print("Your Day Class Schedule ",r," :")
                    print(r5[i],r5[i+1],r5[i+2],r5[i+3],r5[i+4],r5[i+5],r5[i+6])
                    final_routine=[]
                    final_routine.append(r5[i])
                    final_routine.append(r5[i+1])
                    final_routine.append(r5[i+2])
                    final_routine.append(r5[i+3])
                    final_routine.append(r5[i+4])
                    final_routine.append(r5[i+5])
                    final_routine.append(r5[i+6])
                    print("Time Gap Of Day Schedule ",r," :")
                    day_count(final_routine)
                    print("") 
                    p+=1
                    r+=1
    if p==0:
      print("Sorry No Schedule Available In Day Time")
  if m == '2' :
    p=0
    r=1
    for i in range(0,len(r5),7):
      if r5[i][4] != '2:00 PM - 4:30 PM' and r5[i][4] != '1:30 PM - 3:00 PM' and  r5[i][4] != '3:00 PM - 4:30 PM' :
        if r5[i+1][4] != '2:00 PM - 4:30 PM' and r5[i+1][4] != '1:30 PM - 3:00 PM' and  r5[i+1][4] != '3:00 PM - 4:30 PM' :
          if r5[i+2][4] != '2:00 PM - 4:30 PM' and r5[i+2][4] != '1:30 PM - 3:00 PM' and  r5[i+2][4] != '3:00 PM - 4:30 PM' :
            if r5[i+3][4] != '2:00 PM - 4:30 PM' and r5[i+3][4] != '1:30 PM - 3:00 PM' and  r5[i+3][4] != '3:00 PM - 4:30 PM' :
              if r5[i+4][4] != '2:00 PM - 4:30 PM' and r5[i+4][4] != '1:30 PM - 3:00 PM' and  r5[i+4][4] != '3:00 PM - 4:30 PM' :
                if r5[i+5][4] != '2:00 PM - 4:30 PM' and r5[i+5][4] != '1:30 PM - 3:00 PM' and  r5[i+5][4] != '3:00 PM - 4:30 PM' :
                  if r5[i+6][4] != '2:00 PM - 4:30 PM' and r5[i+6][4] != '1:30 PM - 3:00 PM' and  r5[i+6][4] != '3:00 PM - 4:30 PM' :
                    print("Your Morning Class Schedule ",r," :")
                    print(r5[i],r5[i+1],r5[i+2],r5[i+3],r5[i+4],r5[i+5],r5[i+6])
                    final_routine=[]
                    final_routine.append(r5[i])
                    final_routine.append(r5[i+1])
                    final_routine.append(r5[i+2])
                    final_routine.append(r5[i+3])
                    final_routine.append(r5[i+4])
                    final_routine.append(r5[i+5])
                    final_routine.append(r5[i+6])
                    print("Time Gap Of Morning Schedule ",r," :")
                    day_count(final_routine)
                    print("")
                    p+=1
                    r+=1
    if p==0 :
      print("Sorry No Schedule Available In Morning Time")

# %% [markdown]
# # 8 Courses

# %%
if n == '8' :
  selected = []
  for i in range(0,len(np_data)):
    for j in range(len(taken_course)) :
      if np_data[i][0] == taken_course[j] :
        selected.append(np_data[i])

  c1 = []
  c2 = []
  c3 = []
  c4 = []
  c5 = []
  c6 = []
  c7 = []
  c8 = []
  for i in range (0,len(selected)):
      if selected[i][0] == taken_course[0] :
        c1.append(selected[i])
      elif selected[i][0] == taken_course[1] :
        c2.append(selected[i])
      elif selected[i][0] == taken_course[2] :
        c3.append(selected[i])
      elif selected[i][0] == taken_course[3] :
        c4.append(selected[i])
      elif selected[i][0] == taken_course[4] :
        c5.append(selected[i])
      elif selected[i][0] == taken_course[5] :
        c6.append(selected[i])
      elif selected[i][0] == taken_course[6] :
        c7.append(selected[i])
      elif selected[i][0] == taken_course[7] :
        c8.append(selected[i])

  all_possible = len(c1)*len(c2)*len(c3)*len(c4)*len(c5)*len(c6)*len(c7)*len(c8)
  r1 = []
  r2 = []
  #2 course
  #for c1 and c2
  for i in range(0,len(c1)):
    for j in range (0,len(c2)):
      #2 theory
      if c1[i][1].find('Lab') == -1 and c2[j][1].find('Lab') == -1 :
        if c1[i][3] == c2[j][3] :
          if c1[i][4] != c2[j][4]:
            r1.append(c1[i])
            r1.append(c2[j])
        elif  c1[i][3] != c2[j][3]:
          r1.append(c1[i])
          r1.append(c2[j])
      #2 Lab
      if c1[i][1].find('Lab') != -1 and c2[j][1].find('Lab') != -1 :
        if c1[i][3] == c2[j][3] :
          if c1[i][4] != c2[j][4]:
            r1.append(c1[i])
            r1.append(c2[j])
        elif  c1[i][3] != c2[j][3]:
          r1.append(c1[i])
          r1.append(c2[j])
      #1 Theory 1 Lab
      if c1[i][1].find('Lab') != -1 :
          if c2[j][3].find(c1[i][3]) != -1:
            if c1[i][4] == '8:30 AM - 11:00 AM' :
              if c2[j][4] != '8:30 AM - 10:00 AM' and c2[j][4] != '10:05 AM - 11:35 AM' :
                r1.append(c1[i])
                r1.append(c2[j])
            elif c1[i][4] == '11:00 AM - 1:30 PM' :
              if c2[j][4] != '10:05 AM - 11:35 AM' and c2[j][4] != '11:40 AM - 1:10 PM' :
                r1.append(c1[i])
                r1.append(c2[j])
            elif c1[i][4] == '2:00 PM - 4:30 PM' :
              if c2[j][4] != '1:30 PM - 3:00 PM' and c2[j][4] != '3:00 PM - 4:30 PM' :
                r1.append(c1[i])
                r1.append(c2[j])
          else :
            r1.append(c1[i])
            r1.append(c2[j])
      if c2[j][1].find('Lab') != -1:
          if c1[i][3].find(c2[j][3]) != -1:
            if c2[j][4] == '8:30 AM - 11:00 AM' :
              if c1[i][4] != '8:30 AM - 10:00 AM' and c1[i][4] != '10:05 AM - 11:35 AM' :
                r1.append(c1[i])
                r1.append(c2[j])
            elif c2[j][4] == '11:00 AM - 1:30 PM' :
              if c1[i][4] != '10:05 AM - 11:35 AM' and c1[i][4] != '11:40 AM - 1:10 PM' :
                r1.append(c1[i])
                r1.append(c2[j])
            elif c2[j][4] == '2:00 PM - 4:30 PM' :
              if c1[i][4] != '1:30 PM - 3:00 PM' and c1[i][4] != '3:00 PM - 4:30 PM' :
                r1.append(c1[i])
                r1.append(c2[j])
          else :
            r1.append(c1[i])
            r1.append(c2[j])
  #3 course
  r2 = c3
  r3 = []
  for i in range(0,len(r1),2):
    for j in range(0,len(r2)):
      s=0
      #c1 and C3
      #2 theory
      if r1[i][1].find('Lab') == -1 and r2[j][1].find('Lab') == -1 :
        if r1[i][3] == r2[j][3] :
          if r1[i][4] != r2[j][4]:
            s+=1
        elif  r1[i][3] != r2[j][3]:
          s+=1
      #2 Lab
      elif r1[i][1].find('Lab') != -1 and r2[j][1].find('Lab') != -1 :
        if r1[i][3] == r2[j][3] :
          if r1[i][4] != r2[j][4]:
            s+=1
        elif  r1[i][3] != r2[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r1[i][1].find('Lab') != -1 :
          if r2[j][3].find(r1[i][3]) != -1:
            if r1[i][4] == '8:30 AM - 11:00 AM' :
              if r2[j][4] != '8:30 AM - 10:00 AM' and r2[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r1[i][4] == '11:00 AM - 1:30 PM' :
              if r2[j][4] != '10:05 AM - 11:35 AM' and r2[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r1[i][4] == '2:00 PM - 4:30 PM' :
              if r2[j][4] != '1:30 PM - 3:00 PM' and r2[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r2[j][1].find('Lab') != -1:
          if r1[i][3].find(r2[j][3]) != -1:
            if r2[j][4] == '8:30 AM - 11:00 AM' :
              if r1[i][4] != '8:30 AM - 10:00 AM' and r1[i][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r2[j][4] == '11:00 AM - 1:30 PM' :
              if r1[i][4] != '10:05 AM - 11:35 AM' and r1[i][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r2[j][4] == '2:00 PM - 4:30 PM' :
              if r1[i][4] != '1:30 PM - 3:00 PM' and r1[i][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      #c2 and C3
      #2 theory
      if r1[i+1][1].find('Lab') == -1 and r2[j][1].find('Lab') == -1 :
        if r1[i+1][3] == r2[j][3] :
          if r1[i+1][4] != r2[j][4]:
            s+=1
        elif  r1[i+1][3] != r2[j][3]:
          s+=1
      #2 Lab
      elif r1[i+1][1].find('Lab') != -1 and r2[j][1].find('Lab') != -1 :
        if r1[i+1][3] == r2[j][3] :
          if r1[i+1][4] != r2[j][4]:
            s+=1
        elif  r1[i+1][3] != r2[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r1[i+1][1].find('Lab') != -1 :
          if r2[j][3].find(r1[i+1][3]) != -1:
            if r1[i+1][4] == '8:30 AM - 11:00 AM' :
              if r2[j][4] != '8:30 AM - 10:00 AM' and r2[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r1[i+1][4] == '11:00 AM - 1:30 PM' :
              if r2[j][4] != '10:05 AM - 11:35 AM' and r2[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r1[i+1][4] == '2:00 PM - 4:30 PM' :
              if r2[j][4] != '1:30 PM - 3:00 PM' and r2[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r2[j][1].find('Lab') != -1:
          if r1[i+1][3].find(r2[j][3]) != -1:
            if r2[j][4] == '8:30 AM - 11:00 AM' :
              if r1[i+1][4] != '8:30 AM - 10:00 AM' and r1[i+1][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r2[j][4] == '11:00 AM - 1:30 PM' :
              if r1[i+1][4] != '10:05 AM - 11:35 AM' and r1[i+1][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r2[j][4] == '2:00 PM - 4:30 PM' :
              if r1[i+1][4] != '1:30 PM - 3:00 PM' and r1[i+1][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1

      if s==2 :
        r3.append(r1[i])
        r3.append(r1[i+1])
        r3.append(r2[j])
  #4 course
  r4 = c4
  r5 = []
  for i in range(0,len(r3),3):
    for j in range(0,len(r4)):
      s=0
      #course c1 and c4
      #2 theory
      if r3[i][1].find('Lab') == -1 and r4[j][1].find('Lab') == -1 :
        if r3[i][3] == r4[j][3] :
          if r3[i][4] != r4[j][4]:
            s+=1
        elif  r3[i][3] != r4[j][3]:
          s+=1
      #2 Lab
      elif r3[i][1].find('Lab') != -1 and r4[j][1].find('Lab') != -1 :
        if r3[i][3] == r4[j][3] :
          if r3[i][4] != r4[j][4]:
            s+=1
        elif  r3[i][3] != r4[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r3[i][1].find('Lab') != -1 and r4[j][1].find('Lab') == -1:
          if r4[j][3].find(r3[i][3]) != -1:
            if r3[i][4] == '8:30 AM - 11:00 AM' :
              if r4[j][4] != '8:30 AM - 10:00 AM' and r4[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r3[i][4] == '11:00 AM - 1:30 PM' :
              if r4[j][4] != '10:05 AM - 11:35 AM' and r4[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r3[i][4] == '2:00 PM - 4:30 PM' :
              if r4[j][4] != '1:30 PM - 3:00 PM' and r4[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r4[j][1].find('Lab') != -1 and r3[i][1].find('Lab') == -1:
          if r3[i][3].find(r4[j][3]) != -1:
            if r4[j][4] == '8:30 AM - 11:00 AM' :
              if r3[i][4] != '8:30 AM - 10:00 AM' and r3[i][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r4[j][4] == '11:00 AM - 1:30 PM' :
              if r3[i][4] != '10:05 AM - 11:35 AM' and r3[i][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r4[j][4] == '2:00 PM - 4:30 PM' :
              if r3[i][4] != '1:30 PM - 3:00 PM' and r3[i][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      #course c2 and c4
      #2 theory
      if r3[i+1][1].find('Lab') == -1 and r4[j][1].find('Lab') == -1 :
        if r3[i+1][3] == r4[j][3] :
          if r3[i+1][4] != r4[j][4]:
            s+=1
        elif  r3[i+1][3] != r4[j][3]:
          s+=1
      #2 Lab
      elif r3[i+1][1].find('Lab') != -1 and r4[j][1].find('Lab') != -1 :
        if r3[i+1][3] == r4[j][3] :
          if r3[i+1][4] != r4[j][4]:
            s+=1
        elif  r3[i+1][3] != r4[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r3[i+1][1].find('Lab') != -1 and r4[j][1].find('Lab') == -1:
          if r4[j][3].find(r3[i+1][3]) != -1:
            if r3[i+1][4] == '8:30 AM - 11:00 AM' :
              if r4[j][4] != '8:30 AM - 10:00 AM' and r4[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r3[i+1][4] == '11:00 AM - 1:30 PM' :
              if r4[j][4] != '10:05 AM - 11:35 AM' and r4[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r3[i+1][4] == '2:00 PM - 4:30 PM' :
              if r4[j][4] != '1:30 PM - 3:00 PM' and r4[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r4[j][1].find('Lab') != -1:
          if r3[i+1][3].find(r4[j][3]) != -1 and r3[i+1][1].find('Lab') == -1:
            if r4[j][4] == '8:30 AM - 11:00 AM' :
              if r3[i+1][4] != '8:30 AM - 10:00 AM' and r3[i+1][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r4[j][4] == '11:00 AM - 1:30 PM' :
              if r3[i+1][4] != '10:05 AM - 11:35 AM' and r3[i+1][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r4[j][4] == '2:00 PM - 4:30 PM' :
              if r3[i+1][4] != '1:30 PM - 3:00 PM' and r3[i+1][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      #course c3 and c4
      #2 theory
      if r3[i+2][1].find('Lab') == -1 and r4[j][1].find('Lab') == -1 :
        if r3[i+2][3] == r4[j][3] :
          if r3[i+2][4] != r4[j][4]:
            s+=1
        elif  r3[i+2][3] != r4[j][3]:
          s+=1
      #2 Lab
      elif r3[i+2][1].find('Lab') != -1 and r4[j][1].find('Lab') != -1 :
        if r3[i+2][3] == r4[j][3] :
          if r3[i+2][4] != r4[j][4]:
            s+=1
        elif  r3[i+2][3] != r4[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r3[i+2][1].find('Lab') != -1 and r4[j][1].find('Lab') == -1 :
          if r4[j][3].find(r3[i+2][3]) != -1:
            if r3[i+2][4] == '8:30 AM - 11:00 AM' :
              if r4[j][4] != '8:30 AM - 10:00 AM' and r4[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r3[i+2][4] == '11:00 AM - 1:30 PM' :
              if r4[j][4] != '10:05 AM - 11:35 AM' and r4[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r3[i+2][4] == '2:00 PM - 4:30 PM' :
              if r4[j][4] != '1:30 PM - 3:00 PM' and r4[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r4[j][1].find('Lab') != -1 and r3[i+2][1].find('Lab') == -1:
          if r3[i+2][3].find(r4[j][3]) != -1:
            if r4[j][4] == '8:30 AM - 11:00 AM' :
              if r3[i+2][4] != '8:30 AM - 10:00 AM' and r3[i+2][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r4[j][4] == '11:00 AM - 1:30 PM' :
              if r3[i+2][4] != '10:05 AM - 11:35 AM' and r3[i+2][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r4[j][4] == '2:00 PM - 4:30 PM' :
              if r3[i+2][4] != '1:30 PM - 3:00 PM' and r3[i+2][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1

      if s==3 :
        r5.append(r3[i])
        r5.append(r3[i+1])
        r5.append(r3[i+2])
        r5.append(r4[j])
  #5 course
  r3 = r5
  r4 = c5
  r5=[]
  for i in range(0,len(r3),4):
    for j in range(0,len(r4)):
      s=0
      #course c1 and c5
      #2 theory
      if r3[i][1].find('Lab') == -1 and r4[j][1].find('Lab') == -1 :
        if r3[i][3] == r4[j][3] :
          if r3[i][4] != r4[j][4]:
            s+=1
        elif  r3[i][3] != r4[j][3]:
          s+=1
      #2 Lab
      elif r3[i][1].find('Lab') != -1 and r4[j][1].find('Lab') != -1 :
        if r3[i][3] == r4[j][3] :
          if r3[i][4] != r4[j][4]:
            s+=1
        elif  r3[i][3] != r4[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r3[i][1].find('Lab') != -1 and r4[j][1].find('Lab') == -1:
          if r4[j][3].find(r3[i][3]) != -1:
            if r3[i][4] == '8:30 AM - 11:00 AM' :
              if r4[j][4] != '8:30 AM - 10:00 AM' and r4[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r3[i][4] == '11:00 AM - 1:30 PM' :
              if r4[j][4] != '10:05 AM - 11:35 AM' and r4[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r3[i][4] == '2:00 PM - 4:30 PM' :
              if r4[j][4] != '1:30 PM - 3:00 PM' and r4[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r4[j][1].find('Lab') != -1 and r3[i][1].find('Lab') == -1:
          if r3[i][3].find(r4[j][3]) != -1:
            if r4[j][4] == '8:30 AM - 11:00 AM' :
              if r3[i][4] != '8:30 AM - 10:00 AM' and r3[i][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r4[j][4] == '11:00 AM - 1:30 PM' :
              if r3[i][4] != '10:05 AM - 11:35 AM' and r3[i][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r4[j][4] == '2:00 PM - 4:30 PM' :
              if r3[i][4] != '1:30 PM - 3:00 PM' and r3[i][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      #course c2 and c5
      #2 theory
      if r3[i+1][1].find('Lab') == -1 and r4[j][1].find('Lab') == -1 :
        if r3[i+1][3] == r4[j][3] :
          if r3[i+1][4] != r4[j][4]:
            s+=1
        elif  r3[i+1][3] != r4[j][3]:
          s+=1
      #2 Lab
      elif r3[i+1][1].find('Lab') != -1 and r4[j][1].find('Lab') != -1 :
        if r3[i+1][3] == r4[j][3] :
          if r3[i+1][4] != r4[j][4]:
            s+=1
        elif  r3[i+1][3] != r4[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r3[i+1][1].find('Lab') != -1 and r4[j][1].find('Lab') == -1:
          if r4[j][3].find(r3[i+1][3]) != -1:
            if r3[i+1][4] == '8:30 AM - 11:00 AM' :
              if r4[j][4] != '8:30 AM - 10:00 AM' and r4[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r3[i+1][4] == '11:00 AM - 1:30 PM' :
              if r4[j][4] != '10:05 AM - 11:35 AM' and r4[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r3[i+1][4] == '2:00 PM - 4:30 PM' :
              if r4[j][4] != '1:30 PM - 3:00 PM' and r4[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r4[j][1].find('Lab') != -1:
          if r3[i+1][3].find(r4[j][3]) != -1 and r3[i+1][1].find('Lab') == -1:
            if r4[j][4] == '8:30 AM - 11:00 AM' :
              if r3[i+1][4] != '8:30 AM - 10:00 AM' and r3[i+1][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r4[j][4] == '11:00 AM - 1:30 PM' :
              if r3[i+1][4] != '10:05 AM - 11:35 AM' and r3[i+1][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r4[j][4] == '2:00 PM - 4:30 PM' :
              if r3[i+1][4] != '1:30 PM - 3:00 PM' and r3[i+1][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      #course c3 and c5
      #2 theory
      if r3[i+2][1].find('Lab') == -1 and r4[j][1].find('Lab') == -1 :
        if r3[i+2][3] == r4[j][3] :
          if r3[i+2][4] != r4[j][4]:
            s+=1
        elif  r3[i+2][3] != r4[j][3]:
          s+=1
      #2 Lab
      elif r3[i+2][1].find('Lab') != -1 and r4[j][1].find('Lab') != -1 :
        if r3[i+2][3] == r4[j][3] :
          if r3[i+2][4] != r4[j][4]:
            s+=1
        elif  r3[i+2][3] != r4[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r3[i+2][1].find('Lab') != -1 and r4[j][1].find('Lab') == -1 :
          if r4[j][3].find(r3[i+2][3]) != -1:
            if r3[i+2][4] == '8:30 AM - 11:00 AM' :
              if r4[j][4] != '8:30 AM - 10:00 AM' and r4[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r3[i+2][4] == '11:00 AM - 1:30 PM' :
              if r4[j][4] != '10:05 AM - 11:35 AM' and r4[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r3[i+2][4] == '2:00 PM - 4:30 PM' :
              if r4[j][4] != '1:30 PM - 3:00 PM' and r4[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r4[j][1].find('Lab') != -1 and r3[i+2][1].find('Lab') == -1:
          if r3[i+2][3].find(r4[j][3]) != -1:
            if r4[j][4] == '8:30 AM - 11:00 AM' :
              if r3[i+2][4] != '8:30 AM - 10:00 AM' and r3[i+2][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r4[j][4] == '11:00 AM - 1:30 PM' :
              if r3[i+2][4] != '10:05 AM - 11:35 AM' and r3[i+2][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r4[j][4] == '2:00 PM - 4:30 PM' :
              if r3[i+2][4] != '1:30 PM - 3:00 PM' and r3[i+2][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      #course c4 and c5
      #2 theory
      if r3[i+3][1].find('Lab') == -1 and r4[j][1].find('Lab') == -1 :
        if r3[i+3][3] == r4[j][3] :
          if r3[i+3][4] != r4[j][4]:
            s+=1
        elif  r3[i+3][3] != r4[j][3]:
          s+=1
      #2 Lab
      elif r3[i+3][1].find('Lab') != -1 and r4[j][1].find('Lab') != -1 :
        if r3[i+3][3] == r4[j][3] :
          if r3[i+3][4] != r4[j][4]:
            s+=1
        elif  r3[i+3][3] != r4[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r3[i+3][1].find('Lab') != -1 and r4[j][1].find('Lab') == -1 :
          if r4[j][3].find(r3[i+3][3]) != -1:
            if r3[i+3][4] == '8:30 AM - 11:00 AM' :
              if r4[j][4] != '8:30 AM - 10:00 AM' and r4[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r3[i+3][4] == '11:00 AM - 1:30 PM' :
              if r4[j][4] != '10:05 AM - 11:35 AM' and r4[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r3[i+3][4] == '2:00 PM - 4:30 PM' :
              if r4[j][4] != '1:30 PM - 3:00 PM' and r4[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r4[j][1].find('Lab') != -1 and r3[i+3][1].find('Lab') == -1:
          if r3[i+3][3].find(r4[j][3]) != -1:
            if r4[j][4] == '8:30 AM - 11:00 AM' :
              if r3[i+3][4] != '8:30 AM - 10:00 AM' and r3[i+3][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r4[j][4] == '11:00 AM - 1:30 PM' :
              if r3[i+3][4] != '10:05 AM - 11:35 AM' and r3[i+3][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r4[j][4] == '2:00 PM - 4:30 PM' :
              if r3[i+3][4] != '1:30 PM - 3:00 PM' and r3[i+3][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1

      if s==4 :
        r5.append(r3[i])
        r5.append(r3[i+1])
        r5.append(r3[i+2])
        r5.append(r3[i+3])
        r5.append(r4[j])
  #6 course
  r3 = r5
  r4 = c6
  r5 = []
  for i in range(0,len(r3),5):
    for j in range(0,len(r4)):
      s=0
      #course c1 and c6
      #2 theory
      if r3[i][1].find('Lab') == -1 and r4[j][1].find('Lab') == -1 :
        if r3[i][3] == r4[j][3] :
          if r3[i][4] != r4[j][4]:
            s+=1
        elif  r3[i][3] != r4[j][3]:
          s+=1
      #2 Lab
      elif r3[i][1].find('Lab') != -1 and r4[j][1].find('Lab') != -1 :
        if r3[i][3] == r4[j][3] :
          if r3[i][4] != r4[j][4]:
            s+=1
        elif  r3[i][3] != r4[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r3[i][1].find('Lab') != -1 and r4[j][1].find('Lab') == -1:
          if r4[j][3].find(r3[i][3]) != -1:
            if r3[i][4] == '8:30 AM - 11:00 AM' :
              if r4[j][4] != '8:30 AM - 10:00 AM' and r4[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r3[i][4] == '11:00 AM - 1:30 PM' :
              if r4[j][4] != '10:05 AM - 11:35 AM' and r4[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r3[i][4] == '2:00 PM - 4:30 PM' :
              if r4[j][4] != '1:30 PM - 3:00 PM' and r4[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r4[j][1].find('Lab') != -1 and r3[i][1].find('Lab') == -1:
          if r3[i][3].find(r4[j][3]) != -1:
            if r4[j][4] == '8:30 AM - 11:00 AM' :
              if r3[i][4] != '8:30 AM - 10:00 AM' and r3[i][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r4[j][4] == '11:00 AM - 1:30 PM' :
              if r3[i][4] != '10:05 AM - 11:35 AM' and r3[i][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r4[j][4] == '2:00 PM - 4:30 PM' :
              if r3[i][4] != '1:30 PM - 3:00 PM' and r3[i][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      #course c2 and c6
      #2 theory
      if r3[i+1][1].find('Lab') == -1 and r4[j][1].find('Lab') == -1 :
        if r3[i+1][3] == r4[j][3] :
          if r3[i+1][4] != r4[j][4]:
            s+=1
        elif  r3[i+1][3] != r4[j][3]:
          s+=1
      #2 Lab
      elif r3[i+1][1].find('Lab') != -1 and r4[j][1].find('Lab') != -1 :
        if r3[i+1][3] == r4[j][3] :
          if r3[i+1][4] != r4[j][4]:
            s+=1
        elif  r3[i+1][3] != r4[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r3[i+1][1].find('Lab') != -1 and r4[j][1].find('Lab') == -1:
          if r4[j][3].find(r3[i+1][3]) != -1:
            if r3[i+1][4] == '8:30 AM - 11:00 AM' :
              if r4[j][4] != '8:30 AM - 10:00 AM' and r4[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r3[i+1][4] == '11:00 AM - 1:30 PM' :
              if r4[j][4] != '10:05 AM - 11:35 AM' and r4[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r3[i+1][4] == '2:00 PM - 4:30 PM' :
              if r4[j][4] != '1:30 PM - 3:00 PM' and r4[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r4[j][1].find('Lab') != -1:
          if r3[i+1][3].find(r4[j][3]) != -1 and r3[i+1][1].find('Lab') == -1:
            if r4[j][4] == '8:30 AM - 11:00 AM' :
              if r3[i+1][4] != '8:30 AM - 10:00 AM' and r3[i+1][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r4[j][4] == '11:00 AM - 1:30 PM' :
              if r3[i+1][4] != '10:05 AM - 11:35 AM' and r3[i+1][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r4[j][4] == '2:00 PM - 4:30 PM' :
              if r3[i+1][4] != '1:30 PM - 3:00 PM' and r3[i+1][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      #course c3 and c6
      #2 theory
      if r3[i+2][1].find('Lab') == -1 and r4[j][1].find('Lab') == -1 :
        if r3[i+2][3] == r4[j][3] :
          if r3[i+2][4] != r4[j][4]:
            s+=1
        elif  r3[i+2][3] != r4[j][3]:
          s+=1
      #2 Lab
      elif r3[i+2][1].find('Lab') != -1 and r4[j][1].find('Lab') != -1 :
        if r3[i+2][3] == r4[j][3] :
          if r3[i+2][4] != r4[j][4]:
            s+=1
        elif  r3[i+2][3] != r4[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r3[i+2][1].find('Lab') != -1 and r4[j][1].find('Lab') == -1 :
          if r4[j][3].find(r3[i+2][3]) != -1:
            if r3[i+2][4] == '8:30 AM - 11:00 AM' :
              if r4[j][4] != '8:30 AM - 10:00 AM' and r4[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r3[i+2][4] == '11:00 AM - 1:30 PM' :
              if r4[j][4] != '10:05 AM - 11:35 AM' and r4[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r3[i+2][4] == '2:00 PM - 4:30 PM' :
              if r4[j][4] != '1:30 PM - 3:00 PM' and r4[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r4[j][1].find('Lab') != -1 and r3[i+2][1].find('Lab') == -1:
          if r3[i+2][3].find(r4[j][3]) != -1:
            if r4[j][4] == '8:30 AM - 11:00 AM' :
              if r3[i+2][4] != '8:30 AM - 10:00 AM' and r3[i+2][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r4[j][4] == '11:00 AM - 1:30 PM' :
              if r3[i+2][4] != '10:05 AM - 11:35 AM' and r3[i+2][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r4[j][4] == '2:00 PM - 4:30 PM' :
              if r3[i+2][4] != '1:30 PM - 3:00 PM' and r3[i+2][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      #course c4 and c6
      #2 theory
      if r3[i+3][1].find('Lab') == -1 and r4[j][1].find('Lab') == -1 :
        if r3[i+3][3] == r4[j][3] :
          if r3[i+3][4] != r4[j][4]:
            s+=1
        elif  r3[i+3][3] != r4[j][3]:
          s+=1
      #2 Lab
      elif r3[i+3][1].find('Lab') != -1 and r4[j][1].find('Lab') != -1 :
        if r3[i+3][3] == r4[j][3] :
          if r3[i+3][4] != r4[j][4]:
            s+=1
        elif  r3[i+3][3] != r4[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r3[i+3][1].find('Lab') != -1 and r4[j][1].find('Lab') == -1 :
          if r4[j][3].find(r3[i+3][3]) != -1:
            if r3[i+3][4] == '8:30 AM - 11:00 AM' :
              if r4[j][4] != '8:30 AM - 10:00 AM' and r4[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r3[i+3][4] == '11:00 AM - 1:30 PM' :
              if r4[j][4] != '10:05 AM - 11:35 AM' and r4[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r3[i+3][4] == '2:00 PM - 4:30 PM' :
              if r4[j][4] != '1:30 PM - 3:00 PM' and r4[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r4[j][1].find('Lab') != -1 and r3[i+3][1].find('Lab') == -1:
          if r3[i+3][3].find(r4[j][3]) != -1:
            if r4[j][4] == '8:30 AM - 11:00 AM' :
              if r3[i+3][4] != '8:30 AM - 10:00 AM' and r3[i+3][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r4[j][4] == '11:00 AM - 1:30 PM' :
              if r3[i+3][4] != '10:05 AM - 11:35 AM' and r3[i+3][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r4[j][4] == '2:00 PM - 4:30 PM' :
              if r3[i+3][4] != '1:30 PM - 3:00 PM' and r3[i+3][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      #course c5 and c6
      #2 theory
      if r3[i+4][1].find('Lab') == -1 and r4[j][1].find('Lab') == -1 :
        if r3[i+4][3] == r4[j][3] :
          if r3[i+4][4] != r4[j][4]:
            s+=1
        elif  r3[i+4][3] != r4[j][3]:
          s+=1
      #2 Lab
      elif r3[i+4][1].find('Lab') != -1 and r4[j][1].find('Lab') != -1 :
        if r3[i+4][3] == r4[j][3] :
          if r3[i+4][4] != r4[j][4]:
            s+=1
        elif  r3[i+4][3] != r4[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r3[i+4][1].find('Lab') != -1 and r4[j][1].find('Lab') == -1 :
          if r4[j][3].find(r3[i+4][3]) != -1:
            if r3[i+4][4] == '8:30 AM - 11:00 AM' :
              if r4[j][4] != '8:30 AM - 10:00 AM' and r4[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r3[i+4][4] == '11:00 AM - 1:30 PM' :
              if r4[j][4] != '10:05 AM - 11:35 AM' and r4[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r3[i+4][4] == '2:00 PM - 4:30 PM' :
              if r4[j][4] != '1:30 PM - 3:00 PM' and r4[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r4[j][1].find('Lab') != -1 and r3[i+4][1].find('Lab') == -1:
          if r3[i+4][3].find(r4[j][3]) != -1:
            if r4[j][4] == '8:30 AM - 11:00 AM' :
              if r3[i+4][4] != '8:30 AM - 10:00 AM' and r3[i+4][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r4[j][4] == '11:00 AM - 1:30 PM' :
              if r3[i+4][4] != '10:05 AM - 11:35 AM' and r3[i+4][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r4[j][4] == '2:00 PM - 4:30 PM' :
              if r3[i+4][4] != '1:30 PM - 3:00 PM' and r3[i+4][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1

      if s==5 :
        r5.append(r3[i])
        r5.append(r3[i+1])
        r5.append(r3[i+2])
        r5.append(r3[i+3])
        r5.append(r3[i+4])
        r5.append(r4[j])

  #7 course
  r3 = r5
  r4 = c7
  r5 = []
  for i in range(0,len(r3),6):
    for j in range(0,len(r4)):
      s=0
      #course c1 and c7
      #2 theory
      if r3[i][1].find('Lab') == -1 and r4[j][1].find('Lab') == -1 :
        if r3[i][3] == r4[j][3] :
          if r3[i][4] != r4[j][4]:
            s+=1
        elif  r3[i][3] != r4[j][3]:
          s+=1
      #2 Lab
      elif r3[i][1].find('Lab') != -1 and r4[j][1].find('Lab') != -1 :
        if r3[i][3] == r4[j][3] :
          if r3[i][4] != r4[j][4]:
            s+=1
        elif  r3[i][3] != r4[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r3[i][1].find('Lab') != -1 and r4[j][1].find('Lab') == -1:
          if r4[j][3].find(r3[i][3]) != -1:
            if r3[i][4] == '8:30 AM - 11:00 AM' :
              if r4[j][4] != '8:30 AM - 10:00 AM' and r4[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r3[i][4] == '11:00 AM - 1:30 PM' :
              if r4[j][4] != '10:05 AM - 11:35 AM' and r4[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r3[i][4] == '2:00 PM - 4:30 PM' :
              if r4[j][4] != '1:30 PM - 3:00 PM' and r4[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r4[j][1].find('Lab') != -1 and r3[i][1].find('Lab') == -1:
          if r3[i][3].find(r4[j][3]) != -1:
            if r4[j][4] == '8:30 AM - 11:00 AM' :
              if r3[i][4] != '8:30 AM - 10:00 AM' and r3[i][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r4[j][4] == '11:00 AM - 1:30 PM' :
              if r3[i][4] != '10:05 AM - 11:35 AM' and r3[i][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r4[j][4] == '2:00 PM - 4:30 PM' :
              if r3[i][4] != '1:30 PM - 3:00 PM' and r3[i][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      #course c2 and c7
      #2 theory
      if r3[i+1][1].find('Lab') == -1 and r4[j][1].find('Lab') == -1 :
        if r3[i+1][3] == r4[j][3] :
          if r3[i+1][4] != r4[j][4]:
            s+=1
        elif  r3[i+1][3] != r4[j][3]:
          s+=1
      #2 Lab
      elif r3[i+1][1].find('Lab') != -1 and r4[j][1].find('Lab') != -1 :
        if r3[i+1][3] == r4[j][3] :
          if r3[i+1][4] != r4[j][4]:
            s+=1
        elif  r3[i+1][3] != r4[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r3[i+1][1].find('Lab') != -1 and r4[j][1].find('Lab') == -1:
          if r4[j][3].find(r3[i+1][3]) != -1:
            if r3[i+1][4] == '8:30 AM - 11:00 AM' :
              if r4[j][4] != '8:30 AM - 10:00 AM' and r4[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r3[i+1][4] == '11:00 AM - 1:30 PM' :
              if r4[j][4] != '10:05 AM - 11:35 AM' and r4[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r3[i+1][4] == '2:00 PM - 4:30 PM' :
              if r4[j][4] != '1:30 PM - 3:00 PM' and r4[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r4[j][1].find('Lab') != -1:
          if r3[i+1][3].find(r4[j][3]) != -1 and r3[i+1][1].find('Lab') == -1:
            if r4[j][4] == '8:30 AM - 11:00 AM' :
              if r3[i+1][4] != '8:30 AM - 10:00 AM' and r3[i+1][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r4[j][4] == '11:00 AM - 1:30 PM' :
              if r3[i+1][4] != '10:05 AM - 11:35 AM' and r3[i+1][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r4[j][4] == '2:00 PM - 4:30 PM' :
              if r3[i+1][4] != '1:30 PM - 3:00 PM' and r3[i+1][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      #course c3 and c7
      #2 theory
      if r3[i+2][1].find('Lab') == -1 and r4[j][1].find('Lab') == -1 :
        if r3[i+2][3] == r4[j][3] :
          if r3[i+2][4] != r4[j][4]:
            s+=1
        elif  r3[i+2][3] != r4[j][3]:
          s+=1
      #2 Lab
      elif r3[i+2][1].find('Lab') != -1 and r4[j][1].find('Lab') != -1 :
        if r3[i+2][3] == r4[j][3] :
          if r3[i+2][4] != r4[j][4]:
            s+=1
        elif  r3[i+2][3] != r4[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r3[i+2][1].find('Lab') != -1 and r4[j][1].find('Lab') == -1 :
          if r4[j][3].find(r3[i+2][3]) != -1:
            if r3[i+2][4] == '8:30 AM - 11:00 AM' :
              if r4[j][4] != '8:30 AM - 10:00 AM' and r4[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r3[i+2][4] == '11:00 AM - 1:30 PM' :
              if r4[j][4] != '10:05 AM - 11:35 AM' and r4[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r3[i+2][4] == '2:00 PM - 4:30 PM' :
              if r4[j][4] != '1:30 PM - 3:00 PM' and r4[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r4[j][1].find('Lab') != -1 and r3[i+2][1].find('Lab') == -1:
          if r3[i+2][3].find(r4[j][3]) != -1:
            if r4[j][4] == '8:30 AM - 11:00 AM' :
              if r3[i+2][4] != '8:30 AM - 10:00 AM' and r3[i+2][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r4[j][4] == '11:00 AM - 1:30 PM' :
              if r3[i+2][4] != '10:05 AM - 11:35 AM' and r3[i+2][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r4[j][4] == '2:00 PM - 4:30 PM' :
              if r3[i+2][4] != '1:30 PM - 3:00 PM' and r3[i+2][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      #course c4 and c7
      #2 theory
      if r3[i+3][1].find('Lab') == -1 and r4[j][1].find('Lab') == -1 :
        if r3[i+3][3] == r4[j][3] :
          if r3[i+3][4] != r4[j][4]:
            s+=1
        elif  r3[i+3][3] != r4[j][3]:
          s+=1
      #2 Lab
      elif r3[i+3][1].find('Lab') != -1 and r4[j][1].find('Lab') != -1 :
        if r3[i+3][3] == r4[j][3] :
          if r3[i+3][4] != r4[j][4]:
            s+=1
        elif  r3[i+3][3] != r4[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r3[i+3][1].find('Lab') != -1 and r4[j][1].find('Lab') == -1 :
          if r4[j][3].find(r3[i+3][3]) != -1:
            if r3[i+3][4] == '8:30 AM - 11:00 AM' :
              if r4[j][4] != '8:30 AM - 10:00 AM' and r4[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r3[i+3][4] == '11:00 AM - 1:30 PM' :
              if r4[j][4] != '10:05 AM - 11:35 AM' and r4[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r3[i+3][4] == '2:00 PM - 4:30 PM' :
              if r4[j][4] != '1:30 PM - 3:00 PM' and r4[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r4[j][1].find('Lab') != -1 and r3[i+3][1].find('Lab') == -1:
          if r3[i+3][3].find(r4[j][3]) != -1:
            if r4[j][4] == '8:30 AM - 11:00 AM' :
              if r3[i+3][4] != '8:30 AM - 10:00 AM' and r3[i+3][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r4[j][4] == '11:00 AM - 1:30 PM' :
              if r3[i+3][4] != '10:05 AM - 11:35 AM' and r3[i+3][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r4[j][4] == '2:00 PM - 4:30 PM' :
              if r3[i+3][4] != '1:30 PM - 3:00 PM' and r3[i+3][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      #course c5 and c7
      #2 theory
      if r3[i+4][1].find('Lab') == -1 and r4[j][1].find('Lab') == -1 :
        if r3[i+4][3] == r4[j][3] :
          if r3[i+4][4] != r4[j][4]:
            s+=1
        elif  r3[i+4][3] != r4[j][3]:
          s+=1
      #2 Lab
      elif r3[i+4][1].find('Lab') != -1 and r4[j][1].find('Lab') != -1 :
        if r3[i+4][3] == r4[j][3] :
          if r3[i+4][4] != r4[j][4]:
            s+=1
        elif  r3[i+4][3] != r4[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r3[i+4][1].find('Lab') != -1 and r4[j][1].find('Lab') == -1 :
          if r4[j][3].find(r3[i+4][3]) != -1:
            if r3[i+4][4] == '8:30 AM - 11:00 AM' :
              if r4[j][4] != '8:30 AM - 10:00 AM' and r4[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r3[i+4][4] == '11:00 AM - 1:30 PM' :
              if r4[j][4] != '10:05 AM - 11:35 AM' and r4[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r3[i+4][4] == '2:00 PM - 4:30 PM' :
              if r4[j][4] != '1:30 PM - 3:00 PM' and r4[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r4[j][1].find('Lab') != -1 and r3[i+4][1].find('Lab') == -1:
          if r3[i+4][3].find(r4[j][3]) != -1:
            if r4[j][4] == '8:30 AM - 11:00 AM' :
              if r3[i+4][4] != '8:30 AM - 10:00 AM' and r3[i+4][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r4[j][4] == '11:00 AM - 1:30 PM' :
              if r3[i+4][4] != '10:05 AM - 11:35 AM' and r3[i+4][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r4[j][4] == '2:00 PM - 4:30 PM' :
              if r3[i+4][4] != '1:30 PM - 3:00 PM' and r3[i+4][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      #c6 and c7
      #2 theory
      if r3[i+5][1].find('Lab') == -1 and r4[j][1].find('Lab') == -1 :
        if r3[i+5][3] == r4[j][3] :
          if r3[i+5][4] != r4[j][4]:
            s+=1
        elif  r3[i+5][3] != r4[j][3]:
          s+=1
      #2 Lab
      elif r3[i+5][1].find('Lab') != -1 and r4[j][1].find('Lab') != -1 :
        if r3[i+5][3] == r4[j][3] :
          if r3[i+5][4] != r4[j][4]:
            s+=1
        elif  r3[i+5][3] != r4[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r3[i+5][1].find('Lab') != -1 and r4[j][1].find('Lab') == -1:
          if r4[j][3].find(r3[i+5][3]) != -1:
            if r3[i+5][4] == '8:30 AM - 11:00 AM' :
              if r4[j][4] != '8:30 AM - 10:00 AM' and r4[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r3[i+5][4] == '11:00 AM - 1:30 PM' :
              if r4[j][4] != '10:05 AM - 11:35 AM' and r4[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r3[i+5][4] == '2:00 PM - 4:30 PM' :
              if r4[j][4] != '1:30 PM - 3:00 PM' and r4[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r4[j][1].find('Lab') != -1 and r3[i+5][1].find('Lab') == -1:
          if r3[i+5][3].find(r4[j][3]) != -1:
            if r4[j][4] == '8:30 AM - 11:00 AM' :
              if r3[i+5][4] != '8:30 AM - 10:00 AM' and r3[i+5][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r4[j][4] == '11:00 AM - 1:30 PM' :
              if r3[i+5][4] != '10:05 AM - 11:35 AM' and r3[i+5][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r4[j][4] == '2:00 PM - 4:30 PM' :
              if r3[i+5][4] != '1:30 PM - 3:00 PM' and r3[i+5][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1

      if s==6 :
        r5.append(r3[i])
        r5.append(r3[i+1],)
        r5.append(r3[i+2])
        r5.append(r3[i+3])
        r5.append(r3[i+4])
        r5.append(r3[i+5])
        r5.append(r4[j])

  r=1
  # 8 course
  r3 = r5
  r4 = c8
  t=0
  r5 = []
  print("Suggested Schedule :")
  for i in range(0,len(r3),7):
    for j in range(0,len(r4)):
      s=0
      #course c1 and c8
      #2 theory
      if r3[i][1].find('Lab') == -1 and r4[j][1].find('Lab') == -1 :
        if r3[i][3] == r4[j][3] :
          if r3[i][4] != r4[j][4]:
            s+=1
        elif  r3[i][3] != r4[j][3]:
          s+=1
      #2 Lab
      elif r3[i][1].find('Lab') != -1 and r4[j][1].find('Lab') != -1 :
        if r3[i][3] == r4[j][3] :
          if r3[i][4] != r4[j][4]:
            s+=1
        elif  r3[i][3] != r4[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r3[i][1].find('Lab') != -1 and r4[j][1].find('Lab') == -1:
          if r4[j][3].find(r3[i][3]) != -1:
            if r3[i][4] == '8:30 AM - 11:00 AM' :
              if r4[j][4] != '8:30 AM - 10:00 AM' and r4[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r3[i][4] == '11:00 AM - 1:30 PM' :
              if r4[j][4] != '10:05 AM - 11:35 AM' and r4[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r3[i][4] == '2:00 PM - 4:30 PM' :
              if r4[j][4] != '1:30 PM - 3:00 PM' and r4[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r4[j][1].find('Lab') != -1 and r3[i][1].find('Lab') == -1:
          if r3[i][3].find(r4[j][3]) != -1:
            if r4[j][4] == '8:30 AM - 11:00 AM' :
              if r3[i][4] != '8:30 AM - 10:00 AM' and r3[i][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r4[j][4] == '11:00 AM - 1:30 PM' :
              if r3[i][4] != '10:05 AM - 11:35 AM' and r3[i][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r4[j][4] == '2:00 PM - 4:30 PM' :
              if r3[i][4] != '1:30 PM - 3:00 PM' and r3[i][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      #course c2 and c8
      #2 theory
      if r3[i+1][1].find('Lab') == -1 and r4[j][1].find('Lab') == -1 :
        if r3[i+1][3] == r4[j][3] :
          if r3[i+1][4] != r4[j][4]:
            s+=1
        elif  r3[i+1][3] != r4[j][3]:
          s+=1
      #2 Lab
      elif r3[i+1][1].find('Lab') != -1 and r4[j][1].find('Lab') != -1 :
        if r3[i+1][3] == r4[j][3] :
          if r3[i+1][4] != r4[j][4]:
            s+=1
        elif  r3[i+1][3] != r4[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r3[i+1][1].find('Lab') != -1 and r4[j][1].find('Lab') == -1:
          if r4[j][3].find(r3[i+1][3]) != -1:
            if r3[i+1][4] == '8:30 AM - 11:00 AM' :
              if r4[j][4] != '8:30 AM - 10:00 AM' and r4[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r3[i+1][4] == '11:00 AM - 1:30 PM' :
              if r4[j][4] != '10:05 AM - 11:35 AM' and r4[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r3[i+1][4] == '2:00 PM - 4:30 PM' :
              if r4[j][4] != '1:30 PM - 3:00 PM' and r4[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r4[j][1].find('Lab') != -1:
          if r3[i+1][3].find(r4[j][3]) != -1 and r3[i+1][1].find('Lab') == -1:
            if r4[j][4] == '8:30 AM - 11:00 AM' :
              if r3[i+1][4] != '8:30 AM - 10:00 AM' and r3[i+1][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r4[j][4] == '11:00 AM - 1:30 PM' :
              if r3[i+1][4] != '10:05 AM - 11:35 AM' and r3[i+1][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r4[j][4] == '2:00 PM - 4:30 PM' :
              if r3[i+1][4] != '1:30 PM - 3:00 PM' and r3[i+1][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      #course c3 and c8
      #2 theory
      if r3[i+2][1].find('Lab') == -1 and r4[j][1].find('Lab') == -1 :
        if r3[i+2][3] == r4[j][3] :
          if r3[i+2][4] != r4[j][4]:
            s+=1
        elif  r3[i+2][3] != r4[j][3]:
          s+=1
      #2 Lab
      elif r3[i+2][1].find('Lab') != -1 and r4[j][1].find('Lab') != -1 :
        if r3[i+2][3] == r4[j][3] :
          if r3[i+2][4] != r4[j][4]:
            s+=1
        elif  r3[i+2][3] != r4[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r3[i+2][1].find('Lab') != -1 and r4[j][1].find('Lab') == -1 :
          if r4[j][3].find(r3[i+2][3]) != -1:
            if r3[i+2][4] == '8:30 AM - 11:00 AM' :
              if r4[j][4] != '8:30 AM - 10:00 AM' and r4[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r3[i+2][4] == '11:00 AM - 1:30 PM' :
              if r4[j][4] != '10:05 AM - 11:35 AM' and r4[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r3[i+2][4] == '2:00 PM - 4:30 PM' :
              if r4[j][4] != '1:30 PM - 3:00 PM' and r4[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r4[j][1].find('Lab') != -1 and r3[i+2][1].find('Lab') == -1:
          if r3[i+2][3].find(r4[j][3]) != -1:
            if r4[j][4] == '8:30 AM - 11:00 AM' :
              if r3[i+2][4] != '8:30 AM - 10:00 AM' and r3[i+2][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r4[j][4] == '11:00 AM - 1:30 PM' :
              if r3[i+2][4] != '10:05 AM - 11:35 AM' and r3[i+2][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r4[j][4] == '2:00 PM - 4:30 PM' :
              if r3[i+2][4] != '1:30 PM - 3:00 PM' and r3[i+2][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      #course c4 and c8
      #2 theory
      if r3[i+3][1].find('Lab') == -1 and r4[j][1].find('Lab') == -1 :
        if r3[i+3][3] == r4[j][3] :
          if r3[i+3][4] != r4[j][4]:
            s+=1
        elif  r3[i+3][3] != r4[j][3]:
          s+=1
      #2 Lab
      elif r3[i+3][1].find('Lab') != -1 and r4[j][1].find('Lab') != -1 :
        if r3[i+3][3] == r4[j][3] :
          if r3[i+3][4] != r4[j][4]:
            s+=1
        elif  r3[i+3][3] != r4[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r3[i+3][1].find('Lab') != -1 and r4[j][1].find('Lab') == -1 :
          if r4[j][3].find(r3[i+3][3]) != -1:
            if r3[i+3][4] == '8:30 AM - 11:00 AM' :
              if r4[j][4] != '8:30 AM - 10:00 AM' and r4[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r3[i+3][4] == '11:00 AM - 1:30 PM' :
              if r4[j][4] != '10:05 AM - 11:35 AM' and r4[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r3[i+3][4] == '2:00 PM - 4:30 PM' :
              if r4[j][4] != '1:30 PM - 3:00 PM' and r4[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r4[j][1].find('Lab') != -1 and r3[i+3][1].find('Lab') == -1:
          if r3[i+3][3].find(r4[j][3]) != -1:
            if r4[j][4] == '8:30 AM - 11:00 AM' :
              if r3[i+3][4] != '8:30 AM - 10:00 AM' and r3[i+3][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r4[j][4] == '11:00 AM - 1:30 PM' :
              if r3[i+3][4] != '10:05 AM - 11:35 AM' and r3[i+3][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r4[j][4] == '2:00 PM - 4:30 PM' :
              if r3[i+3][4] != '1:30 PM - 3:00 PM' and r3[i+3][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      #course c5 and c8
      #2 theory
      if r3[i+4][1].find('Lab') == -1 and r4[j][1].find('Lab') == -1 :
        if r3[i+4][3] == r4[j][3] :
          if r3[i+4][4] != r4[j][4]:
            s+=1
        elif  r3[i+4][3] != r4[j][3]:
          s+=1
      #2 Lab
      elif r3[i+4][1].find('Lab') != -1 and r4[j][1].find('Lab') != -1 :
        if r3[i+4][3] == r4[j][3] :
          if r3[i+4][4] != r4[j][4]:
            s+=1
        elif  r3[i+4][3] != r4[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r3[i+4][1].find('Lab') != -1 and r4[j][1].find('Lab') == -1 :
          if r4[j][3].find(r3[i+4][3]) != -1:
            if r3[i+4][4] == '8:30 AM - 11:00 AM' :
              if r4[j][4] != '8:30 AM - 10:00 AM' and r4[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r3[i+4][4] == '11:00 AM - 1:30 PM' :
              if r4[j][4] != '10:05 AM - 11:35 AM' and r4[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r3[i+4][4] == '2:00 PM - 4:30 PM' :
              if r4[j][4] != '1:30 PM - 3:00 PM' and r4[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r4[j][1].find('Lab') != -1 and r3[i+4][1].find('Lab') == -1:
          if r3[i+4][3].find(r4[j][3]) != -1:
            if r4[j][4] == '8:30 AM - 11:00 AM' :
              if r3[i+4][4] != '8:30 AM - 10:00 AM' and r3[i+4][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r4[j][4] == '11:00 AM - 1:30 PM' :
              if r3[i+4][4] != '10:05 AM - 11:35 AM' and r3[i+4][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r4[j][4] == '2:00 PM - 4:30 PM' :
              if r3[i+4][4] != '1:30 PM - 3:00 PM' and r3[i+4][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      #c6 and c8
      #2 theory
      if r3[i+5][1].find('Lab') == -1 and r4[j][1].find('Lab') == -1 :
        if r3[i+5][3] == r4[j][3] :
          if r3[i+5][4] != r4[j][4]:
            s+=1
        elif  r3[i+5][3] != r4[j][3]:
          s+=1
      #2 Lab
      elif r3[i+5][1].find('Lab') != -1 and r4[j][1].find('Lab') != -1 :
        if r3[i+5][3] == r4[j][3] :
          if r3[i+5][4] != r4[j][4]:
            s+=1
        elif  r3[i+5][3] != r4[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r3[i+5][1].find('Lab') != -1 and r4[j][1].find('Lab') == -1:
          if r4[j][3].find(r3[i+5][3]) != -1:
            if r3[i+5][4] == '8:30 AM - 11:00 AM' :
              if r4[j][4] != '8:30 AM - 10:00 AM' and r4[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r3[i+5][4] == '11:00 AM - 1:30 PM' :
              if r4[j][4] != '10:05 AM - 11:35 AM' and r4[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r3[i+5][4] == '2:00 PM - 4:30 PM' :
              if r4[j][4] != '1:30 PM - 3:00 PM' and r4[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r4[j][1].find('Lab') != -1 and r3[i+5][1].find('Lab') == -1:
          if r3[i+5][3].find(r4[j][3]) != -1:
            if r4[j][4] == '8:30 AM - 11:00 AM' :
              if r3[i+5][4] != '8:30 AM - 10:00 AM' and r3[i+5][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r4[j][4] == '11:00 AM - 1:30 PM' :
              if r3[i+5][4] != '10:05 AM - 11:35 AM' and r3[i+5][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r4[j][4] == '2:00 PM - 4:30 PM' :
              if r3[i+5][4] != '1:30 PM - 3:00 PM' and r3[i+5][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      #c7 and c8
      #2 theory
      if r3[i+6][1].find('Lab') == -1 and r4[j][1].find('Lab') == -1 :
        if r3[i+6][3] == r4[j][3] :
          if r3[i+6][4] != r4[j][4]:
            s+=1
        elif  r3[i+6][3] != r4[j][3]:
          s+=1
      #2 Lab
      elif r3[i+6][1].find('Lab') != -1 and r4[j][1].find('Lab') != -1 :
        if r3[i+6][3] == r4[j][3] :
          if r3[i+6][4] != r4[j][4]:
            s+=1
        elif  r3[i+6][3] != r4[j][3]:
          s+=1
      #1 Theory 1 Lab
      elif r3[i+6][1].find('Lab') != -1 and r4[j][1].find('Lab') == -1:
          if r4[j][3].find(r3[i+6][3]) != -1:
            if r3[i+6][4] == '8:30 AM - 11:00 AM' :
              if r4[j][4] != '8:30 AM - 10:00 AM' and r4[j][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r3[i+6][4] == '11:00 AM - 1:30 PM' :
              if r4[j][4] != '10:05 AM - 11:35 AM' and r4[j][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r3[i+6][4] == '2:00 PM - 4:30 PM' :
              if r4[j][4] != '1:30 PM - 3:00 PM' and r4[j][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1
      elif r4[j][1].find('Lab') != -1 and r3[i+6][1].find('Lab') == -1:
          if r3[i+6][3].find(r4[j][3]) != -1:
            if r4[j][4] == '8:30 AM - 11:00 AM' :
              if r3[i+6][4] != '8:30 AM - 10:00 AM' and r3[i+6][4] != '10:05 AM - 11:35 AM' :
                s+=1
            elif r4[j][4] == '11:00 AM - 1:30 PM' :
              if r3[i+6][4] != '10:05 AM - 11:35 AM' and r3[i+6][4] != '11:40 AM - 1:10 PM' :
                s+=1
            elif r4[j][4] == '2:00 PM - 4:30 PM' :
              if r3[i+6][4] != '1:30 PM - 3:00 PM' and r3[i+6][4] != '3:00 PM - 4:30 PM' :
                s+=1
          else :
            s+=1

      if s==7 :
        print("Suggested Schedule ",r," :")
        print(r3[i],r3[i+1],r3[i+2],r3[i+3],r3[i+4],r3[i+5],r3[i+6],r4[j])
        r5.append(r3[i])
        r5.append(r3[i+1])
        r5.append(r3[i+2])
        r5.append(r3[i+3])
        r5.append(r3[i+4])
        r5.append(r3[i+5])
        r5.append(r3[i+6])
        r5.append(r4[j])

        final_routine=[]
        print("Time Gap Of Schedule ",r," :")
        final_routine.append(r3[i])
        final_routine.append(r3[i+1])
        final_routine.append(r3[i+2])
        final_routine.append(r3[i+3])
        final_routine.append(r3[i+4])
        final_routine.append(r3[i+5])
        final_routine.append(r3[i+6])
        final_routine.append(r4[j])
        day_count(final_routine)

        t+=1
        r+=1
        print("")

  print("All Posible Schedule = ",all_possible)
  print("Suggested Schedule = ",t)

  print("")
  print("")
  print("")
  print("Your Preferable Schedule :")
  if m == '1' :
    p=0
    r=1
    for i in range(0,len(r5),8):
      if r5[i][4] != '8:30 AM - 10:00 AM' and r5[i][4] != '8:30 AM - 11:00 AM':
        if r5[i+1][4] != '8:30 AM - 10:00 AM'  and r5[i+1][4] != '8:30 AM - 11:00 AM':
          if r5[i+2][4] != '8:30 AM - 10:00 AM' and r5[i+2][4] != '8:30 AM - 11:00 AM':
            if r5[i+3][4] != '8:30 AM - 10:00 AM' and r5[i+3][4] != '8:30 AM - 11:00 AM':
              if r5[i+4][4] != '8:30 AM - 10:00 AM' and r5[i+4][4] != '8:30 AM - 11:00 AM':
                if r5[i+5][4] != '8:30 AM - 10:00 AM' and r5[i+5][4] != '8:30 AM - 11:00 AM':
                  if r5[i+6][4] != '8:30 AM - 10:00 AM' and r5[i+6][4] != '8:30 AM - 11:00 AM':
                    if r5[i+7][4] != '8:30 AM - 10:00 AM' and r5[i+7][4] != '8:30 AM - 11:00 AM':
                      print(r5[i],r5[i+1],r5[i+2],r5[i+3],r5[i+4],r5[i+5],r5[i+6],r5[i+7])
                      final_routine=[]
                      print("Time Gap Of Day Schedule ",r," :")
                      final_routine.append(r5[i])
                      final_routine.append(r5[i+1])
                      final_routine.append(r5[i+2])
                      final_routine.append(r5[i+3])
                      final_routine.append(r5[i+4])
                      final_routine.append(r5[i+5])
                      final_routine.append(r5[i+6])
                      final_routine.append(r5[i+7])
                      day_count(final_routine)
                      print("") 
                      p+=1
                      r+=1
    if p==0:
      print("Sorry No Schedule Available In Day Time")
  if m == '2' :
    p=0
    r=1
    for i in range(0,len(r5),8):
      if r5[i][4] != '2:00 PM - 4:30 PM' and r5[i][4] != '1:30 PM - 3:00 PM' and  r5[i][4] != '3:00 PM - 4:30 PM' :
        if r5[i+1][4] != '2:00 PM - 4:30 PM' and r5[i+1][4] != '1:30 PM - 3:00 PM' and  r5[i+1][4] != '3:00 PM - 4:30 PM' :
          if r5[i+2][4] != '2:00 PM - 4:30 PM' and r5[i+2][4] != '1:30 PM - 3:00 PM' and  r5[i+2][4] != '3:00 PM - 4:30 PM' :
            if r5[i+3][4] != '2:00 PM - 4:30 PM' and r5[i+3][4] != '1:30 PM - 3:00 PM' and  r5[i+3][4] != '3:00 PM - 4:30 PM' :
              if r5[i+4][4] != '2:00 PM - 4:30 PM' and r5[i+4][4] != '1:30 PM - 3:00 PM' and  r5[i+4][4] != '3:00 PM - 4:30 PM' :
                if r5[i+5][4] != '2:00 PM - 4:30 PM' and r5[i+5][4] != '1:30 PM - 3:00 PM' and  r5[i+5][4] != '3:00 PM - 4:30 PM' :
                  if r5[i+6][4] != '2:00 PM - 4:30 PM' and r5[i+6][4] != '1:30 PM - 3:00 PM' and  r5[i+6][4] != '3:00 PM - 4:30 PM' :
                    if r5[i+7][4] != '2:00 PM - 4:30 PM' and r5[i+7][4] != '1:30 PM - 3:00 PM' and  r5[i+7][4] != '3:00 PM - 4:30 PM' :
                      print(r5[i],r5[i+1],r5[i+2],r5[i+3],r5[i+4],r5[i+5],r5[i+6],r5[i+7])
                      final_routine=[]
                      print("Time Gap Of Morning Schedule ",r," :")
                      final_routine.append(r5[i])
                      final_routine.append(r5[i+1])
                      final_routine.append(r5[i+2])
                      final_routine.append(r5[i+3])
                      final_routine.append(r5[i+4])
                      final_routine.append(r5[i+5])
                      final_routine.append(r5[i+6])
                      final_routine.append(r5[i+7])
                      day_count(final_routine)
                      print("")
                      p+=1
                      r+=1
    if p==0 :
      print("Sorry No Schedule Available In Morning Time")
